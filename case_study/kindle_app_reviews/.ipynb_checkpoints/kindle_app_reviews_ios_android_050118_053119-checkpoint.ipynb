# %%
#Importing libraries
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import matplotlib.pyplot as plt#visualization
from PIL import  Image
# %matplotlib inline
import pandas as pd
import seaborn as sns#visualization
import itertools
import warnings
warnings.filterwarnings("ignore")
import io
import plotly.offline as py#visualization
py.init_notebook_mode(connected=True)#visualization
import plotly.graph_objs as go#visualization
import plotly.tools as tls#visualization
import plotly.figure_factory as ff#visualization
import pprint
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#options
pd.options.display.max_rows = 1000
pd.options.display.max_columns = 1000

# %%
# load data
# as = app store; gp = google play
df_gp_kindle_05_18 = pd.read_csv(r"Google Play_Amazon Kindle_2018_05_01-2018_05_31.csv")
df_gp_kindle_06_18 = pd.read_csv(r"Google Play_Amazon Kindle_2018_06_01-2018_06_30.csv")
df_gp_kindle_07_18 = pd.read_csv(r"Google Play_Amazon Kindle_2018_07_01-2018_07_31.csv")
df_gp_kindle_08_18 = pd.read_csv(r"Google Play_Amazon Kindle_2018_08_01-2018_08_31.csv")
df_gp_kindle_09_18 = pd.read_csv(r"Google Play_Amazon Kindle_2018_09_01-2018_09_30.csv")
df_gp_kindle_10_18 = pd.read_csv(r"Google Play_Amazon Kindle_2018_10_01-2018_10_31.csv")
df_gp_kindle_11_18 = pd.read_csv(r"Google Play_Amazon Kindle_2018_11_01-2018_11_30.csv")
df_gp_kindle_12_18 = pd.read_csv(r"Google Play_Amazon Kindle_2018_12_01-2018_12_31.csv")
df_gp_kindle_01_19 = pd.read_csv(r"Google Play_Amazon Kindle_2019_01_01-2019_01_31.csv")
df_gp_kindle_02_19 = pd.read_csv(r"Google Play_Amazon Kindle_2019_02_01-2019_02_28.csv")
df_gp_kindle_03_19 = pd.read_csv(r"Google Play_Amazon Kindle_2019_03_01-2019_03_31.csv")
df_gp_kindle_04_19 = pd.read_csv(r"Google Play_Amazon Kindle_2019_04_01-2019_04_30.csv")
df_gp_kindle_05_19 = pd.read_csv(r"Google Play_Amazon Kindle_2019_05_01-2019_05_31.csv")
df_gp_kindle_05_18_05_19 = pd.concat([df_gp_kindle_05_18,df_gp_kindle_06_18,df_gp_kindle_07_18,df_gp_kindle_08_18,df_gp_kindle_09_18,df_gp_kindle_10_18,df_gp_kindle_11_18,df_gp_kindle_12_18,df_gp_kindle_01_19,df_gp_kindle_02_19,df_gp_kindle_03_19,df_gp_kindle_04_19,df_gp_kindle_05_19])

df_as_kindle_05_18_05_19 = pd.read_csv(r"iOS_Amazon Kindle_2018_05_01-2019_05_31.csv")

# %%
#iOS
#df_as_kindle_05_18_05_19.head()
# Out:
#   Platform        Country       Date     App ID       App Name  Publisher ID  \
# 0      iOS  United States  5/31/2019  302584613  Amazon Kindle     297606954
# 1      iOS  United States  5/31/2019  302584613  Amazon Kindle     297606954
# 2      iOS  United States  5/31/2019  302584613  Amazon Kindle     297606954
# 3      iOS  United States  5/31/2019  302584613  Amazon Kindle     297606954
# 4      iOS  United States  5/31/2019  302584613  Amazon Kindle     297606954
#
#     Publisher Name  User Version  Rating  \
# 0  AMZN Mobile LLC   NaN    6.19       2
# 1  AMZN Mobile LLC   NaN    6.19       5
# 2  AMZN Mobile LLC   NaN    6.19       1
# 3  AMZN Mobile LLC   NaN    6.19       3
# 4  AMZN Mobile LLC   NaN    6.19       5
#
#                                           Title  \
# 0                      Not user friendly at all
# 1                                        Kindle
# 2                            Crashes every time
# 3                                         Books
# 4  Maybe because it’s only a few apps out there
#
#                                               Review
# 0  As I sometimes leave my Kindle at home by mist...
# 1  So convenient and fun to buy and read on my ki...
# 2  I love Kindle and use it every day on my iPad....
# 3  Great app, but I'd like to be able to remove b...
# 4  I have 2k books in my kindle at my disposal. H...

# %%
#Android
#df_gp_kindle_05_18_05_19.head()
# Out:
#       Platform Language       Date             App ID       App Name  \
# 0  Google Play  English  5/31/2018  com.amazon.kindle  Amazon Kindle
# 1  Google Play  English  5/31/2018  com.amazon.kindle  Amazon Kindle
# 2  Google Play  English  5/31/2018  com.amazon.kindle  Amazon Kindle
# 3  Google Play  English  5/31/2018  com.amazon.kindle  Amazon Kindle
# 4  Google Play  English  5/31/2018  com.amazon.kindle  Amazon Kindle
#
#    Publisher ID     Publisher Name  User    Version  Rating Title  \
# 0  2.020000e+13  Amazon Mobile LLC   NaN        NaN       5   NaN
# 1  2.020000e+13  Amazon Mobile LLC   NaN        NaN       5   NaN
# 2  2.020000e+13  Amazon Mobile LLC   NaN   8.0.0.78       1   NaN
# 3  2.020000e+13  Amazon Mobile LLC   NaN  7.15.0.90       3   NaN
# 4  2.020000e+13  Amazon Mobile LLC   NaN        NaN       5   NaN
#
#                                               Review
# 0                                               Good
# 1                                            love it
# 2  HATEEEEE TOOOO READDDDDD I HATTTTEEEE ITTTTT w...
# 3                           Needs some work for sure
# 4                                               Good

# %%
#ios
#df_as_kindle_05_18_05_19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18632 entries, 0 to 18631
# Data columns (total 12 columns):
# Platform          18632 non-null object
# Country           18632 non-null object
# Date              18632 non-null object
# App ID            18632 non-null int64
# App Name          18632 non-null object
# Publisher ID      18632 non-null int64
# Publisher Name    18632 non-null object
# User              0 non-null float64
# Version           18632 non-null object
# Rating            18632 non-null int64
# Title             18631 non-null object
# Review            18632 non-null object
# dtypes: float64(1), int64(3), object(8)
# memory usage: 1.7+ MB

# %%
#android
#df_gp_kindle_05_18_05_19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21048 entries, 0 to 1689
# Data columns (total 12 columns):
# Platform          21048 non-null object
# Language          21048 non-null object
# Date              21048 non-null object
# App ID            21048 non-null object
# App Name          21048 non-null object
# Publisher ID      21048 non-null float64
# Publisher Name    21048 non-null object
# User              0 non-null float64
# Version           11685 non-null object
# Rating            21048 non-null int64
# Title             41 non-null object
# Review            21047 non-null object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 2.1+ MB

# %%
#df_as_kindle_05_18_05_19.nunique()
# Out:
# Platform              1
# Country               1
# Date                395
# App ID                1
# App Name              1
# Publisher ID          1
# Publisher Name        1
# User                  0
# Version              21
# Rating                5
# Title             10674
# Review            18103
# dtype: int64

# %%
#df_gp_kindle_05_18_05_19.nunique()
# Out:
# Platform              1
# Language              1
# Date                394
# App ID                1
# App Name              1
# Publisher ID          1
# Publisher Name        1
# User                  0
# Version             100
# Rating                5
# Title                38
# Review            15499
# dtype: int64

# %% [markdown]
# **iOS**
# - Platform: irrelevant, drop
# - Country: Only US, drop
# - Date: as string convert to datetime object
# - App ID: irrelevant, drop
# - App Name: Amazon Kindle iOS, drop
# - Publisher ID: irrelevant, drop
# - Publisher Name: irrelevant, drop
# - User all missing: drop
# - Version: keep
# - Rating: keep
# - Title: keep
# - Review: keep
#
# **Android**
# - Platform: irrelevant, drop
# - Language: only english, drop
# - Date: as string convert to datetime object
# - App ID: irrelevant, drop
# - App Name: irrelevant, drop
# - Publisher: irrelevant, drop
# - Publisher: irrelevant, drop
# - User: all missing, drop
# - Version: keep
# - Rating: keep
# - Title: very small fraction has non missing values, drop
# - Review: keep

# %%
# data cleaning
# drop
ios_drops = ["Platform","Country","App ID","App Name","Publisher ID","Publisher Name","User"]
android_drops = ["Platform","Language","App ID","App Name","Publisher ID","Publisher Name","User","Title"]
for i in ios_drops:
    df_as_kindle_05_18_05_19 = df_as_kindle_05_18_05_19.drop(columns = i, axis = 1, errors = "ignore")

for i in android_drops:
    df_gp_kindle_05_18_05_19 = df_gp_kindle_05_18_05_19.drop(columns = i, axis = 1, errors = "ignore")

# string to datetime
df_as_kindle_05_18_05_19['Date'] = pd.to_datetime(df_as_kindle_05_18_05_19['Date'])
df_gp_kindle_05_18_05_19['Date'] = pd.to_datetime(df_gp_kindle_05_18_05_19['Date'])

# add week and month level
def time_window(df):
    time_windows = ["year","month","week", "day", "dow"]
    for i in time_windows:
        if i == "year":
            df[i] = df["Date"].dt.year
        elif i == "month":
            df[i] = df["Date"].dt.month
        elif i == "week":
            df[i] = df["Date"].dt.week
        elif i == "day":
            df[i] = df["Date"].dt.day
        else:
            df[i] = df["Date"].dt.dayofweek

#time_window(df_as_kindle_05_18_05_19)
df_as_kindle_05_18_05_19.pipe(time_window)
df_gp_kindle_05_18_05_19.pipe(time_window)
#time_window(df_gp_kindle_05_18_05_19)

# week start and month start
# date to index
df_as_kindle_05_18_05_19.set_index("Date", inplace = True)
df_gp_kindle_05_18_05_19.set_index("Date", inplace = True)

df_as_kindle_05_18_05_19['week_start'] = df_as_kindle_05_18_05_19.index.to_period('W').start_time
df_as_kindle_05_18_05_19['month_start'] = df_as_kindle_05_18_05_19.index.to_period('M').start_time

df_gp_kindle_05_18_05_19['week_start'] = df_gp_kindle_05_18_05_19.index.to_period('W').start_time
df_gp_kindle_05_18_05_19['month_start'] = df_gp_kindle_05_18_05_19.index.to_period('M').start_time

# Day of week mapping change
dow_dict = {0:"Mon",1:"Tue",2:"Wed",3:"Thu",4:"Fri",5:"Sat",6:"Sun"}
df_as_kindle_05_18_05_19.replace({"dow": dow_dict}, inplace = True)
df_gp_kindle_05_18_05_19.replace({"dow": dow_dict}, inplace = True)

#dropping records without review texts
df_as_kindle_05_18_05_19.dropna(subset = ['Review'],inplace=True)
df_gp_kindle_05_18_05_19.dropna(subset = ['Review'],inplace=True)

# %%
df_as_kindle_05_18_05_19.head()
# Out:
#            Version  Rating                                         Title  \
# Date
# 2019-05-31    6.19       2                      Not user friendly at all
# 2019-05-31    6.19       5                                        Kindle
# 2019-05-31    6.19       1                            Crashes every time
# 2019-05-31    6.19       3                                         Books
# 2019-05-31    6.19       5  Maybe because it’s only a few apps out there
#
#                                                        Review  year  month  \
# Date
# 2019-05-31  As I sometimes leave my Kindle at home by mist...  2019      5
# 2019-05-31  So convenient and fun to buy and read on my ki...  2019      5
# 2019-05-31  I love Kindle and use it every day on my iPad....  2019      5
# 2019-05-31  Great app, but I'd like to be able to remove b...  2019      5
# 2019-05-31  I have 2k books in my kindle at my disposal. H...  2019      5
#
#             week  day  dow week_start month_start
# Date
# 2019-05-31    22   31  Fri 2019-05-27  2019-05-01
# 2019-05-31    22   31  Fri 2019-05-27  2019-05-01
# 2019-05-31    22   31  Fri 2019-05-27  2019-05-01
# 2019-05-31    22   31  Fri 2019-05-27  2019-05-01
# 2019-05-31    22   31  Fri 2019-05-27  2019-05-01

# %%
class Solution(object):
    def twoSum(self, nums, target):
        d = {}
        for i, n in enumerate(nums):
            m = target - n
            if m in d:
                return [d[m], i]
            else:
                d[n] = i

# %%
nums = [2, 7, 11, 15]
target = 9

Solution.twoSum(_,nums, target)
# Out:
# [0, 1]

# %%
for i, j in enumerate(nums):
    print(str(i),",",str(j))
# Out:
# 0 , 2
# 1 , 7
# 2 , 11
# 3 , 15

# %% [markdown]
# ### Review Trends ###

# %% [markdown]
# #### iOS ####

# %%
#Daily
ios_daily_rating = pd.DataFrame(df_as_kindle_05_18_05_19.groupby("Date").mean()["Rating"]).reset_index()
ios_daily_rating["Rating_with_Review"] = ios_daily_rating["Rating"].apply(lambda x: round(x,2))

android_daily_rating = pd.DataFrame(df_gp_kindle_05_18_05_19.groupby("Date").mean()["Rating"]).reset_index()
android_daily_rating["Rating_with_Review"] = android_daily_rating["Rating"].apply(lambda x: round(x,2))

#Weekly
ios_weekly_rating = pd.DataFrame(df_as_kindle_05_18_05_19.groupby("week_start").mean()["Rating"]).reset_index()
ios_weekly_rating["Rating_with_Review"] = ios_weekly_rating["Rating"].apply(lambda x: round(x,2))

android_weekly_rating = pd.DataFrame(df_gp_kindle_05_18_05_19.groupby("week_start").mean()["Rating"]).reset_index()
android_weekly_rating["Rating_with_Review"] = android_weekly_rating["Rating"].apply(lambda x: round(x,2))

#Monthly
ios_monthly_rating = pd.DataFrame(df_as_kindle_05_18_05_19.groupby("month_start").mean()["Rating"]).reset_index()
ios_monthly_rating["Rating_with_Review"] = ios_monthly_rating["Rating"].apply(lambda x: round(x,2))

android_monthly_rating = pd.DataFrame(df_gp_kindle_05_18_05_19.groupby("month_start").mean()["Rating"]).reset_index()
android_monthly_rating["Rating_with_Review"] = android_monthly_rating["Rating"].apply(lambda x: round(x,2))

# %%
# daily trend
trace_ios = go.Scatter(
                x=ios_daily_rating.Date,
                y=ios_daily_rating["Rating_with_Review"],
                name = "iOS Rating(with review)",
                line = dict(color = '#17BECF'),
                opacity = 0.5)

trace_android = go.Scatter(
                x=android_daily_rating.Date,
                y=android_daily_rating["Rating_with_Review"],
                name = "android Rating(with review)",
                line = dict(color = '#7F7F7F'),
                opacity = 0.7)

data = [trace_ios,trace_android]

layout = dict(
    title = "iOS and Android daily avg rating (with review texts)", #US for iOS, English for Android
    xaxis = dict(
        range = ['2018-06-11','2019-05-31'])
)

fig = dict(data=data, layout=layout)
py.iplot(fig, filename = "Manually Set Range")
# Out:
# <div>
#
#
#             <div id="ef720d45-4b9d-4493-85ae-bad81fd6eecb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ef720d45-4b9d-4493-85ae-bad81fd6eecb")) {
#                     Plotly.newPlot(
#                         'ef720d45-4b9d-4493-85ae-bad81fd6eecb',
#                         [{"line": {"color": "#17BECF"}, "name": "iOS Rating(with review)", "opacity": 0.5, "type": "scatter", "uid": "36183352-980f-466c-a769-1460dec48d28", "x": ["2018-05-01", "2018-05-02", "2018-05-03", "2018-05-04", "2018-05-05", "2018-05-06", "2018-05-07", "2018-05-08", "2018-05-09", "2018-05-10", "2018-05-11", "2018-05-12", "2018-05-13", "2018-05-14", "2018-05-15", "2018-05-16", "2018-05-17", "2018-05-18", "2018-05-19", "2018-05-20", "2018-05
-01-14", "2019-01-21", "2019-01-28", "2019-02-04", "2019-02-11", "2019-02-18", "2019-02-25", "2019-03-04", "2019-03-11", "2019-03-18", "2019-03-25", "2019-04-01", "2019-04-08", "2019-04-15", "2019-04-22", "2019-04-29", "2019-05-06", "2019-05-13", "2019-05-20", "2019-05-27"], "y": [3.84, 3.99, 4.03, 3.82, 4.11, 3.99, 3.96, 3.96, 3.89, 3.97, 3.79, 3.84, 3.98, 3.82, 3.91, 4.0, 3.88, 4.0, 4.02, 3.95, 3.82, 4.06, 4.02, 4.02, 4.17, 4.15, 3.99, 3.97, 3.97, 3.79, 4.01, 3.93, 3.99, 3.65, 3.68, 3.65, 3.8, 3.72, 3.57, 3.68, 3.83, 3.86, 3.71, 3.87, 3.74, 3.8, 3.56, 3.82, 3.78, 3.92, 3.77, 3.75, 3.79, 3.87, 3.79, 3.69, 3.94]}],
#                         {"title": {"text": "iOS and Android weekly avg rating (with review texts)"}, "xaxis": {"range": ["2018-06-11", "2019-05-31"]}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('66b0993d-5f05-4d3a-93af-099eb51c3b4e');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
# monthly trend
trace_ios = go.Scatter(
                x=ios_monthly_rating.month_start,
                y=ios_monthly_rating["Rating_with_Review"],
                name = "iOS Rating(with review)",
                line = dict(color = '#17BECF', width = 4),
                opacity = 0.8)

trace_android = go.Scatter(
                x=android_monthly_rating.month_start,
                y=android_monthly_rating["Rating_with_Review"],
                name = "android Rating(with review)",
                line = dict(color = '#7F7F7F', width = 4),
                opacity = 0.8)

data = [trace_ios,trace_android]

layout = dict(
    title = "iOS and Android monthly avg rating (with review texts)",
    xaxis = dict(
        range = ['2018-06-11','2019-05-31'])
)

fig = dict(data=data, layout=layout)
py.iplot(fig, filename = "Manually Set Range")
# Out:
# <div>
#
#
#             <div id="41333e7b-a29d-4690-9c7b-3cd5d9c08c3e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("41333e7b-a29d-4690-9c7b-3cd5d9c08c3e")) {
#                     Plotly.newPlot(
#                         '41333e7b-a29d-4690-9c7b-3cd5d9c08c3e',
#                         [{"line": {"color": "#17BECF", "width": 4}, "name": "iOS Rating(with review)", "opacity": 0.8, "type": "scatter", "uid": "2069845a-9fe9-4046-9d07-bc01eabf68f5", "x": ["2018-05-01", "2018-06-01", "2018-07-01", "2018-08-01", "2018-09-01", "2018-10-01", "2018-11-01", "2018-12-01", "2019-01-01", "2019-02-01", "2019-03-01", "2019-04-01", "2019-05-01"], "y": [2.6, 4.73, 4.76, 4.39, 4.3, 4.21, 3.99, 4.05, 4.0, 4.04, 4.0, 4.03, 3.93]}, {"line": {"color": "#7F7F7F", "width": 4}, "name": "android Rating(with review)", "opacity": 0.8, "type": "scatter", "uid": "b679b20e-8f71-4a7e-90f7-477803395d1a", "x": ["2018-05-01", "2018-06-01", "2018-07-01", "2018-08-01", "2018-09-01", "2018-10-01", "2018-11-01", "2018-12-01", "2019-01-01", "2019-02-01", "2019-03-01", "2019-04-01", "2019-05-01"], "y": [3.93, 3.98, 3.89, 3.93, 3.98, 4.07, 3.95, 3.84, 3.71, 3.77, 3.76, 3.81, 3.81]}],
#                         {"title": {"text": "iOS and Android monthly avg rating (with review texts)"}, "xaxis": {"range": ["2018-06-11", "2019-05-31"]}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('41333e7b-a29d-4690-9c7b-3cd5d9c08c3e');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
#Dow
ios = pd.DataFrame(df_as_kindle_05_18_05_19.groupby("dow").mean()["Rating"]).reset_index()
ios["Rating_with_Review"] = ios["Rating"].apply(lambda x: round(x,2))
android = pd.DataFrame(df_gp_kindle_05_18_05_19.groupby("dow").mean()["Rating"]).reset_index()
android["Rating_with_Review"] = android["Rating"].apply(lambda x: round(x,2))
merged = ios.merge(android, on = "dow", suffixes = ("_ios","_andorid") )
merged.drop(["Rating_ios","Rating_andorid"],axis=1,inplace=True)
merged["diff"] = (merged["Rating_with_Review_ios"] - merged["Rating_with_Review_andorid"]) / merged["Rating_with_Review_ios"] * 100
merged.sort_values("diff",ascending=False)
# Out:
#    dow  Rating_with_Review_ios  Rating_with_Review_andorid       diff
# 6  Wed                    4.64                        3.82  17.672414
# 4  Thu                    4.56                        3.84  15.789474
# 0  Fri                    4.58                        3.91  14.628821
# 2  Sat                    4.55                        3.93  13.626374
# 3  Sun                    4.44                        3.90  12.162162
# 1  Mon                    4.35                        3.84  11.724138
# 5  Tue                    4.34                        3.89  10.368664

# %% [markdown]
# Word Bagging

# %%
import re
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk import FreqDist
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\YC\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\YC\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#Define stopwords
sw = stopwords.words('english')
addition = ["a","kindle","at","it","there","and","to","s","would","e","x","k","n","r"] #adding more
for i in range(len(addition)):
    sw.append(addition[i])

# %%
#Preserve Review for vader

#for sentiment shifts

#remove non alphabets
df_as_kindle_05_18_05_19["Review1"] = df_as_kindle_05_18_05_19['Review'].replace(to_replace="[^A-Za-z]", value=r" ", regex=True)
df_gp_kindle_05_18_05_19["Review1"] = df_gp_kindle_05_18_05_19['Review'].replace(to_replace="[^A-Za-z]", value=r" ", regex=True)

#convert to lowercase
df_as_kindle_05_18_05_19["Review1"] = df_as_kindle_05_18_05_19["Review1"].str.lower()
df_gp_kindle_05_18_05_19["Review1"] = df_gp_kindle_05_18_05_19["Review1"].str.lower()

# %%
#tokenize
#1st iteration including all with similar words(sync, syncs, syncing, etc.) to get all frequency. Need to tokenize again after cleaning
df_as_kindle_05_18_05_19['Review1_tok'] = df_as_kindle_05_18_05_19['Review1'].apply(word_tokenize)
df_gp_kindle_05_18_05_19['Review1_tok'] = df_gp_kindle_05_18_05_19['Review1'].apply(word_tokenize)

# %%
#hand pick review words
#get frequency of words

#ios

pd.options.display.max_rows = 10000
pd.options.display.max_columns = 10000

txt = df_as_kindle_05_18_05_19["Review1"].str.lower().str.replace(r'\|', ' ').str.cat(sep=' ')
words = nltk.tokenize.word_tokenize(txt)
word_dist = nltk.FreqDist(words)

top_N = 10000

words_except_stop_dist = nltk.FreqDist(w for w in words if w not in sw) 

# print('iOS All frequencies, including STOPWORDS:')
# print('=' * 60)
# rslt_ios = pd.DataFrame(word_dist.most_common(top_N),
#                     columns=['Word', 'Frequency'])
# print(rslt)
# print('=' * 60)

rslt_ios = pd.DataFrame(words_except_stop_dist.most_common(top_N),columns=['Word', 'Frequency']).set_index('Word')

#path = r'C:/Users/YC/portfolio/case_study/kindle_app_reviews/'
#rslt_ios.to_csv(os.path.join(path,r'_ios_word_freq.csv'))

# %%
rslt_ios_re = rslt_ios.reset_index()
print(rslt_ios_re[rslt_ios_re["Word"] == "crash"])
print(rslt_ios_re[rslt_ios_re["Word"] == "crashes"])
# Out:
#       Word  Frequency
# 365  crash        143
# Empty DataFrame
# Columns: [Word, Frequency]
# Index: []

# %%
rslt_android_re = rslt_android.reset_index()
print(rslt_android_re[rslt_android_re["Word"] == "notification"])
print(rslt_android_re[rslt_android_re["Word"] == "notification"])
# Out:
#              Word  Frequency
# 325  notification         59
#              Word  Frequency
# 325  notification         59

# %%
#top words by frequency
print('iOS All frequencies, excluding STOPWORDS:')
print('=' * 60)
print(rslt_ios)
# Out:
# iOS All frequencies, excluding STOPWORDS:
# ============================================================
#                                                     Frequency
# Word
# books                                                   10696
# app                                                     10487
# read                                                     8285
# love                                                     7859
# book                                                     6445
# reading                                                  5153
# use                                                      3298
# great                                                    2852
# like                                                     2829
# ipad                                                     2511
# easy                                                     2479
# one                                                      2192
# library                                                  1948
# time                                                     1915
# go                                                       1825
# amazon                                                   1802
# able                                                     1673
# phone                                                    1672
# get                                                      1655
# always                                                   1622
# without                                                  1481
# many                                                     1414
# way                                                      1404
# also                                                     1365
# want                                                     1321
# much                                                     1314
# iphone                                                   1292
# using                                                    1170
# best                                                     1158
# new                                                      1157
# never                                                    1157
# years                                                    1148
# page                                                     1148
# enjoy                                                    1136
# could                                                    1124
# really                                                   1121
# reader                                                   1074
# good                                                     1072
# devices                                                  1048
# device                                                   1023
# find                                                     1020
# buy                                                      1009
# well                                                     1009
# every                                                     965
# even                                                      894
# back                                                      876
# download                                                  860
# used                                                      859
# wish                                                      857
# take                                                      827
# better                                                    801
# makes                                                     795
# unlimited                                                 756
# need                                                      747
# make                                                      738
# day                                                       734
# works                                                     734
# still                                                     717
# anywhere                                                  714
# since                                                     712
# convenient                                                695
# purchase                                                  690
# carry                                                     679
# ever                                                      665
# free                                                      660
# keep                                                      658
# know                                                      652
# available                                                 633
# lot                                                       613
# thing                                                     612
# access                                                    607
# first                                                     589
# favorite                                                  580
# easier                                                    579
# see                                                       574
# ability                                                   562
# thank                                                     553
# feature                                                   542
# life                                                      535
# work                                                      532
# font                                                      500
# pages                                                     498
# size                                                      496
# story                                                     491
# hard                                                      489
# place                                                     482
# recommend                                                 475
# wherever                                                  469
# another                                                   466
# around                                                    466
# right                                                     459
# allows                                                    457
# paper                                                     455
# sync                                                      453
# wonderful                                                 451
# series                                                    440
# especially                                                439
# two                                                       436
# several                                                   434
# times                                                     433
# update                                                    430
# left                                                      428
# features                                                  425
# text                                                      424
# different                                                 423
# waiting                                                   421
# please                                                    411
# something                                                 411
# night                                                     410
# apple                                                     408
# authors                                                   407
# apps                                                      406
# easily                                                    404
# thanks                                                    403
# long                                                      403
# think                                                     398
# give                                                      396
# last                                                      394
# problem                                                   392
# screen                                                    392
# author                                                    392
# everything                                                391
# nice                                                      386
# look                                                      382
# option                                                    382
# light                                                     381
# open                                                      380
# put                                                       379
# amazing                                                   377
# home                                                      374
# change                                                    374
# awesome                                                   372
# sometimes                                                 368
# everywhere                                                364
# store                                                     363
# real                                                      357
# convenience                                               357
# getting                                                   356
# next                                                      355
# travel                                                    352
# ebooks                                                    345
# got                                                       339
# downloaded                                                338
# made                                                      335
# old                                                       331
# search                                                    331
# loved                                                     330
# absolutely                                                329
# fingertips                                                329
# going                                                     326
# avid                                                      326
# order                                                     323
# things                                                    322
# however                                                   321
# ease                                                      319
# little                                                    319
# version                                                   316
# keeps                                                     313
# fire                                                      308
# stars                                                     300
# perfect                                                   298
# longer                                                    298
# wait                                                      297
# say                                                       297
# user                                                      297
# enjoyed                                                   296
# daily                                                     296
# background                                                294
# highlight                                                 293
# print                                                     292
# notes                                                     291
# tablet                                                    290
# highly                                                    288
# options                                                   286
# already                                                   286
# let                                                       284
# etc                                                       283
# purchased                                                 283
# found                                                     281
# add                                                       276
# instead                                                   276
# almost                                                    276
# selection                                                 276
# hand                                                      274
# anytime                                                   274
# audible                                                   273
# experience                                                273
# people                                                    271
# words                                                     271
# actual                                                    269
# feel                                                      268
# choose                                                    268
# characters                                                267
# pick                                                      265
# list                                                      263
# live                                                      263
# thought                                                   263
# turn                                                      263
# word                                                      263
# excellent                                                 261
# happy                                                     258
# though                                                    258
# across                                                    258
# try                                                       257
# multiple                                                  257
# often                                                     255
# sure                                                      253
# delete                                                    253
# prefer                                                    250
# readers                                                   247
# problems                                                  247
# help                                                      245
# prime                                                     244
# eyes                                                      243
# enough                                                    243
# start                                                     240
# anything                                                  239
# ago                                                       239
# white                                                     239
# bought                                                    238
# us                                                        237
# far                                                       237
# matter                                                    236
# titles                                                    235
# fix                                                       234
# fact                                                      232
# sample                                                    231
# world                                                     231
# away                                                      231
# bed                                                       231
# dictionary                                                230
# simple                                                    229
# end                                                       224
# whenever                                                  223
# needs                                                     223
# issue                                                     217
# switch                                                    217
# plus                                                      217
# sort                                                      216
# least                                                     215
# collections                                               215
# come                                                      215
# space                                                     215
# done                                                      212
# part                                                      212
# syncs                                                     211
# review                                                    209
# lots                                                      209
# whole                                                     206
# must                                                      206
# audio                                                     205
# buying                                                    204
# hold                                                      204
# less                                                      203
# trying                                                    201
# nothing                                                   201
# color                                                     200
# title                                                     198
# ibooks                                                    198
# started                                                   197
# appreciate                                                197
# looking                                                   196
# traveling                                                 196
# friendly                                                  196
# adjust                                                    195
# issues                                                    195
# continue                                                  195
# either                                                    192
# ios                                                       191
# everyday                                                  191
# black                                                     188
# hundreds                                                  188
# tried                                                     187
# small                                                     187
# takes                                                     187
# scroll                                                    187
# husband                                                   186
# line                                                      186
# difficult                                                 186
# hands                                                     185
# big                                                       185
# actually                                                  183
# full                                                      183
# scrolling                                                 180
# listen                                                    180
# lost                                                      179
# large                                                     178
# allow                                                     177
# navigate                                                  177
# hours                                                     177
# within                                                    177
# account                                                   176
# show                                                      176
# along                                                     175
# ones                                                      175
# annoying                                                  174
# highlighting                                              174
# money                                                     174
# finish                                                    174
# physical                                                  174
# year                                                      174
# carrying                                                  173
# remember                                                  172
# three                                                     171
# room                                                      170
# content                                                   169
# worth                                                     169
# anyone                                                    169
# bring                                                     169
# written                                                   167
# yet                                                       167
# downloading                                               166
# click                                                     166
# entire                                                    166
# seems                                                     165
# turning                                                   165
# miss                                                      164
# return                                                    164
# hope                                                      163
# material                                                  163
# latest                                                    161
# truly                                                     161
# goes                                                      160
# may                                                       160
# reason                                                    160
# making                                                    160
# gives                                                     159
# otherwise                                                 159
# copy                                                      159
# simply                                                    158
# organize                                                  157
# number                                                    157
# else                                                      157
# handy                                                     157
# leave                                                     156
# updates                                                   155
# kindles                                                   155
# variety                                                   155
# family                                                    154
# collection                                                154
# dark                                                      154
# huge                                                      154
# possible                                                  152
# digital                                                   152
# anymore                                                   151
# ebook                                                     151
# maybe                                                     151
# fast                                                      150
# overall                                                   150
# load                                                      150
# android                                                   150
# complaint                                                 150
# computer                                                  150
# five                                                      149
# star                                                      149
# prices                                                    149
# fun                                                       148
# check                                                     148
# came                                                      148
# bit                                                       147
# frustrating                                               147
# quickly                                                   147
# heavy                                                     146
# definitely                                                146
# minutes                                                   145
# others                                                    144
# said                                                      144
# syncing                                                   144
# pretty                                                    144
# useful                                                    143
# brightness                                                143
# given                                                     142
# whatever                                                  142
# close                                                     142
# constantly                                                142
# changed                                                   142
# hate                                                      141
# function                                                  141
# taking                                                    141
# helpful                                                   141
# purchases                                                 141
# week                                                      140
# fantastic                                                 140
# usually                                                   140
# pleasure                                                  139
# directly                                                  139
# might                                                     138
# touch                                                     138
# helps                                                     138
# quite                                                     137
# immediately                                               137
# past                                                      137
# type                                                      137
# choice                                                    136
# choices                                                   136
# price                                                     136
# enjoyable                                                 136
# top                                                       136
# format                                                    136
# probably                                                  135
# days                                                      135
# current                                                   134
# recently                                                  133
# second                                                    133
# reads                                                     132
# wanted                                                    131
# samples                                                   131
# track                                                     130
# service                                                   130
# move                                                      130
# cover                                                     130
# gets                                                      129
# couple                                                    129
# needed                                                    127
# recent                                                    127
# set                                                       126
# chapter                                                   125
# holding                                                   125
# took                                                      124
# whether                                                   123
# working                                                   123
# finally                                                   123
# stories                                                   122
# month                                                     122
# cost                                                      122
# support                                                   122
# friends                                                   122
# someone                                                   121
# house                                                     121
# novels                                                    121
# automatically                                             121
# completely                                                121
# share                                                     121
# together                                                  120
# location                                                  118
# stop                                                      118
# imagine                                                   118
# nook                                                      118
# electronic                                                117
# finding                                                   116
# pay                                                       116
# writing                                                   116
# wrong                                                     115
# super                                                     115
# added                                                     115
# lets                                                      115
# quick                                                     115
# fonts                                                     114
# via                                                       114
# view                                                      114
# magazines                                                 114
# single                                                    113
# become                                                    113
# mind                                                      113
# paperwhite                                                113
# comes                                                     112
# separate                                                  112
# fine                                                      112
# thousands                                                 112
# understand                                                111
# later                                                     111
# finished                                                  111
# bad                                                       110
# character                                                 110
# highlights                                                110
# genre                                                     109
# ready                                                     109
# write                                                     109
# rather                                                    109
# job                                                       108
# gave                                                      108
# purchasing                                                107
# save                                                      106
# except                                                    105
# pocket                                                    105
# missing                                                   105
# finger                                                    105
# lighting                                                  105
# slow                                                      104
# interesting                                               103
# tell                                                      103
# course                                                    103
# figure                                                    102
# tap                                                       102
# weight                                                    102
# updated                                                   102
# borrow                                                    102
# remove                                                    101
# seem                                                      101
# downloads                                                 101
# literally                                                 101
# everyone                                                  101
# sleep                                                     101
# personal                                                  101
# glad                                                      100
# person                                                    100
# yes                                                       100
# rating                                                    100
# says                                                      100
# important                                                 100
# application                                               100
# worry                                                     100
# fan                                                       100
# kept                                                       99
# colors                                                     99
# numbers                                                    99
# totally                                                    98
# friend                                                     98
# cloud                                                      98
# true                                                       97
# means                                                      97
# online                                                     97
# pro                                                        96
# main                                                       96
# provides                                                   96
# soon                                                       96
# fiction                                                    96
# older                                                      95
# low                                                        95
# note                                                       95
# settings                                                   95
# reviews                                                    94
# ways                                                       93
# liked                                                      93
# reference                                                  93
# forward                                                    92
# kind                                                       92
# wife                                                       92
# kids                                                       92
# although                                                   92
# trouble                                                    91
# mode                                                       91
# website                                                    91
# extremely                                                  90
# school                                                     90
# button                                                     90
# product                                                    89
# extra                                                      89
# send                                                       89
# saves                                                      89
# mini                                                       88
# mark                                                       88
# paperback                                                  88
# car                                                        88
# rate                                                       87
# laptop                                                     87
# spend                                                      87
# name                                                       87
# tool                                                       87
# definition                                                 87
# various                                                    86
# office                                                     86
# due                                                        86
# regular                                                    86
# original                                                   85
# romance                                                    85
# offers                                                     85
# larger                                                     85
# forth                                                      84
# purse                                                      84
# local                                                      83
# enjoying                                                   83
# goodreads                                                  82
# beginning                                                  82
# internet                                                   82
# listening                                                  82
# short                                                      82
# searching                                                  82
# categories                                                 82
# printed                                                    82
# places                                                     81
# lose                                                       81
# currently                                                  81
# recommended                                                81
# somewhere                                                  81
# interface                                                  81
# site                                                       81
# four                                                       80
# program                                                    80
# u                                                          79
# information                                                79
# public                                                     79
# mostly                                                     79
# battery                                                    79
# fixed                                                      79
# unread                                                     79
# point                                                      79
# ap                                                         79
# went                                                       78
# instantly                                                  78
# ipads                                                      78
# smell                                                      77
# reread                                                     77
# stuff                                                      77
# run                                                        77
# bright                                                     77
# certain                                                    77
# voracious                                                  77
# months                                                     76
# pain                                                       76
# functionality                                              76
# system                                                     76
# novel                                                      76
# stuck                                                      76
# customer                                                   76
# learn                                                      76
# improvement                                                76
# favorites                                                  75
# discovered                                                 75
# accessible                                                 75
# select                                                     75
# intuitive                                                  75
# genres                                                     75
# gift                                                       75
# future                                                     75
# shows                                                      74
# limited                                                    74
# setting                                                    74
# moment                                                     74
# idea                                                       74
# process                                                    74
# continuous                                                 74
# addition                                                   74
# improvements                                               74
# forget                                                     74
# trips                                                      74
# users                                                      73
# joy                                                        73
# ok                                                         73
# eye                                                        73
# including                                                  73
# disappointed                                               73
# deal                                                       73
# selections                                                 73
# crashes                                                    72
# technology                                                 72
# previous                                                   72
# worked                                                     72
# control                                                    72
# pull                                                       72
# subscription                                               71
# history                                                    71
# side                                                       71
# amount                                                     71
# section                                                    71
# seamlessly                                                 71
# pad                                                        70
# bottom                                                     70
# bookmark                                                   70
# bookmarks                                                  70
# storage                                                    70
# unable                                                     70
# offered                                                    70
# member                                                     69
# date                                                       69
# passages                                                   69
# happen                                                     69
# folders                                                    69
# non                                                        69
# documents                                                  69
# hooked                                                     68
# interest                                                   68
# paperbacks                                                 68
# stopped                                                    67
# organized                                                  67
# follow                                                     67
# complete                                                   67
# rarely                                                     67
# improve                                                    67
# trip                                                       67
# versions                                                   67
# vacation                                                   67
# complaints                                                 66
# expensive                                                  66
# research                                                   66
# allowed                                                    66
# became                                                     66
# spot                                                       66
# reliable                                                   66
# instant                                                    66
# deleted                                                    65
# saved                                                      65
# middle                                                     65
# web                                                        65
# sitting                                                    65
# cheaper                                                    65
# portable                                                   65
# impossible                                                 65
# browser                                                    65
# quality                                                    65
# example                                                    65
# email                                                      64
# changing                                                   64
# offer                                                      64
# play                                                       64
# clear                                                      63
# stay                                                       63
# turns                                                      63
# changes                                                    63
# study                                                      63
# onto                                                       63
# based                                                      63
# losing                                                     63
# unless                                                     62
# mobile                                                     62
# definitions                                                62
# pdf                                                        62
pd.options.display.max_rows = 10000
pd.options.display.max_columns = 10000

txt = df_gp_kindle_05_18_05_19["Review1"].str.lower().str.replace(r'\|', ' ').str.cat(sep=' ')
words = nltk.tokenize.word_tokenize(txt)
word_dist = nltk.FreqDist(words)

top_N = 10000

words_except_stop_dist = nltk.FreqDist(w for w in words if w not in sw) 

# print('Android All frequencies, including STOPWORDS:')
# print('=' * 60)
# rslt_android = pd.DataFrame(word_dist.most_common(top_N),
#                     columns=['Word', 'Frequency'])
# print(rslt_android)
# print('=' * 60)

rslt_android = pd.DataFrame(words_except_stop_dist.most_common(top_N),
                    columns=['Word', 'Frequency']).set_index('Word')

#path = r'C:/Users/YC/portfolio/case_study/kindle_app_reviews/'
#rslt_android.to_csv(os.path.join(path,r'_android_word_freq.csv'))

# %%
#without stop words
print('Android All frequencies, excluding STOPWORDS:')
print('=' * 60)
print(rslt_android)
# Out:
# Android All frequencies, excluding STOPWORDS:
# ============================================================
#                                                     Frequency
# Word
# app                                                      7388
# books                                                    3427
# good                                                     3177
# love                                                     2546
# read                                                     2046
# book                                                     1874
# nice                                                     1514
# reading                                                  1474
# great                                                    1474
# like                                                     1090
# amazon                                                    997
# use                                                       924
# download                                                  866
# best                                                      843
# phone                                                     819
# get                                                       726
# time                                                      707
# free                                                      615
# awesome                                                   604
# update                                                    597
# one                                                       580
# even                                                      554
# want                                                      531
# really                                                    510
# please                                                    509
# amazing                                                   495
# library                                                   430
# much                                                      426
# easy                                                      409
# go                                                        408
# new                                                       407
# page                                                      393
# open                                                      380
# work                                                      361
# way                                                       358
# bad                                                       356
# every                                                     345
# buy                                                       340
# excellent                                                 340
# many                                                      338
# back                                                      333
# ever                                                      326
# better                                                    321
# also                                                      321
# still                                                     320
# able                                                      315
# fix                                                       314
# keeps                                                     307
# need                                                      305
# android                                                   293
# used                                                      289
# thanks                                                    282
# tablet                                                    281
# find                                                      280
# device                                                    280
# ok                                                        278
# apps                                                      276
# useful                                                    276
# reader                                                    274
# using                                                     270
# without                                                   264
# store                                                     262
# let                                                       261
# could                                                     256
# screen                                                    256
# option                                                    255
# downloaded                                                252
# never                                                     252
# works                                                     250
# know                                                      248
# think                                                     238
# account                                                   233
# well                                                      231
# u                                                         230
# unlimited                                                 226
# see                                                       225
# access                                                    221
# problem                                                   221
# try                                                       216
# working                                                   216
# give                                                      216
# keep                                                      212
# always                                                    210
# since                                                     210
# last                                                      209
# make                                                      208
# add                                                       204
# available                                                 202
# version                                                   199
# lot                                                       199
# worst                                                     195
# uninstall                                                 194
# wish                                                      194
# help                                                      194
# hate                                                      192
# sync                                                      192
# devices                                                   191
# thank                                                     190
# super                                                     188
# money                                                     187
# loved                                                     181
# feature                                                   176
# stars                                                     176
# change                                                    175
# experience                                                175
# text                                                      174
# prime                                                     173
# tried                                                     169
# pages                                                     168
# years                                                     166
# google                                                    166
# downloading                                               165
# cool                                                      162
# got                                                       158
# install                                                   157
# times                                                     157
# nothing                                                   156
# everything                                                152
# dont                                                      148
# card                                                      146
# going                                                     145
# purchased                                                 145
# anything                                                  144
# helpful                                                   143
# readers                                                   142
# waste                                                     141
# crashes                                                   141
# anywhere                                                  141
# makes                                                     140
# wonderful                                                 139
# bought                                                    137
# thing                                                     137
# day                                                       137
# cant                                                      137
# enjoy                                                     135
# take                                                      133
# us                                                        133
# people                                                    132
# fine                                                      132
# issue                                                     132
# pay                                                       131
# delete                                                    130
# getting                                                   129
# annoying                                                  128
# application                                               127
# play                                                      127
# trying                                                    126
# search                                                    125
# happy                                                     124
# purchase                                                  124
# already                                                   122
# dictionary                                                122
# needs                                                     121
# ebooks                                                    121
# right                                                     120
# useless                                                   120
# unable                                                    119
# crashing                                                  117
# first                                                     116
# samsung                                                   116
# latest                                                    115
# something                                                 114
# space                                                     114
# ebook                                                     114
# user                                                      112
# issues                                                    110
# though                                                    110
# home                                                      110
# perfect                                                   109
# reinstall                                                 109
# says                                                      108
# uninstalled                                               108
# made                                                      107
# service                                                   107
# mode                                                      106
# longer                                                    106
# sign                                                      105
# full                                                      104
# aap                                                       102
# load                                                      102
# sucks                                                     102
# must                                                      102
# frustrating                                               102
# superb                                                    101
# different                                                 101
# night                                                     101
# content                                                   101
# absolutely                                                101
# far                                                       101
# yet                                                       100
# fantastic                                                  99
# old                                                        99
# sure                                                       98
# things                                                     98
# turn                                                       98
# installed                                                  96
# say                                                        96
# password                                                   95
# problems                                                   95
# remove                                                     95
# click                                                      94
# instead                                                    93
# long                                                       93
# star                                                       93
# wow                                                        92
# slow                                                       91
# takes                                                      91
# audible                                                    90
# hard                                                       90
# audio                                                      90
# another                                                    90
# stop                                                       89
# data                                                       89
# features                                                   89
# language                                                   89
# favorite                                                   89
# reason                                                     88
# ads                                                        88
# word                                                       88
# allow                                                      88
# recommend                                                  87
# updates                                                    87
# list                                                       87
# error                                                      86
# show                                                       86
# stopped                                                    86
# start                                                      86
# font                                                       85
# opening                                                    84
# customer                                                   84
# sd                                                         84
# galaxy                                                     83
# world                                                      82
# mobile                                                     82
# constantly                                                 82
# im                                                         82
# updated                                                    81
# options                                                    81
# done                                                       79
# knowledge                                                  78
# seems                                                      78
# look                                                       77
# put                                                        77
# button                                                     77
# etc                                                        77
# convenient                                                 76
# stories                                                    76
# words                                                      75
# enough                                                     75
# choose                                                     75
# support                                                    75
# ability                                                    75
# settings                                                   74
# paid                                                       74
# sometimes                                                  74
# several                                                    74
# collection                                                 73
# scrolling                                                  73
# life                                                       73
# review                                                     73
# actually                                                   73
# friendly                                                   73
# days                                                       72
# found                                                      72
# stupid                                                     72
# wont                                                       72
# started                                                    71
# helps                                                      71
# log                                                        71
# place                                                      71
# tell                                                       70
# whole                                                      70
# fixed                                                      70
# kids                                                       69
# worked                                                     69
# interesting                                                69
# easily                                                     69
# scroll                                                     69
# two                                                        68
# left                                                       68
# hope                                                       68
# brightness                                                 67
# lots                                                       67
# note                                                       67
# l                                                          67
# pretty                                                     67
# soon                                                       67
# around                                                     66
# everyone                                                   66
# speech                                                     66
# lost                                                       66
# anymore                                                    65
# learn                                                      65
# completely                                                 65
# fire                                                       65
# simply                                                     65
# english                                                    65
# wanted                                                     65
# come                                                       65
# often                                                      65
# number                                                     64
# buying                                                     64
# poor                                                       64
# gets                                                       64
# months                                                     64
# children                                                   64
# lovers                                                     64
# horrible                                                   64
# easier                                                     63
# size                                                       63
# authors                                                    63
# almost                                                     62
# goes                                                       62
# sample                                                     62
# real                                                       61
# interface                                                  61
# saying                                                     61
# study                                                      61
# next                                                       60
# especially                                                 60
# looking                                                    60
# liked                                                      60
# anytime                                                    60
# month                                                      60
# set                                                        59
# notification                                               59
# least                                                      59
# background                                                 59
# said                                                       59
# little                                                     58
# close                                                      58
# selection                                                  58
# carry                                                      58
# showing                                                    58
# difficult                                                  58
# learning                                                   58
# taking                                                     57
# message                                                    57
# subscription                                               57
# stuck                                                      57
# email                                                      57
# function                                                   57
# otherwise                                                  56
# properly                                                   56
# huge                                                       56
# feel                                                       56
# else                                                       55
# guys                                                       55
# samples                                                    55
# terrible                                                   55
# however                                                    55
# g                                                          55
# freezes                                                    55
# stuff                                                      55
# recently                                                   55
# students                                                   55
# storage                                                    55
# less                                                       55
# send                                                       55
# notes                                                      55
# allows                                                     55
# job                                                        54
# shows                                                      54
# kind                                                       54
# big                                                        54
# pdf                                                        54
# away                                                       54
# internet                                                   54
# okay                                                       53
# impossible                                                 53
# wrong                                                      53
# deleted                                                    53
# everytime                                                  53
# view                                                       53
# making                                                     53
# multiple                                                   53
# hi                                                         53
# recent                                                     52
# totally                                                    52
# automatically                                              52
# thought                                                    52
# gone                                                       52
# black                                                      52
# rating                                                     52
# notifications                                              52
# save                                                       51
# gives                                                      51
# plus                                                       51
# later                                                      51
# story                                                      50
# worth                                                      50
# login                                                      50
# reinstalled                                                50
# loading                                                    50
# sort                                                       49
# tab                                                        49
# hours                                                      49
# couple                                                     49
# possible                                                   49
# order                                                      49
# collections                                                49
# whenever                                                   49
# finally                                                    49
# downloads                                                  48
# given                                                      48
# color                                                      48
# fun                                                        48
# changed                                                    48
# overall                                                    48
# quite                                                      48
# return                                                     48
# missing                                                    48
# simple                                                     48
# location                                                   48
# improve                                                    47
# top                                                        47
# setting                                                    46
# worse                                                      46
# live                                                       46
# brilliant                                                  46
# online                                                     46
# year                                                       46
# understand                                                 46
# uninstalling                                               46
# single                                                     46
# price                                                      45
# needed                                                     45
# choice                                                     45
# previous                                                   45
# highlight                                                  45
# small                                                      45
# battery                                                    45
# ios                                                        45
# end                                                        45
# ago                                                        44
# provide                                                    44
# disappointed                                               44
# school                                                     44
# titles                                                     44
# leave                                                      44
# wifi                                                       43
# seen                                                       43
# p                                                          43
# files                                                      43
# point                                                      43
# prices                                                     43
# five                                                       43
# forever                                                    42
# plz                                                        42
# broken                                                     42
# listen                                                     42
# force                                                      42
# hindi                                                      42
# reviews                                                    42
# except                                                     42
# across                                                     42
# waiting                                                    41
# ask                                                        41
# today                                                      41
# write                                                      41
# type                                                       41
# switch                                                     41
# either                                                     41
# novels                                                     41
# de                                                         41
# landscape                                                  41
# added                                                      41
# white                                                      41
# dark                                                       41
# unless                                                     40
# part                                                       40
# syncing                                                    40
# menu                                                       40
# past                                                       40
# become                                                     40
# current                                                    40
# c                                                          40
# others                                                     40
# lovely                                                     40
# everywhere                                                 40
# offline                                                    39
# check                                                      39
# move                                                       39
# company                                                    39
# select                                                     39
# system                                                     39
# removed                                                    39
# yes                                                        39
# users                                                      39
# half                                                       39
# reset                                                      39
# fast                                                       39
# fact                                                       39
# light                                                      38
# via                                                        38
# bit                                                        38
# comics                                                     38
# week                                                       38
# trial                                                      38
# idea                                                       38
# v                                                          38
# highlights                                                 38
# trouble                                                    38
# rather                                                     38
# w                                                          38
# maybe                                                      38
# wait                                                       37
# took                                                       37
# gave                                                       37
# wishlist                                                   37
# minutes                                                    37
# reinstalling                                               37
# bug                                                        37
# h                                                          37
# continuous                                                 37
# information                                                36
# auto                                                       36
# matter                                                     36
# shopping                                                   36
# purchases                                                  36
# lol                                                        36
# prefer                                                     36
# pocket                                                     36
# syncs                                                      36
# pain                                                       36
# ones                                                       36
# unfortunately                                              36
# mb                                                         36
# turning                                                    36
# author                                                     36
# title                                                      36
# reads                                                      36
# installing                                                 35
# important                                                  35
# eyes                                                       35
# seem                                                       35
# icon                                                       35
# hai                                                        35
# unusable                                                   35
# boring                                                     35
# fabulous                                                   35
# awsome                                                     35
# happened                                                   35
# bookmarks                                                  35
# rate                                                       35
# series                                                     35
# anyone                                                     35
# handy                                                      35
# credit                                                     34
# might                                                      34
# favourite                                                  34
# giving                                                     34
# finish                                                     34
# whatever                                                   34
# definitely                                                 34
# went                                                       34
# touch                                                      34
# large                                                      34
# paper                                                      34
# pc                                                         34
# progress                                                   34
# low                                                        33
# crash                                                      33
# bar                                                        33
# quick                                                      33
# someone                                                    33
# nyc                                                        33
# may                                                        33
# garbage                                                    33
# phones                                                     33
# b                                                          33
# cost                                                       33
# format                                                     33
# paperwhite                                                 33
# carousel                                                   33
# digital                                                    33
# share                                                      33
# guess                                                      33
# fingertips                                                 33
# membership                                                 33
# fonts                                                      33
# na                                                         33
# bright                                                     32
# doesnt                                                     32
# mind                                                       32
# copy                                                       32
# genre                                                      32
# gud                                                        32
# pop                                                        32
# extremely                                                  32
# run                                                        32
# filter                                                     32
# portrait                                                   32
# connection                                                 32
# clear                                                      32
# f                                                          32
# payment                                                    32
# th                                                         32
# alot                                                       32
# lenovo                                                     32
# non                                                        31
# code                                                       31
# complete                                                   31
# cancel                                                     31
# interested                                                 31
# tablets                                                    31
# improved                                                   31
# website                                                    31
# game                                                       31
# none                                                       31
# recommendations                                            31
# rid                                                        31
# rubbish                                                    31
# bring                                                      31
# memory                                                     31
# weeks                                                      31
# navigate                                                   31
# tap                                                        31
# spend                                                      30
# irritating                                                 30
# beautiful                                                  30
# j                                                          30
# zoom                                                       30
# blank                                                      30
# currently                                                  30
# highly                                                     30
# asking                                                     30
# chapter                                                    30
# computer                                                   30
# enable                                                     30
# loving                                                     30
# enjoyed                                                    30
# amount                                                     30
# suggestions                                                29
# sorry                                                      29
# items                                                      29
# disabled                                                   29
# ridiculous                                                 29
# loads                                                      29
# novel                                                      29
# bugs                                                       29
# happens                                                    28
# redownload                                                 28
# restart                                                    28
# seriously                                                  28
# bookmark                                                   28
# que                                                        28
# remember                                                   28
# miss                                                       28
# means                                                      28
# lose                                                       28
# told                                                       28
# forced                                                     28
# request                                                    28
# opened                                                     28
# site                                                       28
# speed                                                      28
# frustrated                                                 28
# numbers                                                    28
# high                                                       27
# charged                                                    27
# limited                                                    27
# wherever                                                   27
# cause                                                      27
# running                                                    27
# ur                                                         27
# pro                                                        27
# per                                                        27
# hell                                                       27
# osm                                                        27
# correct                                                    27
# buggy                                                      27
# actual                                                     27
# name                                                       27
# process                                                    27
# family                                                     27
# refuses                                                    27
# hated                                                      27
# due                                                        27
# middle                                                     27
# paying                                                     27
# japanese                                                   27
# friend                                                     26
# came                                                       26
# spent                                                      26
# ui                                                         26
# hand                                                       26
# freezing                                                   26
# developers                                                 26
# member                                                     26
# telling                                                    26
# intuitive                                                  26
# turned                                                     26
# yeah                                                       26
# main                                                       26
# file                                                       25
# create                                                     25
# total                                                      25
# along                                                      25
# probably                                                   25
# updating                                                   25
# ive                                                        25
# manually                                                   25
# uses                                                       25
# looks                                                      25
# stops                                                      25
# pick                                                       25
# appear                                                     25
# lets                                                       25
# upgrade                                                    25
# although                                                   25
# onto                                                       25
# india                                                      25
# care                                                       25
# basic                                                      25
# class                                                      25
# closes                                                     25
# within                                                     25
# software                                                   25
# carrying                                                   25
# suddenly                                                   25
# line                                                       25
# oh                                                         25
# lately                                                     25
# changing                                                   25
# forward                                                    25
# improvement                                                24
# apparently                                                 24
# daily                                                      24
# comes                                                      24
# faster                                                     24
# bottom                                                     24
# section                                                    24
# lover                                                      24
# luv                                                        24
# disappeared                                                24
# supposed                                                   24
# browser                                                    24
# physical                                                   24
# avid                                                       24
# adds                                                       24
# literally                                                  24
# adding                                                     24
# info                                                       24
# randomly                                                   24
# forget                                                     24
# older                                                      24
# bakwas                                                     23
# deleting                                                   23
# debit                                                      23
# sell                                                       23
# music                                                      23
# program                                                    23
# wants                                                      23
# correctly                                                  23
# limit                                                      23
# previously                                                 23
# hassle                                                     23
# press                                                      23
# hundreds                                                   23
# outstanding                                                23
# flip                                                       23
# offer                                                      23
# accounts                                                   23
# date                                                       23
# refund                                                     23
# nook                                                       23
# nd                                                         22
# seconds                                                    22
# damn                                                       22
# ...
# baaaaaad                                                    1
# grsat                                                       1
# suppwr                                                      1
# ctrl                                                        1
# auideo                                                      1
# alll                                                        1
# freash                                                      1
# intressting                                                 1
# sycning                                                     1
# chatty                                                      1
# configuration                                               1
# configurable                                                1
# atification                                                 1
# patrica                                                     1
# cornwells                                                   1
# chand                                                       1
# fussy                                                       1
# racket                                                      1
# switcher                                                    1
# hotstar                                                     1
# horasious                                                   1
# cooollll                                                    1
# optimise                                                    1
# suppport                                                    1
# turner                                                      1
# simulation                                                  1
# llllllllllooollllllllllllllllllll                           1
# llf                                                         1
# jrs                                                         1
# depend                                                      1
# minimalistic                                                1
# aau                                                         1
# estuve                                                      1
# desinstal                                                   1
# datos                                                       1
# cobrado                                                     1
# dos                                                         1
# despu                                                       1
# avisarme                                                    1
# carg                                                        1
# ndolo                                                       1
# cuenta                                                      1
# dekhate                                                     1
# tires                                                       1
# jharna                                                      1
# sarkar                                                      1
# roshnipasi                                                  1
# payements                                                   1
# buts                                                        1
# summaries                                                   1
# favirete                                                    1
# relate                                                      1
# interests                                                   1
# questionable                                                1
# objectionable                                               1
# downright                                                   1
# displeasure                                                 1
# ccouldn                                                     1
# interact                                                    1
# explaining                                                  1
# puper                                                       1
# unpdate                                                     1
# butty                                                       1
# googles                                                     1
# brieeggs                                                    1
# ua                                                          1
# guyg                                                        1
# qfttey                                                      1
# pyler                                                       1
# gaaaa                                                       1
# rudy                                                        1
# rre                                                         1
# yeee                                                        1
# feet                                                        1
# bhhurt                                                      1
# euryeurya                                                   1
# sp                                                          1
# tqq                                                         1
# itu                                                         1
# fe                                                          1
# awee                                                        1
# tuyr                                                        1
# rehhhhhhhls                                                 1
# chr                                                         1
# trtrt                                                       1
# riederrrrt                                                  1
# err                                                         1
# vg                                                          1
# sethu                                                       1
# iski                                                        1
# chodo                                                       1
# jhaatu                                                      1
# chutiyapa                                                   1
# ra                                                          1
# bancho                                                      1
# caverns                                                     1
# recognized                                                  1
# intentionaly                                                1
# offending                                                   1
# abusive                                                     1
# groth                                                       1
# stuvk                                                       1
# copycat                                                     1
# disguise                                                    1
# xico                                                        1
# reminds                                                     1
# cassette                                                    1
# tape                                                        1
# wseetax                                                     1
# ow                                                          1
# whis                                                        1

# %%
#Group and normalize similar words (i.e. sync, syncs, syncing)

def manual_kw_normalizer(df):
    
    #sync
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[^r][s][y][n][c][a-z]*", value = r"sync", regex=True) #preserving whispersync
    #download
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[d][o][w][n][l][o][a][d][a-z]*", value = r"download", regex=True)
    #bookmark
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[b][o][o][k][m][a][r][k][a-z]*", value = r"bookmark", regex=True)
    #bug
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[b][u][g][a-z]*", value = r"bug", regex=True)
    #bookshelf
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[b][o][o][k][s][h][e][l][f][a-z]*", value = r"bookshelf", regex=True)
    #borrow
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[b][o][r][r][o][w][a-z]*", value = r"borrow", regex=True)
    #buy
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[b][u][y][a-z]*", value = r"buy", regex=True)
    #choice
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[c][h][o][i][c][e][a-z]*", value = r"choice", regex=True)
    #collection
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[c][o][l][l][e][c][t][i][o][n][a-z]*", value = r"collection", regex=True)
    #color
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[c][o][l][o][r][a-z]*", value = r"color", regex=True)
    #crash
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[c][r][a][s][h][a-z]*", value = r"crash", regex=True)
    #delete
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[d][e][l][e][t][e][a-z]*", value = r"delete", regex=True)
    #dictionary
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[d][i][c][t][i][o][n][a][r][y][a-z]*", value = r"dictionary", regex=True)
    #difficult
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[d][i][f][f][i][c][u][l][t][a-z]*", value = r"difficult", regex=True)
    #experience
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[e][x][p][e][r][i][e][n][c][e][a-z]*", value = r"experience", regex=True)
    #fast
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[f][a][s][t][a-z]*", value = r"fast", regex=True)
    #feature
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[f][e][a][t][u][r][e][a-z]*", value = r"feature", regex=True)
    #find
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[f][i][n][d][a-z]*", value = r"find", regex=True)
    #search
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[s][e][a][r][c][h][a-z]*", value = r"search", regex=True)
    #format
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[f][o][r][m][a][t][a-z]*", value = r"format", regex=True)
    #freeze
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[f][r][e][e][z][e][a-z]*", value = r"freeze", regex=True)
    #glitch
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[g][l][i][t][c][h][a-z]*", value = r"glitch", regex=True)
    #genre
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[g][e][n][r][e][a-z]*", value = r"genre", regex=True)
    #frustration
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[f][r][u][s][t][a-z]*", value = r"frustration", regex=True)
    #highlight
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[h][i][g][h][l][i][g][h][t][a-z]*", value = r"highlight", regex=True)
    #improvement
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[i][m][p][r][o][v][e][a-z]*", value = r"improve", regex=True)
    #library
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[l][i][b][r][a][r][a-z]*", value = r"library", regex=True)
    #notification
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[n][o][t][i][f][i][c][a][t][i][o][n][a-z]*", value = r"notification", regex=True)
    #organize
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[o][r][g][a][n][i][z][a-z]*", value = r"organize", regex=True)
    #pdf
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[p][d][f][a-z]*", value = r"pdf", regex=True)
    #purchase
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[p][u][r][c][h][a][s][a-z]*", value = r"purchase", regex=True)
    #recommendation
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[r][e][c][o][m][m][e][n][d][a][t][i][o][n][a-z]*", value = r"recommendation", regex=True)
    #sample
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[s][a][m][p][l][a-z]*", value = r"sample", regex=True)
    #scroll
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[s][c][r][o][l][l][a-z]*", value = r"scroll", regex=True)
    #suggestion
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[s][u][g][g][e][s][t][i][o][n][a-z]*", value = r"suggestion", regex=True)
    #update
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[u][p][d][a][t][e][a-z]*", value = r"update", regex=True)
    #uninstall
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[u][n][i][n][s][t][a][l][l][a-z]*", value = r"uninstall", regex=True)
    #install
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[i][n][s][t][a][l][l][a-z]*", value = r"install", regex=True)
    #disappear
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[d][i][s][a][p][p][e][a][r][a-z]*", value = r"disappear", regex=True)
    #function
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[f][u][n][c][t][i][o][n][a-z]*", value = r"function", regex=True)
   
    
df_as_kindle_05_18_05_19.pipe(manual_kw_normalizer)
df_gp_kindle_05_18_05_19.pipe(manual_kw_normalizer)

df_as_kindle_05_18_05_19['Review1_tok'] = df_as_kindle_05_18_05_19['Review1'].apply(word_tokenize)
df_gp_kindle_05_18_05_19['Review1_tok'] = df_gp_kindle_05_18_05_19['Review1'].apply(word_tokenize)

# %%
#Import manually picked keywords
ios_keywords = sorted(list(pd.read_csv(r"ios_keywords.csv").values.flatten()))
android_keywords = sorted(list(pd.read_csv(r"android_keywords.csv").values.flatten()))
combined_keywords = ios_keywords + android_keywords

# %%
#ios keywords to rating
keywords = []
Reviews = []
month_starts = []
Ratings = []
for _, row in df_as_kindle_05_18_05_19.iterrows():
    Review = row.Review1
    month_start = row.month_start
    Rating = row.Rating
    
    for keyword in row.Review1_tok:
        if keyword in ios_keywords:
            Reviews.append(Review)
            keywords.append(keyword)
            month_starts.append(month_start)
            Ratings.append(Rating)
        
as_kw_to_review = pd.DataFrame({
    "month_start": month_starts,
    "Review": Reviews,
    "keyword": keywords,
    "Rating": Ratings
})

# %%
#Android keywords to rating
keywords = []
Reviews = []
month_starts = []
Ratings = []
for _, row in df_gp_kindle_05_18_05_19.iterrows():
    Review = row.Review1
    month_start = row.month_start
    Rating = row.Rating
    
    for keyword in row.Review1_tok:
        if keyword in android_keywords:
            Reviews.append(Review)
            keywords.append(keyword)
            month_starts.append(month_start)
            Ratings.append(Rating)
        
gp_kw_to_review = pd.DataFrame({
    "month_start": month_starts,
    "Review": Reviews,
    "keyword": keywords,
    "Rating": Ratings
})

# %%
#Overall rating by keywords
ios_kw_rating = as_kw_to_review.groupby(["keyword","month_start"]).mean().reset_index().sort_values("Rating",ascending=False)
android_kw_rating = gp_kw_to_review.groupby(["keyword","month_start"]).mean().reset_index().sort_values("Rating",ascending=False)

# %%
#show change

kw = "sort"

as_kw_to_review_sub= ios_kw_rating[ios_kw_rating["keyword"] == kw].sort_values("month_start",ascending=False)
gp_kw_to_review_sub = android_kw_rating[android_kw_rating["keyword"] == kw].sort_values("month_start",ascending=False)

# monthly trend
trace_ios = go.Scatter(
                x=as_kw_to_review_sub.month_start,
                y=as_kw_to_review_sub["Rating"],
                name = "iOS Rating(with review)",
                line = dict(color = '#17BECF', width = 4),
                opacity = 0.8)

trace_android = go.Scatter(
                x=gp_kw_to_review_sub.month_start,
                y=gp_kw_to_review_sub["Rating"],
                name = "Android Rating(with review)",
                line = dict(color = '#7F7F7F', width = 4),
                opacity = 0.8)

data = [trace_ios,trace_android]

layout = dict(
    title = "keyword: " + kw + " " +"iOS and Android monthly avg rating (with review texts)",
    xaxis = dict(
        range = ['2018-06-11','2019-05-31']),
    yaxis = dict(range = [0,5])
)

fig = dict(data=data, layout=layout)
py.iplot(fig, filename = "Manually Set Range")
# Out:
# <div>
#
#
#             <div id="673c0563-853d-44db-9288-b4ea8c168d49" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("673c0563-853d-44db-9288-b4ea8c168d49")) {
#                     Plotly.newPlot(
#                         '673c0563-853d-44db-9288-b4ea8c168d49',
#                         [{"line": {"color": "#17BECF", "width": 4}, "name": "iOS Rating(with review)", "opacity": 0.8, "type": "scatter", "uid": "73ad68aa-7066-41b3-a865-5dead4a26e45", "x": ["2019-05-01", "2019-04-01", "2019-02-01", "2019-01-01", "2018-12-01", "2018-11-01", "2018-10-01", "2018-09-01", "2018-08-01", "2018-07-01", "2018-06-01", "2018-05-01"], "y": [3.5, 3.8, 1.0, 3.4, 4.333333333333333, 2.75, 3.727272727272727, 3.2222222222222223, 2.8181818181818183, 3.8360655737704916, 4.022988505747127, 3.0]}, {"line": {"color": "#7F7F7F", "width": 4}, "name": "Android Rating(with review)", "opacity": 0.8, "type": "scatter", "uid": "0890f0d2-6dc2-414e-82ed-59f48f98c41e", "x": ["2019-05-01", "2019-04-01", "2019-03-01", "2019-02-01", "2019-01-01", "2018-12-01", "2018-11-01", "2018-10-01", "2018-09-01", "2018-08-01", "2018-07-01", "2018-06-01", "2018-05-01"], "y": [2.5, 2.5, 3.0, 3.0, 2.25, 2.5, 4.0, 2.5, 2.3333333333333335, 2.3333333333333335, 3.0, 2.875, 3.0]}],
#                         {"title": {"text": "keyword: sort iOS and Android monthly avg rating (with review texts)"}, "xaxis": {"range": ["2018-06-11", "2019-05-31"]}, "yaxis": {"range": [0, 5]}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('673c0563-853d-44db-9288-b4ea8c168d49');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
#show change

kw = "library"

as_kw_to_review_sub= ios_kw_rating[ios_kw_rating["keyword"] == kw].sort_values("month_start",ascending=False)
gp_kw_to_review_sub = android_kw_rating[android_kw_rating["keyword"] == kw].sort_values("month_start",ascending=False)

# monthly trend
trace_ios = go.Scatter(
                x=as_kw_to_review_sub.month_start,
                y=as_kw_to_review_sub["Rating"],
                name = "iOS Rating(with review)",
                line = dict(color = '#17BECF', width = 4),
                opacity = 0.8)

trace_android = go.Scatter(
                x=gp_kw_to_review_sub.month_start,
                y=gp_kw_to_review_sub["Rating"],
                name = "Android Rating(with review)",
                line = dict(color = '#7F7F7F', width = 4),
                opacity = 0.8)

data = [trace_ios,trace_android]

layout = dict(
    title = "keyword: " + kw + " " +"iOS and Android monthly avg rating (with review texts)",
    xaxis = dict(
        range = ['2018-06-11','2019-05-31']),
    yaxis = dict(range = [0,5])
)

fig = dict(data=data, layout=layout)
py.iplot(fig, filename = "Manually Set Range")
# Out:
# <div>
#
#
#             <div id="6fb57daf-1711-4f85-8119-1c5231608f52" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("6fb57daf-1711-4f85-8119-1c5231608f52")) {
#                     Plotly.newPlot(
#                         '6fb57daf-1711-4f85-8119-1c5231608f52',
#                         [{"line": {"color": "#17BECF", "width": 4}, "name": "iOS Rating(with review)", "opacity": 0.8, "type": "scatter", "uid": "18c52c4a-ac96-4929-ab22-abe77a5ebc88", "x": ["2019-05-01", "2019-04-01", "2019-03-01", "2019-02-01", "2019-01-01", "2018-12-01", "2018-11-01", "2018-10-01", "2018-09-01", "2018-08-01", "2018-07-01", "2018-06-01", "2018-05-01"], "y": [3.4411764705882355, 3.3448275862068964, 3.823529411764706, 4.130434782608695, 3.46, 4.214285714285714, 4.017543859649122, 4.313432835820896, 4.27906976744186, 4.47191011235955, 4.690697674418605, 4.629084967320262, 2.875]}, {"line": {"color": "#7F7F7F", "width": 4}, "name": "Android Rating(with review)", "opacity": 0.8, "type": "scatter", "uid": "35fc750d-deb1-4699-a133-3a360518bdaa", "x": ["2019-05-01", "2019-04-01", "2019-03-01", "2019-02-01", "2019-01-01", "2018-12-01", "2018-11-01", "2018-10-01", "2018-09-01", "2018-08-01", "2018-07-01", "2018-06-01", "2018-05-01"], "y": [3.1724137931034484, 3.4791666666666665, 2.8857142857142857, 2.806451612903226, 3.025, 2.8214285714285716, 3.72, 3.409090909090909, 2.8684210526315788, 3.6486486486486487, 3.027027027027027, 3.3529411764705883, 2.914285714285714]}],
#                         {"title": {"text": "keyword: library iOS and Android monthly avg rating (with review texts)"}, "xaxis": {"range": ["2018-06-11", "2019-05-31"]}, "yaxis": {"range": [0, 5]}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('6fb57daf-1711-4f85-8119-1c5231608f52');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
#show change

kw = "buy"
kw1 = "purchase"

as_kw_to_review_sub= ios_kw_rating[ios_kw_rating["keyword"] == kw].sort_values("month_start",ascending=False)
gp_kw_to_review_sub = android_kw_rating[android_kw_rating["keyword"] == kw].sort_values("month_start",ascending=False)

as_kw_to_review_sub1= ios_kw_rating[ios_kw_rating["keyword"] == kw1].sort_values("month_start",ascending=False)
gp_kw_to_review_sub1 = android_kw_rating[android_kw_rating["keyword"] == kw1].sort_values("month_start",ascending=False)


# monthly trend
trace_ios = go.Scatter(
                x=as_kw_to_review_sub.month_start,
                y=as_kw_to_review_sub["Rating"],
                name = "iOS Rating(with review)",
                line = dict(color = '#17BECF', width = 4),
                opacity = 0.6)

trace_ios1 = go.Scatter(
                x=as_kw_to_review_sub1.month_start,
                y=as_kw_to_review_sub1["Rating"],
                name = "iOS Rating(with review)",
                line = dict(color = '#3F71AD', width = 4),
                opacity = 0.6)

trace_android = go.Scatter(
                x=gp_kw_to_review_sub.month_start,
                y=gp_kw_to_review_sub["Rating"],
                name = "Android Rating(with review)",
                line = dict(color = '#7F7F7F', width = 4),
                opacity = 0.6)
trace_android1 = go.Scatter(
                x=gp_kw_to_review_sub1.month_start,
                y=gp_kw_to_review_sub1["Rating"],
                name = "Android Rating(with review)",
                line = dict(color = '#2A2B2C', width = 4),
                opacity = 0.6)

data = [trace_ios,trace_android, trace_ios1,trace_android1]

layout = dict(
    title = "keyword: " + kw + "/" + kw1 + " " +"iOS and Android monthly avg rating (with review texts)",
    xaxis = dict(
        range = ['2018-06-11','2019-05-31']),
    yaxis = dict(range = [0,5])
)

fig = dict(data=data, layout=layout)
py.iplot(fig, filename = "Manually Set Range")
# Out:
# <div>
#
#
#             <div id="b929fb2e-17ad-4fa6-9b5e-d4158847b5ad" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("b929fb2e-17ad-4fa6-9b5e-d4158847b5ad")) {
#                     Plotly.newPlot(
#                         'b929fb2e-17ad-4fa6-9b5e-d4158847b5ad',
#                         [{"line": {"color": "#17BECF", "width": 4}, "name": "iOS Rating(with review)", "opacity": 0.6, "type": "scatter", "uid": "1f43c764-53f1-49f4-81eb-62103de1ea3a", "x": ["2019-05-01", "2019-04-01", "2019-03-01", "2019-02-01", "2019-01-01", "2018-12-01", "2018-11-01", "2018-10-01", "2018-09-01", "2018-08-01", "2018-07-01", "2018-06-01", "2018-05-01"], "y": [3.054054054054054, 3.25, 2.880952380952381, 3.5757575757575757, 2.962962962962963, 3.2222222222222223, 3.642857142857143, 3.8214285714285716, 3.7464788732394365, 3.887323943661972, 4.387012987012987, 4.408955223880597, 3.3529411764705883]}, {"line": {"color": "#7F7F7F", "width": 4}, "name": "Android Rating(with review)", "opacity": 0.6, "type": "scatter", "uid": "0b6d7424-2ddd-489e-81e3-2f053edbd93b", "x": ["2019-05-01", "2019-04-01", "2019-03-01", "2019-02-01", "2019-01-01", "2018-12-01", "2018-11-01", "2018-10-01", "2018-09-01", "2018-08-01", "2018-07-01", "2018-06-01", "2018-05-01"], "y": [2.6923076923076925, 2.875, 2.2857142857142856, 2.590909090909091, 2.8214285714285716, 2.0416666666666665, 2.5217391304347827, 3.4, 2.5757575757575757, 2.5, 2.5185185185185186, 2.9696969696969697, 1.6923076923076923]}, {"line": {"color": "#3F71AD", "width": 4}, "name": "iOS Rating(with review)", "opacity": 0.6, "type": "scatter", "uid": "32a935e2-3d02-4516-83b0-f72deea7b823", "x": ["2019-05-01", "2019-04-01", "2019-03-01", "2019-02-01", "2019-01-01", "2018-12-01", "2018-11-01", "2018-10-01", "2018-09-01", "2018-08-01", "2018-07-01", "2018-06-01", "2018-05-01"], "y": [2.4444444444444446, 3.0416666666666665, 3.3142857142857145, 2.948717948717949, 2.847826086956522, 2.909090909090909, 3.0, 3.234375, 3.3380281690140845, 3.7260273972602738, 4.295843520782396, 4.307462686567164, 2.7058823529411766]}, {"line": {"color": "#2A2B2C", "width": 4}, "name": "Android Rating(with review)", "opacity": 0.6, "type": "scatter", "uid": "8e531cd0-bea7-4921-a245-e1fab95a1c94", "x": ["2019-05-01", "2019-04-01", "2019-03-01", "2019-02-01", "2019-01-01", "2018-12-01", "2018-11-01", "2018-10-01", "2018-09-01", "2018-08-01", "2018-07-01", "2018-06-01", "2018-05-01"], "y": [1.7894736842105263, 1.8148148148148149, 2.2325581395348837, 2.0714285714285716, 2.185185185185185, 2.838709677419355, 2.2666666666666666, 2.473684210526316, 3.074074074074074, 2.0, 2.0357142857142856, 1.7391304347826086, 2.0]}],
#                         {"title": {"text": "keyword: buy/purchase iOS and Android monthly avg rating (with review texts)"}, "xaxis": {"range": ["2018-06-11", "2019-05-31"]}, "yaxis": {"range": [0, 5]}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('b929fb2e-17ad-4fa6-9b5e-d4158847b5ad');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
#show change

kw = "crash"

as_kw_to_review_sub= ios_kw_rating[ios_kw_rating["keyword"] == kw].sort_values("month_start",ascending=False)
gp_kw_to_review_sub = android_kw_rating[android_kw_rating["keyword"] == kw].sort_values("month_start",ascending=False)

# monthly trend
trace_ios = go.Scatter(
                x=as_kw_to_review_sub.month_start,
                y=as_kw_to_review_sub["Rating"],
                name = "iOS Rating(with review)",
                line = dict(color = '#17BECF', width = 4),
                opacity = 0.8)

trace_android = go.Scatter(
                x=gp_kw_to_review_sub.month_start,
                y=gp_kw_to_review_sub["Rating"],
                name = "Android Rating(with review)",
                line = dict(color = '#7F7F7F', width = 4),
                opacity = 0.8)

data = [trace_ios,trace_android]

layout = dict(
    title = "keyword: " + kw + " " +"iOS and Android monthly avg rating (with review texts)",
    xaxis = dict(
        range = ['2018-06-11','2019-05-31']),
    yaxis = dict(range = [0,5])
)

fig = dict(data=data, layout=layout)
py.iplot(fig, filename = "Manually Set Range")
# Out:
# <div>
#
#
#             <div id="6a46d0e2-b234-4db1-bd23-362eb42331d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("6a46d0e2-b234-4db1-bd23-362eb42331d3")) {
#                     Plotly.newPlot(
#                         '6a46d0e2-b234-4db1-bd23-362eb42331d3',
#                         [{"line": {"color": "#17BECF", "width": 4}, "name": "iOS Rating(with review)", "opacity": 0.8, "type": "scatter", "uid": "57396c85-180f-47a7-a85a-3e294449bf52", "x": ["2019-05-01", "2019-04-01", "2019-03-01", "2019-02-01", "2019-01-01", "2018-12-01", "2018-11-01", "2018-10-01", "2018-09-01", "2018-08-01", "2018-07-01", "2018-06-01", "2018-05-01"], "y": [1.0, 2.142857142857143, 2.0, 1.8333333333333333, 1.5, 2.0, 1.6, 1.0, 2.3333333333333335, 2.857142857142857, 3.8620689655172415, 3.0, 1.5]}, {"line": {"color": "#7F7F7F", "width": 4}, "name": "Android Rating(with review)", "opacity": 0.8, "type": "scatter", "uid": "7114c775-8886-4442-8bc2-9aa55dbd9e56", "x": ["2019-05-01", "2019-04-01", "2019-03-01", "2019-02-01", "2019-01-01", "2018-12-01", "2018-11-01", "2018-10-01", "2018-09-01", "2018-08-01", "2018-07-01", "2018-06-01", "2018-05-01"], "y": [1.5666666666666667, 2.2, 1.619047619047619, 1.7916666666666667, 2.4166666666666665, 1.736842105263158, 2.727272727272727, 1.6, 2.1, 1.7857142857142858, 1.75, 2.064516129032258, 1.894736842105263]}],
#                         {"title": {"text": "keyword: crash iOS and Android monthly avg rating (with review texts)"}, "xaxis": {"range": ["2018-06-11", "2019-05-31"]}, "yaxis": {"range": [0, 5]}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('6a46d0e2-b234-4db1-bd23-362eb42331d3');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
#show change

kw = "recommendation"

as_kw_to_review_sub= ios_kw_rating[ios_kw_rating["keyword"] == kw].sort_values("month_start",ascending=False)
gp_kw_to_review_sub = android_kw_rating[android_kw_rating["keyword"] == kw].sort_values("month_start",ascending=False)

# monthly trend
trace_ios = go.Scatter(
                x=as_kw_to_review_sub.month_start,
                y=as_kw_to_review_sub["Rating"],
                name = "iOS Rating(with review)",
                line = dict(color = '#17BECF', width = 4),
                opacity = 0.8)

trace_android = go.Scatter(
                x=gp_kw_to_review_sub.month_start,
                y=gp_kw_to_review_sub["Rating"],
                name = "Android Rating(with review)",
                line = dict(color = '#7F7F7F', width = 4),
                opacity = 0.8)

data = [trace_ios,trace_android]

layout = dict(
    title = "keyword: " + kw + " " +"iOS and Android monthly avg rating (with review texts)",
    xaxis = dict(
        range = ['2018-06-11','2019-05-31']),
    yaxis = dict(range = [0,5])
)

fig = dict(data=data, layout=layout)
py.iplot(fig, filename = "Manually Set Range")
# Out:
# <div>
#
#
#             <div id="981a3842-5f58-403b-82cb-6e5e8fca41b6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById
');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
#show change

kw = "sample"

as_kw_to_review_sub= ios_kw_rating[ios_kw_rating["keyword"] == kw].sort_values("month_start",ascending=False)
gp_kw_to_review_sub = android_kw_rating[android_kw_rating["keyword"] == kw].sort_values("month_start",ascending=False)

# monthly trend
trace_ios = go.Scatter(
                x=as_kw_to_review_sub.month_start,
                y=as_kw_to_review_sub["Rating"],
                name = "iOS Rating(with review)",
                line = dict(color = '#17BECF', width = 4),
                opacity = 0.8)

trace_android = go.Scatter(
                x=gp_kw_to_review_sub.month_start,
                y=gp_kw_to_review_sub["Rating"],
                name = "Android Rating(with review)",
                line = dict(color = '#7F7F7F', width = 4),
                opacity = 0.8)

data = [trace_ios,trace_android]

layout = dict(
    title = "keyword: " + kw + " " +"iOS and Android monthly avg rating (with review texts)",
    xaxis = dict(
        range = ['2018-06-11','2019-05-31']),
    yaxis = dict(range = [0,5])
)

fig = dict(data=data, layout=layout)
py.iplot(fig, filename = "Manually Set Range")
# Out:
# <div>
#
#
#             <div id="a1e4c953-2039-4c5e-ba50-ac2fe29b6320" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("a1e4c953-2039-4c5e-ba50-ac2fe29b6320")) {
#                     Plotly.newPlot(
#                         'a1e4c953-2039-4c5e-ba50-ac2fe29b6320',
#                         [{"line": {"color": "#17BECF", "width": 4}, "name": "iOS Rating(with review)", "opacity": 0.8, "type": "scatter", "uid": "6c57127c-c5df-442c-8eeb-dcbdce13567a", "x": ["2019-05-01", "2019-04-01", "2019-03-01", "2019-02-01", "2019-01-01", "2018-12-01", "2018-11-01", "2018-10-01", "2018-09-01", "2018-08-01", "2018-07-01", "2018-06-01", "2018-05-01"], "y": [3.04, 2.769230769230769, 2.238095238095238, 4.0, 2.9473684210526314, 3.272727272727273, 2.9473684210526314, 3.3548387096774195, 3.2666666666666666, 3.05, 4.241758241758242, 4.056338028169014, 3.4]}, {"line": {"color": "#7F7F7F", "width": 4}, "name": "Android Rating(with review)", "opacity": 0.8, "type": "scatter", "uid": "a8057ddf-6caa-4860-85d5-b3504a6d9e1b", "x": ["2019-05-01", "2019-04-01", "2019-03-01", "2019-02-01", "2019-01-01", "2018-12-01", "2018-11-01", "2018-10-01", "2018-09-01", "2018-08-01", "2018-07-01", "2018-06-01", "2018-05-01"], "y": [2.4210526315789473, 2.0, 2.125, 1.5, 2.857142857142857, 2.5384615384615383, 3.0, 2.857142857142857, 2.076923076923077, 2.6, 2.3, 1.3333333333333333, 2.1666666666666665]}],
#                         {"title": {"text": "keyword: sample iOS and Android monthly avg rating (with review texts)"}, "xaxis": {"range": ["2018-06-11", "2019-05-31"]}, "yaxis": {"range": [0, 5]}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('a1e4c953-2039-4c5e-ba50-ac2fe29b6320');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
#show change

kw = "highlight"

as_kw_to_review_sub= ios_kw_rating[ios_kw_rating["keyword"] == kw].sort_values("month_start",ascending=False)
gp_kw_to_review_sub = android_kw_rating[android_kw_rating["keyword"] == kw].sort_values("month_start",ascending=False)

# monthly trend
trace_ios = go.Scatter(
                x=as_kw_to_review_sub.month_start,
                y=as_kw_to_review_sub["Rating"],
                name = "iOS Rating(with review)",
                line = dict(color = '#17BECF', width = 4),
                opacity = 0.8)

trace_android = go.Scatter(
                x=gp_kw_to_review_sub.month_start,
                y=gp_kw_to_review_sub["Rating"],
                name = "Android Rating(with review)",
                line = dict(color = '#7F7F7F', width = 4),
                opacity = 0.8)

data = [trace_ios,trace_android]

layout = dict(
    title = "keyword: " + kw + " " +"iOS and Android monthly avg rating (with review texts)",
    xaxis = dict(
        range = ['2018-06-11','2019-05-31']),
    yaxis = dict(range = [0,5])
)

fig = dict(data=data, layout=layout)
py.iplot(fig, filename = "Manually Set Range")
# Out:
# <div>
#
#
#             <div id="8e674b75-cc3c-4df8-9e05-fdb1982a0439" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("8e674b75-cc3c-4df8-9e05-fdb1982a0439")) {
#                     Plotly.newPlot(
#                         '8e674b75-cc3c-4df8-9e05-fdb1982a0439',
#                         [{"line": {"color": "#17BECF", "width": 4}, "name": "iOS Rating(with review)", "opacity": 0.8, "type": "scatter", "uid": "07bfb564-6256-4baf-9192-d2aae64360ef", "x": ["2019-05-01", "2019-04-01", "2019-03-01", "2019-02-01", "2019-01-01", "2018-12-01", "2018-11-01", "2018-10-01", "2018-09-01", "2018-08-01", "2018-07-01", "2018-06-01", "2018-05-01"], "y": [3.8095238095238093, 4.176470588235294, 3.6, 3.736842105263158, 3.642857142857143, 3.740740740740741, 4.142857142857143, 4.131578947368421, 4.0, 3.7837837837837838, 4.602510460251046, 4.528455284552845, 3.3333333333333335]}, {"line": {"color": "#7F7F7F", "width": 4}, "name": "Android Rating(with review)", "opacity": 0.8, "type": "scatter", "uid": "bed71f25-52aa-48a6-814e-de76318f2607", "x": ["2019-05-01", "2019-04-01", "2019-03-01", "2019-02-01", "2019-01-01", "2018-12-01", "2018-11-01", "2018-10-01", "2018-09-01", "2018-08-01", "2018-07-01", "2018-06-01", "2018-05-01"], "y": [3.1666666666666665, 3.1666666666666665, 3.142857142857143, 4.2, 3.6923076923076925, 4.333333333333333, 4.142857142857143, 3.5, 2.875, 3.5, 2.8, 2.857142857142857, 2.1818181818181817]}],
#                         {"title": {"text": "keyword: highlight iOS and Android monthly avg rating (with review texts)"}, "xaxis": {"range": ["2018-06-11", "2019-05-31"]}, "yaxis": {"range": [0, 5]}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('8e674b75-cc3c-4df8-9e05-fdb1982a0439');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
#show change

kw = "pdf"

as_kw_to_review_sub= ios_kw_rating[ios_kw_rating["keyword"] == kw].sort_values("month_start",ascending=False)
gp_kw_to_review_sub = android_kw_rating[android_kw_rating["keyword"] == kw].sort_values("month_start",ascending=False)

# monthly trend
trace_ios = go.Scatter(
                x=as_kw_to_review_sub.month_start,
                y=as_kw_to_review_sub["Rating"],
                name = "iOS Rating(with review)",
                line = dict(color = '#17BECF', width = 4),
                opacity = 0.8)

trace_android = go.Scatter(
                x=gp_kw_to_review_sub.month_start,
                y=gp_kw_to_review_sub["Rating"],
                name = "Android Rating(with review)",
                line = dict(color = '#7F7F7F', width = 4),
                opacity = 0.8)

data = [trace_ios,trace_android]

layout = dict(
    title = "keyword: " + kw + " " +"iOS and Android monthly avg rating (with review texts)",
    xaxis = dict(
        range = ['2018-06-11','2019-05-31']),
    yaxis = dict(range = [0,5])
)

fig = dict(data=data, layout=layout)
py.iplot(fig, filename = "Manually Set Range")
# Out:
# <div>
#
#
#             <div id="8001be39-ac1a-43bb-9535-042079c72c5e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("8001be39-ac1a-43bb-9535-042079c72c5e")) {
#                     Plotly.newPlot(
#                         '8001be39-ac1a-43bb-9535-042079c72c5e',
#                         [{"line": {"color": "#17BECF", "width": 4}, "name": "iOS Rating(with review)", "opacity": 0.8, "type": "scatter", "uid": "d644723e-a8b0-47c4-ba0f-bcf8debbb2b6", "x": ["2019-05-01", "2019-04-01", "2019-03-01", "2019-02-01", "2019-01-01", "2018-12-01", "2018-11-01", "2018-10-01", "2018-09-01", "2018-08-01", "2018-07-01", "2018-06-01", "2018-05-01"], "y": [2.5, 1.3333333333333333, 3.6666666666666665, 1.0, 4.571428571428571, 3.25, 4.333333333333333, 4.333333333333333, 3.4444444444444446, 4.777777777777778, 4.5, 4.6, 5.0]}, {"line": {"color": "#7F7F7F", "width": 4}, "name": "Android Rating(with review)", "opacity": 0.8, "type": "scatter", "uid": "03213abb-be35-4611-a653-3a2ed7fc8fe3", "x": ["2019-05-01", "2019-04-01", "2019-03-01", "2019-02-01", "2019-01-01", "2018-12-01", "2018-11-01", "2018-10-01", "2018-09-01", "2018-08-01", "2018-07-01", "2018-06-01", "2018-05-01"], "y": [3.5, 4.2, 1.5, 2.8, 2.5, 3.625, 4.4, 2.6666666666666665, 2.3333333333333335, 2.1666666666666665, 2.8, 2.5555555555555554, 2.3333333333333335]}],
#                         {"title": {"text": "keyword: pdf iOS and Android monthly avg rating (with review texts)"}, "xaxis": {"range": ["2018-06-11", "2019-05-31"]}, "yaxis": {"range": [0, 5]}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('8001be39-ac1a-43bb-9535-042079c72c5e');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
#show change

kw = "suggestion"

as_kw_to_review_sub= ios_kw_rating[ios_kw_rating["keyword"] == kw].sort_values("month_start",ascending=False)
gp_kw_to_review_sub = android_kw_rating[android_kw_rating["keyword"] == kw].sort_values("month_start",ascending=False)

# monthly trend
trace_ios = go.Scatter(
                x=as_kw_to_review_sub.month_start,
                y=as_kw_to_review_sub["Rating"],
                name = "iOS Rating(with review)",
                line = dict(color = '#17BECF', width = 4),
                opacity = 0.8)

trace_android = go.Scatter(
                x=gp_kw_to_review_sub.month_start,
                y=gp_kw_to_review_sub["Rating"],
                name = "Android Rating(with review)",
                line = dict(color = '#7F7F7F', width = 4),
                opacity = 0.8)

data = [trace_ios,trace_android]

layout = dict(
    title = "keyword: " + kw + " " +"iOS and Android monthly avg rating (with review texts)",
    xaxis = dict(
        range = ['2018-06-11','2019-05-31']),
    yaxis = dict(range = [0,5])
)

fig = dict(data=data, layout=layout)
py.iplot(fig, filename = "Manually Set Range")
# Out:
# <div>
#
#
#             <div id="257337e6-4299-4816-8a1e-40e0f31f3893" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("257337e6-4299-4816-8a1e-40e0f31f3893")) {
#                     Plotly.newPlot(
#                         '257337e6-4299-4816-8a1e-40e0f31f3893',
#                         [{"line": {"color": "#17BECF", "width": 4}, "name": "iOS Rating(with review)", "opacity": 0.8, "type": "scatter", "uid": "51140b15-eb8e-45a7-b799-2c66da934be8", "x": ["2019-05-01", "2019-04-01", "2019-03-01", "2019-02-01", "2019-01-01", "2018-12-01", "2018-11-01", "2018-10-01", "2018-09-01", "2018-08-01", "2018-07-01", "2018-06-01", "2018-05-01"], "y": [4.166666666666667, 5.0, 3.0, 4.333333333333333, 3.6666666666666665, 4.0, 3.8, 5.0, 4.571428571428571, 3.7142857142857144, 4.555555555555555, 4.444444444444445, 4.0]}, {"line": {"color": "#7F7F7F", "width": 4}, "name": "Android Rating(with review)", "opacity": 0.8, "type": "scatter", "uid": "399c243e-5edf-4f54-b1a1-13dccf6b8b17", "x": ["2019-05-01", "2019-04-01", "2019-03-01", "2019-02-01", "2019-01-01", "2018-12-01", "2018-11-01", "2018-10-01", "2018-09-01", "2018-08-01", "2018-07-01", "2018-06-01", "2018-05-01"], "y": [3.0, 2.75, 3.4, 3.0, 5.0, 5.0, 4.5, 3.0, 4.0, 1.0, 2.5, 5.0, 3.75]}],
#                         {"title": {"text": "keyword: suggestion iOS and Android monthly avg rating (with review texts)"}, "xaxis": {"range": ["2018-06-11", "2019-05-31"]}, "yaxis": {"range": [0, 5]}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('257337e6-4299-4816-8a1e-40e0f31f3893');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
#combined word freq excluding stop words to csv for inspection
#pd.concat([rslt_ios,rslt_android]).to_csv(os.path.join(path,r'combined_word_freq.csv'))

# %%
# tokenized_sms = pd.array([nltk.word_tokenize(str(sentence)) for sentence in df_as_kindle_05_18_05_19["Title1"]])
# for word in tokenized_sms:
#     if word in sw:
#         tokenized_sms.remove(word)

# tokenized_sms = pd.array([nltk.word_tokenize(str(sentence)) for sentence in df_as_kindle_05_18_05_19["Title1"]])
# for sentence in tokenized_sms:
#     for word in sentence:
#         if word in sw:
#             tokenized_sms[sentence].remove(word)

# %%
a = rslt.reset_index()
print(a[a["Word"]=="crash"])
print(a[a["Word"]=="crashes"])
# Out:
#       Word  Frequency
# 567  crash          6
#         Word  Frequency
# 153  crashes         27

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()

# %%
#sentiment analysis
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.classify import NaiveBayesClassifier
from nltk.corpus import subjectivity
from nltk.sentiment import SentimentAnalyzer
from nltk.sentiment.util import *

# %% [markdown]
# ### In-Book Reading CX related key words ###
#
# text, color, background, dictionary, Aa, bookmark, navigation, brightness, font, margin, paragraph, turn, animation, continous scroll, vertical scroll, notes, highlight, x-ray, flash cards, share,
#
# ### Outside the Book CX related key words ###
#
# Sync, library, download, pdf, search, sd card, filter, mark as read, all, downloaded, store, reading insights, friends, community
#
# ### Else ###
# Notification, prime subscription, ku subscription, best seller, recommendation, multi-user related (husband, wife, son, daughter, grandma, etc.), students (textbook, school), borrow, sample, listen, audible, alexa, magazine, comic

# %% [markdown]
# To do:
# - add review text legth nd by VADER Score
