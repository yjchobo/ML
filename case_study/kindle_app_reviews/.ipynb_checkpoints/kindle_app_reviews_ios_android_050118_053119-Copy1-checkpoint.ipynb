# %%
#Importing libraries
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import matplotlib.pyplot as plt#visualization
from PIL import  Image
# %matplotlib inline
import pandas as pd
import seaborn as sns#visualization
import itertools
import warnings
warnings.filterwarnings("ignore")
import io
import plotly.offline as py#visualization
py.init_notebook_mode(connected=True)#visualization
import plotly.graph_objs as go#visualization
import plotly.tools as tls#visualization
import plotly.figure_factory as ff#visualization
import pprint
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#options
pd.options.display.max_rows = 1000
pd.options.display.max_columns = 1000

# %%
# load data
# as = app store; gp = google play
df_gp_kindle_05_18 = pd.read_csv(r"Google Play_Amazon Kindle_2018_05_01-2018_05_31.csv")
df_gp_kindle_06_18 = pd.read_csv(r"Google Play_Amazon Kindle_2018_06_01-2018_06_30.csv")
df_gp_kindle_07_18 = pd.read_csv(r"Google Play_Amazon Kindle_2018_07_01-2018_07_31.csv")
df_gp_kindle_08_18 = pd.read_csv(r"Google Play_Amazon Kindle_2018_08_01-2018_08_31.csv")
df_gp_kindle_09_18 = pd.read_csv(r"Google Play_Amazon Kindle_2018_09_01-2018_09_30.csv")
df_gp_kindle_10_18 = pd.read_csv(r"Google Play_Amazon Kindle_2018_10_01-2018_10_31.csv")
df_gp_kindle_11_18 = pd.read_csv(r"Google Play_Amazon Kindle_2018_11_01-2018_11_30.csv")
df_gp_kindle_12_18 = pd.read_csv(r"Google Play_Amazon Kindle_2018_12_01-2018_12_31.csv")
df_gp_kindle_01_19 = pd.read_csv(r"Google Play_Amazon Kindle_2019_01_01-2019_01_31.csv")
df_gp_kindle_02_19 = pd.read_csv(r"Google Play_Amazon Kindle_2019_02_01-2019_02_28.csv")
df_gp_kindle_03_19 = pd.read_csv(r"Google Play_Amazon Kindle_2019_03_01-2019_03_31.csv")
df_gp_kindle_04_19 = pd.read_csv(r"Google Play_Amazon Kindle_2019_04_01-2019_04_30.csv")
df_gp_kindle_05_19 = pd.read_csv(r"Google Play_Amazon Kindle_2019_05_01-2019_05_31.csv")
df_gp_kindle_05_18_05_19 = pd.concat([df_gp_kindle_05_18,df_gp_kindle_06_18,df_gp_kindle_07_18,df_gp_kindle_08_18,df_gp_kindle_09_18,df_gp_kindle_10_18,df_gp_kindle_11_18,df_gp_kindle_12_18,df_gp_kindle_01_19,df_gp_kindle_02_19,df_gp_kindle_03_19,df_gp_kindle_04_19,df_gp_kindle_05_19])

df_as_kindle_05_18_05_19 = pd.read_csv(r"iOS_Amazon Kindle_2018_05_01-2019_05_31.csv")

# %%
#iOS
#df_as_kindle_05_18_05_19.head()
# Out:
#   Platform        Country       Date     App ID       App Name  Publisher ID  \
# 0      iOS  United States  5/31/2019  302584613  Amazon Kindle     297606954
# 1      iOS  United States  5/31/2019  302584613  Amazon Kindle     297606954
# 2      iOS  United States  5/31/2019  302584613  Amazon Kindle     297606954
# 3      iOS  United States  5/31/2019  302584613  Amazon Kindle     297606954
# 4      iOS  United States  5/31/2019  302584613  Amazon Kindle     297606954
#
#     Publisher Name  User Version  Rating  \
# 0  AMZN Mobile LLC   NaN    6.19       2
# 1  AMZN Mobile LLC   NaN    6.19       5
# 2  AMZN Mobile LLC   NaN    6.19       1
# 3  AMZN Mobile LLC   NaN    6.19       3
# 4  AMZN Mobile LLC   NaN    6.19       5
#
#                                           Title  \
# 0                      Not user friendly at all
# 1                                        Kindle
# 2                            Crashes every time
# 3                                         Books
# 4  Maybe because it’s only a few apps out there
#
#                                               Review
# 0  As I sometimes leave my Kindle at home by mist...
# 1  So convenient and fun to buy and read on my ki...
# 2  I love Kindle and use it every day on my iPad....
# 3  Great app, but I'd like to be able to remove b...
# 4  I have 2k books in my kindle at my disposal. H...

# %%
#Android
#df_gp_kindle_05_18_05_19.head()
# Out:
#       Platform Language       Date             App ID       App Name  \
# 0  Google Play  English  5/31/2018  com.amazon.kindle  Amazon Kindle
# 1  Google Play  English  5/31/2018  com.amazon.kindle  Amazon Kindle
# 2  Google Play  English  5/31/2018  com.amazon.kindle  Amazon Kindle
# 3  Google Play  English  5/31/2018  com.amazon.kindle  Amazon Kindle
# 4  Google Play  English  5/31/2018  com.amazon.kindle  Amazon Kindle
#
#    Publisher ID     Publisher Name  User    Version  Rating Title  \
# 0  2.020000e+13  Amazon Mobile LLC   NaN        NaN       5   NaN
# 1  2.020000e+13  Amazon Mobile LLC   NaN        NaN       5   NaN
# 2  2.020000e+13  Amazon Mobile LLC   NaN   8.0.0.78       1   NaN
# 3  2.020000e+13  Amazon Mobile LLC   NaN  7.15.0.90       3   NaN
# 4  2.020000e+13  Amazon Mobile LLC   NaN        NaN       5   NaN
#
#                                               Review
# 0                                               Good
# 1                                            love it
# 2  HATEEEEE TOOOO READDDDDD I HATTTTEEEE ITTTTT w...
# 3                           Needs some work for sure
# 4                                               Good

# %%
#ios
#df_as_kindle_05_18_05_19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18632 entries, 0 to 18631
# Data columns (total 12 columns):
# Platform          18632 non-null object
# Country           18632 non-null object
# Date              18632 non-null object
# App ID            18632 non-null int64
# App Name          18632 non-null object
# Publisher ID      18632 non-null int64
# Publisher Name    18632 non-null object
# User              0 non-null float64
# Version           18632 non-null object
# Rating            18632 non-null int64
# Title             18631 non-null object
# Review            18632 non-null object
# dtypes: float64(1), int64(3), object(8)
# memory usage: 1.7+ MB

# %%
#android
#df_gp_kindle_05_18_05_19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21048 entries, 0 to 1689
# Data columns (total 12 columns):
# Platform          21048 non-null object
# Language          21048 non-null object
# Date              21048 non-null object
# App ID            21048 non-null object
# App Name          21048 non-null object
# Publisher ID      21048 non-null float64
# Publisher Name    21048 non-null object
# User              0 non-null float64
# Version           11685 non-null object
# Rating            21048 non-null int64
# Title             41 non-null object
# Review            21047 non-null object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 2.1+ MB

# %%
#df_as_kindle_05_18_05_19.nunique()
# Out:
# Platform              1
# Country               1
# Date                395
# App ID                1
# App Name              1
# Publisher ID          1
# Publisher Name        1
# User                  0
# Version              21
# Rating                5
# Title             10674
# Review            18103
# dtype: int64

# %%
#df_gp_kindle_05_18_05_19.nunique()
# Out:
# Platform              1
# Language              1
# Date                394
# App ID                1
# App Name              1
# Publisher ID          1
# Publisher Name        1
# User                  0
# Version             100
# Rating                5
# Title                38
# Review            15499
# dtype: int64

# %% [markdown]
# **iOS**
# - Platform: irrelevant, drop
# - Country: Only US, drop
# - Date: as string convert to datetime object
# - App ID: irrelevant, drop
# - App Name: Amazon Kindle iOS, drop
# - Publisher ID: irrelevant, drop
# - Publisher Name: irrelevant, drop
# - User all missing: drop
# - Version: keep
# - Rating: keep
# - Title: keep
# - Review: keep
#
# **Android**
# - Platform: irrelevant, drop
# - Language: only english, drop
# - Date: as string convert to datetime object
# - App ID: irrelevant, drop
# - App Name: irrelevant, drop
# - Publisher: irrelevant, drop
# - Publisher: irrelevant, drop
# - User: all missing, drop
# - Version: keep
# - Rating: keep
# - Title: very small fraction has non missing values, drop
# - Review: keep

# %%
# data cleaning
# drop
ios_drops = ["Platform","Country","App ID","App Name","Publisher ID","Publisher Name","User"]
android_drops = ["Platform","Language","App ID","App Name","Publisher ID","Publisher Name","User","Title"]
for i in ios_drops:
    df_as_kindle_05_18_05_19 = df_as_kindle_05_18_05_19.drop(columns = i, axis = 1, errors = "ignore")

for i in android_drops:
    df_gp_kindle_05_18_05_19 = df_gp_kindle_05_18_05_19.drop(columns = i, axis = 1, errors = "ignore")

# string to datetime
df_as_kindle_05_18_05_19['Date'] = pd.to_datetime(df_as_kindle_05_18_05_19['Date'])
df_gp_kindle_05_18_05_19['Date'] = pd.to_datetime(df_gp_kindle_05_18_05_19['Date'])

# add week and month level
def time_window(df):
    time_windows = ["year","month","week", "day", "dow"]
    for i in time_windows:
        if i == "year":
            df[i] = df["Date"].dt.year
        elif i == "month":
            df[i] = df["Date"].dt.month
        elif i == "week":
            df[i] = df["Date"].dt.week
        elif i == "day":
            df[i] = df["Date"].dt.day
        else:
            df[i] = df["Date"].dt.dayofweek

#time_window(df_as_kindle_05_18_05_19)
df_as_kindle_05_18_05_19.pipe(time_window)
df_gp_kindle_05_18_05_19.pipe(time_window)
#time_window(df_gp_kindle_05_18_05_19)

# week start and month start
# date to index
df_as_kindle_05_18_05_19.set_index("Date", inplace = True)
df_gp_kindle_05_18_05_19.set_index("Date", inplace = True)

df_as_kindle_05_18_05_19['week_start'] = df_as_kindle_05_18_05_19.index.to_period('W').start_time
df_as_kindle_05_18_05_19['month_start'] = df_as_kindle_05_18_05_19.index.to_period('M').start_time

df_gp_kindle_05_18_05_19['week_start'] = df_gp_kindle_05_18_05_19.index.to_period('W').start_time
df_gp_kindle_05_18_05_19['month_start'] = df_gp_kindle_05_18_05_19.index.to_period('M').start_time

# Day of week mapping change
dow_dict = {0:"Mon",1:"Tue",2:"Wed",3:"Thu",4:"Fri",5:"Sat",6:"Sun"}
df_as_kindle_05_18_05_19.replace({"dow": dow_dict}, inplace = True)
df_gp_kindle_05_18_05_19.replace({"dow": dow_dict}, inplace = True)

#dropping records without review texts
df_as_kindle_05_18_05_19.dropna(subset = ['Review'],inplace=True)
df_gp_kindle_05_18_05_19.dropna(subset = ['Review'],inplace=True)

# %%
df_as_kindle_05_18_05_19.head()
# Out:
#            Version  Rating                                         Title  \
# Date
# 2019-05-31    6.19       2                      Not user friendly at all
# 2019-05-31    6.19       5                                        Kindle
# 2019-05-31    6.19       1                            Crashes every time
# 2019-05-31    6.19       3                                         Books
# 2019-05-31    6.19       5  Maybe because it’s only a few apps out there
#
#                                                        Review  year  month  \
# Date
# 2019-05-31  As I sometimes leave my Kindle at home by mist...  2019      5
# 2019-05-31  So convenient and fun to buy and read on my ki...  2019      5
# 2019-05-31  I love Kindle and use it every day on my iPad....  2019      5
# 2019-05-31  Great app, but I'd like to be able to remove b...  2019      5
# 2019-05-31  I have 2k books in my kindle at my disposal. H...  2019      5
#
#             week  day  dow week_start month_start
# Date
# 2019-05-31    22   31  Fri 2019-05-27  2019-05-01
# 2019-05-31    22   31  Fri 2019-05-27  2019-05-01
# 2019-05-31    22   31  Fri 2019-05-27  2019-05-01
# 2019-05-31    22   31  Fri 2019-05-27  2019-05-01
# 2019-05-31    22   31  Fri 2019-05-27  2019-05-01

# %%
class Solution(object):
    def twoSum(self, nums, target):
        d = {}
        for i, n in enumerate(nums):
            m = target - n
            if m in d:
                return [d[m], i]
            else:
                d[n] = i

# %%
nums = [2, 7, 11, 15]
target = 9

Solution.twoSum(_,nums, target)
# Out:
# [0, 1]

# %%
for i, j in enumerate(nums):
    print(str(i),",",str(j))
# Out:
# 0 , 2
# 1 , 7
# 2 , 11
# 3 , 15

# %% [markdown]
# ### Review Trends ###

# %% [markdown]
# #### iOS ####

# %%
#Daily
ios_daily_rating = pd.DataFrame(df_as_kindle_05_18_05_19.groupby("Date").mean()["Rating"]).reset_index()
ios_daily_rating["Rating_with_Review"] = ios_daily_rating["Rating"].apply(lambda x: round(x,2))

android_daily_rating = pd.DataFrame(df_gp_kindle_05_18_05_19.groupby("Date").mean()["Rating"]).reset_index()
android_daily_rating["Rating_with_Review"] = android_daily_rating["Rating"].apply(lambda x: round(x,2))

#Weekly
ios_weekly_rating = pd.DataFrame(df_as_kindle_05_18_05_19.groupby("week_start").mean()["Rating"]).reset_index()
ios_weekly_rating["Rating_with_Review"] = ios_weekly_rating["Rating"].apply(lambda x: round(x,2))

android_weekly_rating = pd.DataFrame(df_gp_kindle_05_18_05_19.groupby("week_start").mean()["Rating"]).reset_index()
android_weekly_rating["Rating_with_Review"] = android_weekly_rating["Rating"].apply(lambda x: round(x,2))

#Monthly
ios_monthly_rating = pd.DataFrame(df_as_kindle_05_18_05_19.groupby("month_start").mean()["Rating"]).reset_index()
ios_monthly_rating["Rating_with_Review"] = ios_monthly_rating["Rating"].apply(lambda x: round(x,2))

android_monthly_rating = pd.DataFrame(df_gp_kindle_05_18_05_19.groupby("month_start").mean()["Rating"]).reset_index()
android_monthly_rating["Rating_with_Review"] = android_monthly_rating["Rating"].apply(lambda x: round(x,2))

# %%
# daily trend
trace_ios = go.Scatter(
                x=ios_daily_rating.Date,
                y=ios_daily_rating["Rating_with_Review"],
                name = "iOS Rating(with review)",
                line = dict(color = '#17BECF'),
                opacity = 0.5)

trace_android = go.Scatter(
                x=android_daily_rating.Date,
                y=android_daily_rating["Rating_with_Review"],
                name = "android Rating(with review)",
                line = dict(color = '#7F7F7F'),
                opacity = 0.7)

data = [trace_ios,trace_android]

layout = dict(
    title = "iOS and Android daily avg rating (with review texts)", #US for iOS, English for Android
    xaxis = dict(
        range = ['2018-06-11','2019-05-31'])
)

fig = dict(data=data, layout=layout)
py.iplot(fig, filename = "Manually Set Range")
# Out:
# <div>
#
#
#             <div id="ef720d45-4b9d-4493-85ae-bad81fd6eecb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ef720d45-4b9d-4493-85ae-bad81fd6eecb")) {
#                     Plotly.newPlot(
#                         'ef720d45-4b9d-4493-85ae-bad81fd6eecb',
#                         [{"line": {"color": "#17BECF"}, "name": "iOS Rating(with review)", "opacity": 0.5, "type": "scatter", "uid": "36183352-980f-466c-a769-1460dec48d28", "x": ["2018-05-01", "2018-05-02", "2018-05-03", "2018-05-04", "2018-05-05", "2018-05-06", "2018-05-07", "2018-05-08", "2018-05-09", "2018-05-10", "2018-05-11", "2018-05-12", "2018-05-13", "2018-05-14", "2018-05-15", "2018-05-16", "2018-05-17", "2018-05-18", "2018-05-19", "2018-05-20", "2018-05-21", "2018-05-22", "2018-05-23", "2018-05-24", "2018-05-25", "2018-05-26", "2018-05-27", "2018-05-28", "2018-05-29", "2018-05-30", "2018-05-31", "2018-06-01", "2018-06-02", "2018-06-03", "2018-06-05", "2018-06-06", "2018-06-07", "2018-06-08", "2018-06-09", "2018-06-10", "2018-06-11", "2018-06-12", "2018-06-13", "2018-06-14", "2018-06-15", "2018-06-16", "2018-06-17", "2018-06-18", "2018-06-19", "2018-06-20", "2018-06-21", "2018-06-22", "2018-06-23", "2018-06-24", "2018-06-25", "2018-06-26", "2018-06-27", "2018-06-28", "2018-06-29", "2018-06-30", "2018-07-01", "2018-07-02", "2018-07-03", "2018-07-04", "2018-07-05", "2018-07-06", "2018-07-07", "2018-07-08", "2018-07-09", "2018-07-10", "2018-07-11", "2018-07-12", "2018-07-13", "2018-07-14", "2018-07-15", "2018-07-16", "2018-07-17", "2018-07-18", "2018-07-19", "2018-07-20", "2018-07-21", "2018-07-22", "2018-07-23", "2018-07-24", "2018-07-25", "2018-07-26", "2018-07-27", "2018-07-28", "2018-07-29", "2018-07-30", "2018-07-31", "2018-08-01", "2018-08-02", "2018-08-03", "2018-08-04", "2018-08-05", "2018-08-06", "2018-08-07", "2018-08-08", "2018-08-09", "2018-08-10", "2018-08-11", "2018-08-12", "2018-08-13", "2018-08-14", "2018-08-15", "2018-08-16", "2018-08-17", "2018-08-18", "2018-08-19", "2018-08-20", "2018-08-21", "2018-08-22", "2018-08-23", "2018-08-24", "2018-08-25", "2018-08-26", "2018-08-27", "2018-08-28", "2018-08-29", "2018-08-30", "2018-08-31", "2018-09-01", "2018-09-02", "2018-09-03", "2018-09-04", "2018-09-05", "2018-09-06", "2018-09-07", "2018-09-08", "2018-09-09", "2018-09-10", "2018-09-11", "2018-09-12", "2018-09-13", "2018-09-14", "2018-09-15", "2018-09-16", "2018-09-17", "2018-09-18", "2018-09-19", "2018-09-20", "2018-09-21", "2018-09-22", "2018-09-23", "2018-09-24", "2018-09-25", "2018-09-26", "2018-09-27", "2018-09-28", "2018-09-29", "2018-09-30", "2018-10-01", "2018-10-02", "2018-10-03", "2018-10-04", "2018-10-05", "2018-10-06", "2018-10-07", "2018-10-08", "2018-10-09", "2018-10-10", "2018-10-11", "2018-10-12", "2018-10-13", "2018-10-14", "2018-10-15", "2018-10-16", "2018-10-17", "2018-10-18", "2018-10-19", "2018-10-20", "2018-10-21", "2018-10-22", "2018-10-23", "2018-10-24", "2018-10-25", "2018-10-26", "2018-10-27", "2018-10-28", "2018-10-29", "2018-10-30", "2018-10-31", "2018-11-01", "2018-11-02", "2018-11-03", "2018-11-04", "2018-11-05", "2018-11-06", "2018-11-07", "2018-11-08", "2018-11-09", "2018-11-10", "2018-11-11", "2018-11-12", "2018-11-13", "2018-11-14", "2018-11-15", "2018-11-16", "2018-11-17", "2018-11-18", "2018-11-19", "2018-11-20", "2018-11-21", "2018-11-22", "2018-11-23", "2018-11-24", "2018-11-25", "2018-11-26", "2018-11-27", "2018-11-28", "2018-11-29", "2018-11-30", "2018-12-01", "2018-12-02", "2018-12-03", "2018-12-04", "2018-12-05", "2018-12-06", "2018-12-07", "2018-12-08", "2018-12-09", "2018-12-10", "2018-12-11", "2018-12-12", "2018-12-13", "2018-12-14", "2018-12-15", "2018-12-16", "2018-12-17", "2018-12-18", "2018-12-19", "2018-12-20", "2018-12-21", "2018-12-22", "2018-12-23", "2018-12-24", "2018-12-25", "2018-12-26", "2018-12-27", "2018-12-28", "2018-12-29", "2018-12-30", "2018-12-31", "2019-01-01", "2019-01-02", "2019-01-03", "2019-01-04", "2019-01-05", "2019-01-06", "2019-01-07", "2019-01-08", "2019-01-09", "2019-01-10", "2019-01-11", "2019-01-12", "2019-01-13", "2019-01-14", "2019-01-15", "2019-01-16", "2019-01-17", "2019-01-18", "2019-01-19", "2019-01-20", "2019-01-21", "2019-01-22", "2019-01-23", "2019-01-24", "2019-01-25", "2019-01-26", "2019-01-27", "2019-01-28", "2019-01-29", ...

# %%
# weekly trend
trace_ios = go.Scatter(
                x=ios_weekly_rating.week_start,
                y=ios_weekly_rating["Rating_with_Review"],
                name = "iOS Rating(with review)",
                line = dict(color = '#17BECF', width = 4),
                opacity = 0.8)

trace_android = go.Scatter(
                x=android_weekly_rating.week_start,
                y=android_weekly_rating["Rating_with_Review"],
                name = "android Rating(with review)",
                line = dict(color = '#7F7F7F', width = 4),
                opacity = 0.8)

data = [trace_ios,trace_android]

layout = dict(
    title = "iOS and Android weekly avg rating (with review texts)",
    xaxis = dict(
        range = ['2018-06-11','2019-05-31'])
)

fig = dict(data=data, layout=layout)
py.iplot(fig, filename = "Manually Set Range")
# Out:
# <div>
#
#
#             <div id="66b0993d-5f05-4d3a-93af-099eb51c3b4e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("66b0993d-5f05-4d3a-93af-099eb51c3b4e")) {
#                     Plotly.newPlot(
#                         '66b0993d-5f05-4d3a-93af-099eb51c3b4e',
#                         [{"line": {"color": "#17BECF", "width": 4}, "name": "iOS Rating(with review)", "opacity": 0.8, "type": "scatter", "uid": "bed82a18-6fb2-47a3-bc7a-184401ec6632", "x": ["2018-04-30", "2018-05-07", "2018-05-14", "2018-05-21", "2018-05-28", "2018-06-04", "2018-06-11", "2018-06-18", "2018-06-25", "2018-07-02", "2018-07-09", "2018-07-16", "2018-07-23", "2018-07-30", "2018-08-06", "2018-08-13", "2018-08-20", "2018-08-27", "2018-09-03", "2018-09-10", "2018-09-17", "2018-09-24", "2018-10-01", "2018-10-08", "2018-10-15", "2018-10-22", "2018-10-29", "2018-11-05", "2018-11-12", "2018-11-19", "2018-11-26", "2018-12-03", "2018-12-10", "2018-12-17", "2018-12-24", "2018-12-31", "2019-01-07", "2019-01-14", "2019-01-21", "2019-01-28", "2019-02-04", "2019-02-11", "2019-02-18", "2019-02-25", "2019-03-04", "2019-03-11", "2019-03-18", "2019-03-25", "2019-04-01", "2019-04-08", "2019-04-15", "2019-04-22", "2019-04-29", "2019-05-06", "2019-05-13", "2019-05-20", "2019-05-27"], "y": [2.41, 2.68, 2.8, 3.04, 2.44, 4.76, 4.75, 4.68, 4.5, 4.78, 4.74, 4.78, 4.65, 4.38, 4.49, 4.4, 3.74, 4.48, 4.26, 4.34, 4.39, 4.02, 4.24, 4.15, 4.22, 4.27, 4.12, 3.89, 3.94, 4.04, 3.95, 4.2, 3.8, 4.24, 4.05, 4.09, 3.97, 4.19, 3.99, 3.72, 4.04, 4.2, 4.07, 3.89, 4.05, 3.87, 3.96, 4.16, 4.17, 3.88, 3.89, 4.07, 4.14, 3.81, 3.84, 3.75, 4.26]}, {"line": {"color": "#7F7F7F", "width": 4}, "name": "android Rating(with review)", "opacity": 0.8, "type": "scatter", "uid": "d91ee6bc-d5cd-4a69-90e4-35218f66fa39", "x": ["2018-04-30", "2018-05-07", "2018-05-14", "2018-05-21", "2018-05-28", "2018-06-04", "2018-06-11", "2018-06-18", "2018-06-25", "2018-07-02", "2018-07-09", "2018-07-16", "2018-07-23", "2018-07-30", "2018-08-06", "2018-08-13", "2018-08-20", "2018-08-27", "2018-09-03", "2018-09-10", "2018-09-17", "2018-09-24", "2018-10-01", "2018-10-08", "2018-10-15", "2018-10-22", "2018-10-29", "2018-11-05", "2018-11-12", "2018-11-19", "2018-11-26", "2018-12-03", "2018-12-10", "2018-12-17", "2018-12-24", "2018-12-31", "2019-01-07", "2019-01-14", "2019-01-21", "2019-01-28", "2019-02-04", "2019-02-11", "2019-02-18", "2019-02-25", "2019-03-04", "2019-03-11", "2019-03-18", "2019-03-25", "2019-04-01", "2019-04-08", "2019-04-15", "2019-04-22", "2019-04-29", "2019-05-06", "2019-05-13", "2019-05-20", "2019-05-27"], "y": [3.84, 3.99, 4.03, 3.82, 4.11, 3.99, 3.96, 3.96, 3.89, 3.97, 3.79, 3.84, 3.98, 3.82, 3.91, 4.0, 3.88, 4.0, 4.02, 3.95, 3.82, 4.06, 4.02, 4.02, 4.17, 4.15, 3.99, 3.97, 3.97, 3.79, 4.01, 3.93, 3.99, 3.65, 3.68, 3.65, 3.8, 3.72, 3.57, 3.68, 3.83, 3.86, 3.71, 3.87, 3.74, 3.8, 3.56, 3.82, 3.78, 3.92, 3.77, 3.75, 3.79, 3.87, 3.79, 3.69, 3.94]}],
#                         {"title": {"text": "iOS and Android weekly avg rating (with review texts)"}, "xaxis": {"range": ["2018-06-11", "2019-05-31"]}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('66b0993d-5f05-4d3a-93af-099eb51c3b4e');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
# monthly trend
trace_ios = go.Scatter(
                x=ios_monthly_rating.month_start,
                y=ios_monthly_rating["Rating_with_Review"],
                name = "iOS Rating(with review)",
                line = dict(color = '#17BECF', width = 4),
                opacity = 0.8)

trace_android = go.Scatter(
                x=android_monthly_rating.month_start,
                y=android_monthly_rating["Rating_with_Review"],
                name = "android Rating(with review)",
                line = dict(color = '#7F7F7F', width = 4),
                opacity = 0.8)

data = [trace_ios,trace_android]

layout = dict(
    title = "iOS and Android monthly avg rating (with review texts)",
    xaxis = dict(
        range = ['2018-06-11','2019-05-31'])
)

fig = dict(data=data, layout=layout)
py.iplot(fig, filename = "Manually Set Range")
# Out:
# <div>
#
#
#             <div id="41333e7b-a29d-4690-9c7b-3cd5d9c08c3e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("41333e7b-a29d-4690-9c7b-3cd5d9c08c3e")) {
#                     Plotly.newPlot(
#                         '41333e7b-a29d-4690-9c7b-3cd5d9c08c3e',
#                         [{"line": {"color": "#17BECF", "width": 4}, "name": "iOS Rating(with review)", "opacity": 0.8, "type": "scatter", "uid": "2069845a-9fe9-4046-9d07-bc01eabf68f5", "x": ["2018-05-01", "2018-06-01", "2018-07-01", "2018-08-01", "2018-09-01", "2018-10-01", "2018-11-01", "2018-12-01", "2019-01-01", "2019-02-01", "2019-03-01", "2019-04-01", "2019-05-01"], "y": [2.6, 4.73, 4.76, 4.39, 4.3, 4.21, 3.99, 4.05, 4.0, 4.04, 4.0, 4.03, 3.93]}, {"line": {"color": "#7F7F7F", "width": 4}, "name": "android Rating(with review)", "opacity": 0.8, "type": "scatter", "uid": "b679b20e-8f71-4a7e-90f7-477803395d1a", "x": ["2018-05-01", "2018-06-01", "2018-07-01", "2018-08-01", "2018-09-01", "2018-10-01", "2018-11-01", "2018-12-01", "2019-01-01", "2019-02-01", "2019-03-01", "2019-04-01", "2019-05-01"], "y": [3.93, 3.98, 3.89, 3.93, 3.98, 4.07, 3.95, 3.84, 3.71, 3.77, 3.76, 3.81, 3.81]}],
#                         {"title": {"text": "iOS and Android monthly avg rating (with review texts)"}, "xaxis": {"range": ["2018-06-11", "2019-05-31"]}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('41333e7b-a29d-4690-9c7b-3cd5d9c08c3e');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
#Dow
ios = pd.DataFrame(df_as_kindle_05_18_05_19.groupby("dow").mean()["Rating"]).reset_index()
ios["Rating_with_Review"] = ios["Rating"].apply(lambda x: round(x,2))
android = pd.DataFrame(df_gp_kindle_05_18_05_19.groupby("dow").mean()["Rating"]).reset_index()
android["Rating_with_Review"] = android["Rating"].apply(lambda x: round(x,2))
merged = ios.merge(android, on = "dow", suffixes = ("_ios","_andorid") )
merged.drop(["Rating_ios","Rating_andorid"],axis=1,inplace=True)
merged["diff"] = (merged["Rating_with_Review_ios"] - merged["Rating_with_Review_andorid"]) / merged["Rating_with_Review_ios"] * 100
merged.sort_values("diff",ascending=False)
# Out:
#    dow  Rating_with_Review_ios  Rating_with_Review_andorid       diff
# 6  Wed                    4.64                        3.82  17.672414
# 4  Thu                    4.56                        3.84  15.789474
# 0  Fri                    4.58                        3.91  14.628821
# 2  Sat                    4.55                        3.93  13.626374
# 3  Sun                    4.44                        3.90  12.162162
# 1  Mon                    4.35                        3.84  11.724138
# 5  Tue                    4.34                        3.89  10.368664

# %% [markdown]
# Word Bagging

# %%
import re
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk import FreqDist
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\YC\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\YC\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#Define stopwords
sw = stopwords.words('english')
addition = ["a","kindle","at","it","there","and","to","s","would","e","x","k","n","r"] #adding more
for i in range(len(addition)):
    sw.append(addition[i])

# %%
#Preserve Review for vader

#for sentiment shifts

#remove non alphabets
df_as_kindle_05_18_05_19["Review1"] = df_as_kindle_05_18_05_19['Review'].replace(to_replace="[^A-Za-z]", value=r" ", regex=True)
df_gp_kindle_05_18_05_19["Review1"] = df_gp_kindle_05_18_05_19['Review'].replace(to_replace="[^A-Za-z]", value=r" ", regex=True)

#convert to lowercase
df_as_kindle_05_18_05_19["Review1"] = df_as_kindle_05_18_05_19["Review1"].str.lower()
df_gp_kindle_05_18_05_19["Review1"] = df_gp_kindle_05_18_05_19["Review1"].str.lower()

# %%
#tokenize
df_as_kindle_05_18_05_19['Review1_tok'] = df_as_kindle_05_18_05_19['Review1'].apply(word_tokenize)
df_gp_kindle_05_18_05_19['Review1_tok'] = df_gp_kindle_05_18_05_19['Review1'].apply(word_tokenize)

# %%
#hand pick review words
#get frequency of words

#ios

pd.options.display.max_rows = 10000
pd.options.display.max_columns = 10000

txt = df_as_kindle_05_18_05_19["Review1"].str.lower().str.replace(r'\|', ' ').str.cat(sep=' ')
words = nltk.tokenize.word_tokenize(txt)
word_dist = nltk.FreqDist(words)

top_N = 10000

words_except_stop_dist = nltk.FreqDist(w for w in words if w not in sw) 

# print('iOS All frequencies, including STOPWORDS:')
# print('=' * 60)
# rslt_ios = pd.DataFrame(word_dist.most_common(top_N),
#                     columns=['Word', 'Frequency'])
# print(rslt)
# print('=' * 60)

rslt_ios = pd.DataFrame(words_except_stop_dist.most_common(top_N),
                    columns=['Word', 'Frequency']).set_index('Word')

path = r'C:/Users/YC/portfolio/case_study/kindle_app_reviews/'
#rslt_ios.to_csv(os.path.join(path,r'_ios_word_freq.csv'))

# %%
#without stop words
print('iOS All frequencies, excluding STOPWORDS:')
print('=' * 60)
print(rslt)
# Out:
# iOS All frequencies, excluding STOPWORDS:
# ============================================================
#                                                     Frequency
# Word
# app                                                      7388
# books                                                    3427
# good                                                     3177
# love                                                     2546
# read                                                     2046
# book                                                     1874
# nice                                                     1514
# reading                                                  1474
# great                                                    1474
# like                                                     1090
# amazon                                                    997
# use                                                       924
# download                                                  866
# best                                                      843
# phone                                                     819
# get                                                       726
# time                                                      707
# free                                                      615
# awesome                                                   604
# update                                                    597
# one                                                       580
# even                                                      554
# want                                                      531
# really                                                    510
# please                                                    509
# amazing                                                   495
# library                                                   430
# much                                                      426
# easy                                                      409
# go                                                        408
# new                                                       407
# page                                                      393
# open                                                      380
# work                                                      361
# way                                                       358
# bad                                                       356
# every                                                     345
# buy                                                       340
# excellent                                                 340
# many                                                      338
# back                                                      333
# ever                                                      326
# better                                                    321
# also                                                      321
# still                                                     320
# able                                                      315
# fix                                                       314
# keeps                                                     307
# need                                                      305
# android                                                   293
# used                                                      289
# thanks                                                    282
# tablet                                                    281
# find                                                      280
# device                                                    280
# ok                                                        278
# apps                                                      276
# useful                                                    276
# reader                                                    274
# using                                                     270
# without                                                   264
# store                                                     262
# let                                                       261
# could                                                     256
# screen                                                    256
# option                                                    255
# downloaded                                                252
# never                                                     252
# works                                                     250
# know                                                      248
# think                                                     238
# account                                                   233
# well                                                      231
# u                                                         230
# unlimited                                                 226
# see                                                       225
# access                                                    221
# problem                                                   221
# try                                                       216
# working                                                   216
# give                                                      216
# keep                                                      212
# always                                                    210
# since                                                     210
# last                                                      209
# make                                                      208
# add                                                       204
# available                                                 202
# version                                                   199
# lot                                                       199
# worst                                                     195
# uninstall                                                 194
# wish                                                      194
# help                                                      194
# hate                                                      192
# sync                                                      192
# devices                                                   191
# thank                                                     190
# super                                                     188
# money                                                     187
# loved                                                     181
# feature                                                   176
# stars                                                     176
# change                                                    175
# experience                                                175
# text                                                      174
# prime                                                     173
# tried                                                     169
# pages                                                     168
# years                                                     166
# google                                                    166
# downloading                                               165
# cool                                                      162
# got                                                       158
# install                                                   157
# times                                                     157
# nothing                                                   156
# everything                                                152
# dont                                                      148
# card                                                      146
# going                                                     145
# purchased                                                 145
# anything                                                  144
# helpful                                                   143
# readers                                                   142
# waste                                                     141
# crashes                                                   141
# anywhere                                                  141
# makes                                                     140
# wonderful                                                 139
# bought                                                    137
# thing                                                     137
# day                                                       137
# cant                                                      137
# enjoy                                                     135
# take                                                      133
# us                                                        133
# people                                                    132
# fine                                                      132
# issue                                                     132
# pay                                                       131
# delete                                                    130
# getting                                                   129
# annoying                                                  128
# application                                               127
# play                                                      127
# trying                                                    126
# search                                                    125
# happy                                                     124
# purchase                                                  124
# already                                                   122
# dictionary                                                122
# needs                                                     121
# ebooks                                                    121
# right                                                     120
# useless                                                   120
# unable                                                    119
# crashing                                                  117
# first                                                     116
# samsung                                                   116
# latest                                                    115
# something                                                 114
# space                                                     114
# ebook                                                     114
# user                                                      112
# issues                                                    110
# though                                                    110
# home                                                      110
# perfect                                                   109
# reinstall                                                 109
# says                                                      108
# uninstalled                                               108
# made                                                      107
# service                                                   107
# mode                                                      106
# longer                                                    106
# sign                                                      105
# full                                                      104
# aap                                                       102
# load                                                      102
# sucks                                                     102
# must                                                      102
# frustrating                                               102
# superb                                                    101
# different                                                 101
# night                                                     101
# content                                                   101
# absolutely                                                101
# far                                                       101
# yet                                                       100
# fantastic                                                  99
# old                                                        99
# sure                                                       98
# things                                                     98
# turn                                                       98
# installed                                                  96
# say                                                        96
# password                                                   95
# problems                                                   95
# remove                                                     95
# click                                                      94
# instead                                                    93
# long                                                       93
# star                                                       93
# wow                                                        92
# slow                                                       91
# takes                                                      91
# audible                                                    90
# hard                                                       90
# audio                                                      90
# another                                                    90
# stop                                                       89
# data                                                       89
# features                                                   89
# language                                                   89
# favorite                                                   89
# reason                                                     88
# ads                                                        88
# word                                                       88
# allow                                                      88
# recommend                                                  87
# updates                                                    87
# list                                                       87
# error                                                      86
# show                                                       86
# stopped                                                    86
# start                                                      86
# font                                                       85
# opening                                                    84
# customer                                                   84
# sd                                                         84
# galaxy                                                     83
# world                                                      82
# mobile                                                     82
# constantly                                                 82
# im                                                         82
# updated                                                    81
# options                                                    81
# done                                                       79
# knowledge                                                  78
# seems                                                      78
# look                                                       77
# put                                                        77
# button                                                     77
# etc                                                        77
# convenient                                                 76
# stories                                                    76
# words                                                      75
# enough                                                     75
# choose                                                     75
# support                                                    75
# ability                                                    75
# settings                                                   74
# paid                                                       74
# sometimes                                                  74
# several                                                    74
# collection                                                 73
# scrolling                                                  73
# life                                                       73
# review                                                     73
# actually                                                   73
# friendly                                                   73
# days                                                       72
# found                                                      72
# stupid                                                     72
# wont                                                       72
# started                                                    71
# helps                                                      71
# log                                                        71
# place                                                      71
# tell                                                       70
# whole                                                      70
# fixed                                                      70
# kids                                                       69
# worked                                                     69
# interesting                                                69
# easily                                                     69
# scroll                                                     69
# two                                                        68
# left                                                       68
# hope                                                       68
# brightness                                                 67
# lots                                                       67
# note                                                       67
# l                                                          67
# pretty                                                     67
# soon                                                       67
# around                                                     66
# everyone                                                   66
# speech                                                     66
# lost                                                       66
# anymore                                                    65
# learn                                                      65
# completely                                                 65
# fire                                                       65
# simply                                                     65
# english                                                    65
# wanted                                                     65
# come                                                       65
# often                                                      65
# number                                                     64
# buying                                                     64
# poor                                                       64
# gets                                                       64
# months                                                     64
# children                                                   64
# lovers                                                     64
# horrible                                                   64
# easier                                                     63
# size                                                       63
# authors                                                    63
# almost                                                     62
# goes                                                       62
# sample                                                     62
# real                                                       61
# interface                                                  61
# saying                                                     61
# study                                                      61
# next                                                       60
# especially                                                 60
# looking                                                    60
# liked                                                      60
# anytime                                                    60
# month                                                      60
# set                                                        59
# notification                                               59
# least                                                      59
# background                                                 59
# said                                                       59
# little                                                     58
# close                                                      58
# selection                                                  58
# carry                                                      58
# showing                                                    58
# difficult                                                  58
# learning                                                   58
# taking                                                     57
# message                                                    57
# subscription                                               57
# stuck                                                      57
# email                                                      57
# function                                                   57
# otherwise                                                  56
# properly                                                   56
# huge                                                       56
# feel                                                       56
# else                                                       55
# guys                                                       55
# samples                                                    55
# terrible                                                   55
# however                                                    55
# g                                                          55
# freezes                                                    55
# stuff                                                      55
# recently                                                   55
# students                                                   55
# storage                                                    55
# less                                                       55
# send                                                       55
# notes                                                      55
# allows                                                     55
# job                                                        54
# shows                                                      54
# kind                                                       54
# big                                                        54
# pdf                                                        54
# away                                                       54
# internet                                                   54
# okay                                                       53
# impossible                                                 53
# wrong                                                      53
# deleted                                                    53
# everytime                                                  53
# view                                                       53
# making                                                     53
# multiple                                                   53
# hi                                                         53
# recent                                                     52
# totally                                                    52
# automatically                                              52
# thought                                                    52
# gone                                                       52
# black                                                      52
# rating                                                     52
# notifications                                              52
# save                                                       51
# gives                                                      51
# plus                                                       51
# later                                                      51
# story                                                      50
# worth                                                      50
# login                                                      50
# reinstalled                                                50
# loading                                                    50
# sort                                                       49
# tab                                                        49
# hours                                                      49
# couple                                                     49
# possible                                                   49
# order                                                      49
# collections                                                49
# whenever                                                   49
# finally                                                    49
# downloads                                                  48
# given                                                      48
# color                                                      48
# fun                                                        48
# changed                                                    48
# overall                                                    48
# quite                                                      48
# return                                                     48
# missing                                                    48
# simple                                                     48
# location                                                   48
# improve                                                    47
# top                                                        47
# setting                                                    46
# worse                                                      46
# live                                                       46
# brilliant                                                  46
# online                                                     46
# year                                                       46
# understand                                                 46
# uninstalling                                               46
# single                                                     46
# price                                                      45
# needed                                                     45
# choice                                                     45
# previous                                                   45
# highlight                                                  45
# small                                                      45
# battery                                                    45
# ios                                                        45
# end                                                        45
# ago                                                        44
# provide                                                    44
# disappointed                                               44
# school                                                     44
# titles                                                     44
# leave                                                      44
# wifi                                                       43
# seen                                                       43
# p                                                          43
# files                                                      43
# point                                                      43
# prices                                                     43
# five                                                       43
# forever                                                    42
# plz                                                        42
# broken                                                     42
# listen                                                     42
# force                                                      42
# hindi                                                      42
# reviews                                                    42
# except                                                     42
# across                                                     42
# waiting                                                    41
# ask                                                        41
# today                                                      41
# write                                                      41
# type                                                       41
# switch                                                     41
# either                                                     41
# novels                                                     41
# de                                                         41
# landscape                                                  41
# added                                                      41
# white                                                      41
# dark                                                       41
# unless                                                     40
# part                                                       40
# syncing                                                    40
# menu                                                       40
# past                                                       40
# become                                                     40
# current                                                    40
# c                                                          40
# others                                                     40
# lovely                                                     40
# everywhere                                                 40
# offline                                                    39
# check                                                      39
# move                                                       39
# company                                                    39
# select                                                     39
# system                                                     39
# removed                                                    39
# yes                                                        39
# users                                                      39
# half                                                       39
# reset                                                      39
# fast                                                       39
# fact                                                       39
# light                                                      38
# via                                                        38
# bit                                                        38
# comics                                                     38
# week                                                       38
# trial                                                      38
# idea                                                       38
# v                                                          38
# highlights                                                 38
# trouble                                                    38
# rather                                                     38
# w                                                          38
# maybe                                                      38
# wait                                                       37
# took                                                       37
# gave                                                       37
# wishlist                                                   37
# minutes                                                    37
# reinstalling                                               37
# bug                                                        37
# h                                                          37
# continuous                                                 37
# information                                                36
# auto                                                       36
# matter                                                     36
# shopping                                                   36
# purchases                                                  36
# lol                                                        36
# prefer                                                     36
# pocket                                                     36
# syncs                                                      36
# pain                                                       36
# ones                                                       36
# unfortunately                                              36
# mb                                                         36
# turning                                                    36
# author                                                     36
# title                                                      36
# reads                                                      36
# installing                                                 35
# important                                                  35
# eyes                                                       35
# seem                                                       35
# icon                                                       35
# hai                                                        35
# unusable                                                   35
# boring                                                     35
# fabulous                                                   35
# awsome                                                     35
# happened                                                   35
# bookmarks                                                  35
# rate                                                       35
# series                                                     35
# anyone                                                     35
# handy                                                      35
# credit                                                     34
# might                                                      34
# favourite                                                  34
# giving                                                     34
# finish                                                     34
# whatever                                                   34
# definitely                                                 34
# went                                                       34
# touch                                                      34
# large                                                      34
# paper                                                      34
# pc                                                         34
# progress                                                   34
# low                                                        33
# crash                                                      33
# bar                                                        33
# quick                                                      33
# someone                                                    33
# nyc                                                        33
# may                                                        33
# garbage                                                    33
# phones                                                     33
# b                                                          33
# cost                                                       33
# format                                                     33
# paperwhite                                                 33
# carousel                                                   33
# digital                                                    33
# share                                                      33
# guess                                                      33
# fingertips                                                 33
# membership                                                 33
# fonts                                                      33
# na                                                         33
# bright                                                     32
# doesnt                                                     32
# mind                                                       32
# copy                                                       32
# genre                                                      32
# gud                                                        32
# pop                                                        32
# extremely                                                  32
# run                                                        32
# filter                                                     32
# portrait                                                   32
# connection                                                 32
# clear                                                      32
# f                                                          32
# payment                                                    32
# th                                                         32
# alot                                                       32
# lenovo                                                     32
# non                                                        31
# code                                                       31
# complete                                                   31
# cancel                                                     31
# interested                                                 31
# tablets                                                    31
# improved                                                   31
# website                                                    31
# game                                                       31
# none                                                       31
# recommendations                                            31
# rid                                                        31
# rubbish                                                    31
# bring                                                      31
# memory                                                     31
# weeks                                                      31
# navigate                                                   31
# tap                                                        31
# spend                                                      30
# irritating                                                 30
# beautiful                                                  30
# j                                                          30
# zoom                                                       30
# blank                                                      30
# currently                                                  30
# highly                                                     30
# asking                                                     30
# chapter                                                    30
# computer                                                   30
# enable                                                     30
# loving                                                     30
# enjoyed                                                    30
# amount                                                     30
# suggestions                                                29
# sorry                                                      29
# items                                                      29
# disabled                                                   29
# ridiculous                                                 29
# loads                                                      29
# novel                                                      29
# bugs                                                       29
# happens                                                    28
# redownload                                                 28
# restart                                                    28
# seriously                                                  28
# bookmark                                                   28
# que                                                        28
# remember                                                   28
# miss                                                       28
# means                                                      28
# lose                                                       28
# told                                                       28
# forced                                                     28
# request                                                    28
# opened                                                     28
# site                                                       28
# speed                                                      28
# frustrated                                                 28
# numbers                                                    28
# high                                                       27
# charged                                                    27
# limited                                                    27
# wherever                                                   27
# cause                                                      27
# running                                                    27
# ur                                                         27
# pro                                                        27
# per                                                        27
# hell                                                       27
# osm                                                        27
# correct                                                    27
# buggy                                                      27
# actual                                                     27
# name                                                       27
# process                                                    27
# family                                                     27
# refuses                                                    27
# hated                                                      27
# due                                                        27
# middle                                                     27
# paying                                                     27
# japanese                                                   27
# friend                                                     26
# came                                                       26
# spent                                                      26
# ui                                                         26
# hand                                                       26
# freezing                                                   26
# developers                                                 26
# member                                                     26
# telling                                                    26
# intuitive                                                  26
# turned                                                     26
# yeah                                                       26
# main                                                       26
# file                                                       25
# create                                                     25
# total                                                      25
# along                                                      25
# probably                                                   25
# updating                                                   25
# ive                                                        25
# manually                                                   25
# uses                                                       25
# looks                                                      25
# stops                                                      25
# pick                                                       25
# appear                                                     25
# lets                                                       25
# upgrade                                                    25
# although                                                   25
# onto                                                       25
# india                                                      25
# care                                                       25
# basic                                                      25
# class                                                      25
# closes                                                     25
# within                                                     25
# software                                                   25
# carrying                                                   25
# suddenly                                                   25
# line                                                       25
# oh                                                         25
# lately                                                     25
# changing                                                   25
# forward                                                    25
# improvement                                                24
# apparently                                                 24
# daily                                                      24
# comes                                                      24
# faster                                                     24
# bottom                                                     24
# section                                                    24
# lover                                                      24
# luv                                                        24
# disappeared                                                24
# supposed                                                   24
# browser                                                    24
# physical                                                   24
# avid                                                       24
# adds                                                       24
# literally                                                  24
# adding                                                     24
# info                                                       24
# randomly                                                   24
# forget                                                     24
# older                                                      24
# bakwas                                                     23
# deleting                                                   23
# debit                                                      23
# sell                                                       23
# music                                                      23
# program                                                    23
# wants                                                      23
# correctly                                                  23
# limit                                                      23
# previously                                                 23
# hassle                                                     23
# press                                                      23
# hundreds                                                   23
# outstanding                                                23
# flip                                                       23
# offer                                                      23
# accounts                                                   23
# date                                                       23
# refund                                                     23
# nook                                                       23
# nd                                                         22
# seconds                                                    22
# damn                                                       22
# ...
# baaaaaad                                                    1
# grsat                                                       1
# suppwr                                                      1
# ctrl                                                        1
# auideo                                                      1
# alll                                                        1
# freash                                                      1
# intressting                                                 1
# sycning                                                     1
# chatty                                                      1
# configuration                                               1
# configurable                                                1
# atification                                                 1
# patrica                                                     1
# cornwells                                                   1
# chand                                                       1
# fussy                                                       1
# racket                                                      1
# switcher                                                    1
# hotstar                                                     1
# favoritest                                                  1
# dox                                                         1
# talented                                                    1
# golly                                                       1
# bajeezus                                                    1
# boyfriends                                                  1
# spreadsheet                                                 1
# dhjb                                                        1
# tolerate                                                    1
# muh                                                         1
# unwillingly                                                 1
# immoral                                                     1
# dressing                                                    1
# vest                                                        1
# rows                                                        1
# spoilt                                                      1
# warranty                                                    1
# thanksgiving                                                1
# bestfriend                                                  1
# savior                                                      1
# ward                                                        1
# preordered                                                  1
# noe                                                         1
# theclse                                                     1
# roshan                                                      1
# dandsena                                                    1
# nhai                                                        1
# pasand                                                      1
# rh                                                          1
# uska                                                        1
# dikhaaty                                                    1
# mang                                                        1
# rhy                                                         1
# owning                                                      1
# freeprimebook                                               1
# dhoni                                                       1
# crickettips                                                 1
# motivated                                                   1
# watseofmoney                                                1
# nochooseoption                                              1
# foolingsus                                                  1
# nocompetitionbook                                           1
# poorquality                                                 1
# everytimesamehappen                                         1
# thiss                                                       1
# booklibrary                                                 1
# knowle                                                      1
# dge                                                         1
# histry                                                      1
# recieved                                                    1
# wonderous                                                   1
# fantabulious                                                1
# syncronizing                                                1
# uuuyuuuyyyuycu                                              1
# nnnnnn                                                      1
# psychology                                                  1
# belongs                                                     1
# bmm                                                         1
# kannda                                                      1
# serv                                                        1
# finsh                                                       1
# toc                                                         1
# betrayl                                                     1
# seee                                                        1
# prerpbrrpr                                                  1
# rrbr                                                        1
# enbn                                                        1
# paj                                                         1
# subfolders                                                  1
# wh                                                          1
# creed                                                       1
# training                                                    1
# phadu                                                       1
# bai                                                         1
# rings                                                       1
# kanna                                                       1
# bhaija                                                      1
# vjjuk                                                       1
# acted                                                       1
# shortly                                                     1
# washingwet                                                  1
# udikd                                                       1
# thaks                                                       1
# reappears                                                   1
# boht                                                        1
# cooll                                                       1
# sshit                                                       1
# dumbest                                                     1
# rekiability                                                 1
# yuu                                                         1
# wgg                                                         1
# ggu                                                         1
# fwm                                                         1
# oppo                                                        1
# era                                                         1
# malapart                                                    1
# artaud                                                      1
# byron                                                       1
# fanu                                                        1
# beckett                                                     1
# james                                                       1
# joyce                                                       1
# zora                                                        1
# neal                                                        1
# hurston                                                     1
# maya                                                        1
# anjelu                                                      1
# appetite                                                    1
# instal                                                      1
# blu                                                         1
# verygood                                                    1
# spr                                                         1
# deduct                                                      1
# aplgg                                                       1
# shelfing                                                    1
# puzzle                                                      1
# solves                                                      1
# surprize                                                    1
# bmc                                                         1
# boin                                                        1
# ov                                                          1
# wou                                                         1
# nuld                                                        1
# saibd                                                       1
# decreasing                                                  1
# otimos                                                      1
# luij                                                        1
# inn                                                         1
# ummj                                                        1
# iouvi                                                       1
# kllmupimmmm                                                 1
# bl                                                          1
# increases                                                   1
# simly                                                       1
# worat                                                       1
# oooooooooooooooooooooddddddddded                            1
# sandra                                                      1
# tusssss                                                     1
# negation                                                    1
# haunt                                                       1
# rada                                                        1
# shovelware                                                  1
# bhut                                                        1
# creep                                                       1
# identify                                                    1
# optimal                                                     1
# cooperative                                                 1
# horasious                                                   1
# cooollll                                                    1
# optimise                                                    1
# suppport                                                    1
# turner                                                      1
# simulation                                                  1
# llllllllllooollllllllllllllllllll                           1
# llf                                                         1
# jrs                                                         1
# depend                                                      1
# minimalistic                                                1
# aau                                                         1
# estuve                                                      1
# desinstal                                                   1
# datos                                                       1
# cobrado                                                     1
# dos                                                         1
# despu                                                       1
# avisarme                                                    1
# carg                                                        1
# ndolo                                                       1
# cuenta                                                      1
# dekhate                                                     1
# tires                                                       1
# jharna                                                      1
# sarkar                                                      1
# roshnipasi                                                  1
# payements                                                   1
# buts                                                        1
# summaries                                                   1
# favirete                                                    1
# relate                                                      1
# interests                                                   1
# questionable                                                1
# objectionable                                               1
# downright                                                   1
# displeasure                                                 1
# ccouldn                                                     1
# interact                                                    1
# explaining                                                  1
# puper                                                       1
# unpdate                                                     1
# butty                                                       1
# googles                                                     1
# brieeggs                                                    1
# ua                                                          1
# guyg                                                        1
# qfttey                                                      1
# pyler                                                       1
# gaaaa                                                       1
# rudy                                                        1
# rre                                                         1
# yeee                                                        1
# feet                                                        1
# bhhurt                                                      1
# euryeurya                                                   1
# sp                                                          1
# tqq                                                         1
# itu                                                         1
# fe                                                          1
# awee                                                        1
# tuyr                                                        1
# rehhhhhhhls                                                 1
# chr                                                         1
# trtrt                                                       1
# riederrrrt                                                  1
# err                                                         1
# vg                                                          1
# sethu                                                       1
# iski                                                        1
# chodo                                                       1
# jhaatu                                                      1
# chutiyapa                                                   1
# ra                                                          1
# bancho                                                      1
# caverns                                                     1
# recognized                                                  1
# intentionaly                                                1
# offending                                                   1
# abusive                                                     1
# groth                                                       1
# stuvk                                                       1
# copycat                                                     1
# disguise                                                    1
# xico                                                        1
# reminds                                                     1
# cassette                                                    1
# tape                                                        1
# wseetax                                                     1
# ow                                                          1
# whis                                                        1

# %%
#hand pick review words to associate with the score (1~5)
#get frequency of words

#Android

pd.options.display.max_rows = 10000
pd.options.display.max_columns = 10000

txt = df_gp_kindle_05_18_05_19["Review1"].str.lower().str.replace(r'\|', ' ').str.cat(sep=' ')
words = nltk.tokenize.word_tokenize(txt)
word_dist = nltk.FreqDist(words)

top_N = 10000

words_except_stop_dist = nltk.FreqDist(w for w in words if w not in sw) 

# print('Android All frequencies, including STOPWORDS:')
# print('=' * 60)
# rslt_android = pd.DataFrame(word_dist.most_common(top_N),
#                     columns=['Word', 'Frequency'])
# print(rslt_android)
# print('=' * 60)

rslt_android = pd.DataFrame(words_except_stop_dist.most_common(top_N),
                    columns=['Word', 'Frequency']).set_index('Word')

path = r'C:/Users/YC/portfolio/case_study/kindle_app_reviews/'
#rslt_android.to_csv(os.path.join(path,r'_android_word_freq.csv'))

# %%
#without stop words
print('Android All frequencies, excluding STOPWORDS:')
print('=' * 60)
print(rslt_android)
# Out:
# Android All frequencies, excluding STOPWORDS:
# ============================================================
#                                                     Frequency
# Word
# app                                                      7388
# books                                                    3427
# good                                                     3177
# love                                                     2546
# read                                                     2046
# book                                                     1874
# nice                                                     1514
# reading                                                  1474
# great                                                    1474
# like                                                     1090
# amazon                                                    997
# use                                                       924
# download                                                  866
# best                                                      843
# phone                                                     819
# get                                                       726
# time                                                      707
# free                                                      615
# awesome                                                   604
# update                                                    597
# one                                                       580
# even                                                      554
# want                                                      531
# really                                                    510
# please                                                    509
# amazing                                                   495
# library                                                   430
# much                                                      426
# easy                                                      409
# go                                                        408
# new                                                       407
# page                                                      393
# open                                                      380
# work                                                      361
# way                                                       358
# bad                                                       356
# every                                                     345
# buy                                                       340
# excellent                                                 340
# many                                                      338
# back                                                      333
# ever                                                      326
# better                                                    321
# also                                                      321
# still                                                     320
# able                                                      315
# fix                                                       314
# keeps                                                     307
# need                                                      305
# android                                                   293
# used                                                      289
# thanks                                                    282
# tablet                                                    281
# find                                                      280
# device                                                    280
# ok                                                        278
# apps                                                      276
# useful                                                    276
# reader                                                    274
# using                                                     270
# without                                                   264
# store                                                     262
# let                                                       261
# could                                                     256
# screen                                                    256
# option                                                    255
# downloaded                                                252
# never                                                     252
# works                                                     250
# know                                                      248
# think                                                     238
# account                                                   233
# well                                                      231
# u                                                         230
# unlimited                                                 226
# see                                                       225
# access                                                    221
# problem                                                   221
# try                                                       216
# working                                                   216
# give                                                      216
# keep                                                      212
# always                                                    210
# since                                                     210
# last                                                      209
# make                                                      208
# add                                                       204
# available                                                 202
# version                                                   199
# lot                                                       199
# worst                                                     195
# uninstall                                                 194
# wish                                                      194
# help                                                      194
# hate                                                      192
# sync                                                      192
# devices                                                   191
# thank                                                     190
# super                                                     188
# money                                                     187
# loved                                                     181
# feature                                                   176
# stars                                                     176
# change                                                    175
# experience                                                175
# text                                                      174
# prime                                                     173
# tried                                                     169
# pages                                                     168
# years                                                     166
# google                                                    166
# downloading                                               165
# cool                                                      162
# got                                                       158
# install                                                   157
# times                                                     157
# nothing                                                   156
# everything                                                152
# dont                                                      148
# card                                                      146
# going                                                     145
# purchased                                                 145
# anything                                                  144
# helpful                                                   143
# readers                                                   142
# waste                                                     141
# crashes                                                   141
# anywhere                                                  141
# makes                                                     140
# wonderful                                                 139
# bought                                                    137
# thing                                                     137
# day                                                       137
# cant                                                      137
# enjoy                                                     135
# take                                                      133
# us                                                        133
# people                                                    132
# fine                                                      132
# issue                                                     132
# pay                                                       131
# delete                                                    130
# getting                                                   129
# annoying                                                  128
# application                                               127
# play                                                      127
# trying                                                    126
# search                                                    125
# happy                                                     124
# purchase                                                  124
# already                                                   122
# dictionary                                                122
# needs                                                     121
# ebooks                                                    121
# right                                                     120
# useless                                                   120
# unable                                                    119
# crashing                                                  117
# first                                                     116
# samsung                                                   116
# latest                                                    115
# something                                                 114
# space                                                     114
# ebook                                                     114
# user                                                      112
# issues                                                    110
# though                                                    110
# home                                                      110
# perfect                                                   109
# reinstall                                                 109
# says                                                      108
# uninstalled                                               108
# made                                                      107
# service                                                   107
# mode                                                      106
# longer                                                    106
# sign                                                      105
# full                                                      104
# aap                                                       102
# load                                                      102
# sucks                                                     102
# must                                                      102
# frustrating                                               102
# superb                                                    101
# different                                                 101
# night                                                     101
# content                                                   101
# absolutely                                                101
# far                                                       101
# yet                                                       100
# fantastic                                                  99
# old                                                        99
# sure                                                       98
# things                                                     98
# turn                                                       98
# installed                                                  96
# say                                                        96
# password                                                   95
# problems                                                   95
# remove                                                     95
# click                                                      94
# instead                                                    93
# long                                                       93
# star                                                       93
# wow                                                        92
# slow                                                       91
# takes                                                      91
# audible                                                    90
# hard                                                       90
# audio                                                      90
# another                                                    90
# stop                                                       89
# data                                                       89
# features                                                   89
# language                                                   89
# favorite                                                   89
# reason                                                     88
# ads                                                        88
# word                                                       88
# allow                                                      88
# recommend                                                  87
# updates                                                    87
# list                                                       87
# error                                                      86
# show                                                       86
# stopped                                                    86
# start                                                      86
# font                                                       85
# opening                                                    84
# customer                                                   84
# sd                                                         84
# galaxy                                                     83
# world                                                      82
# mobile                                                     82
# constantly                                                 82
# im                                                         82
# updated                                                    81
# options                                                    81
# done                                                       79
# knowledge                                                  78
# seems                                                      78
# look                                                       77
# put                                                        77
# button                                                     77
# etc                                                        77
# convenient                                                 76
# stories                                                    76
# words                                                      75
# enough                                                     75
# choose                                                     75
# support                                                    75
# ability                                                    75
# settings                                                   74
# paid                                                       74
# sometimes                                                  74
# several                                                    74
# collection                                                 73
# scrolling                                                  73
# life                                                       73
# review                                                     73
# actually                                                   73
# friendly                                                   73
# days                                                       72
# found                                                      72
# stupid                                                     72
# wont                                                       72
# started                                                    71
# helps                                                      71
# log                                                        71
# place                                                      71
# tell                                                       70
# whole                                                      70
# fixed                                                      70
# kids                                                       69
# worked                                                     69
# interesting                                                69
# easily                                                     69
# scroll                                                     69
# two                                                        68
# left                                                       68
# hope                                                       68
# brightness                                                 67
# lots                                                       67
# note                                                       67
# l                                                          67
# pretty                                                     67
# soon                                                       67
# around                                                     66
# everyone                                                   66
# speech                                                     66
# lost                                                       66
# anymore                                                    65
# learn                                                      65
# completely                                                 65
# fire                                                       65
# simply                                                     65
# english                                                    65
# wanted                                                     65
# come                                                       65
# often                                                      65
# number                                                     64
# buying                                                     64
# poor                                                       64
# gets                                                       64
# months                                                     64
# children                                                   64
# lovers                                                     64
# horrible                                                   64
# easier                                                     63
# size                                                       63
# authors                                                    63
# almost                                                     62
# goes                                                       62
# sample                                                     62
# real                                                       61
# interface                                                  61
# saying                                                     61
# study                                                      61
# next                                                       60
# especially                                                 60
# looking                                                    60
# liked                                                      60
# anytime                                                    60
# month                                                      60
# set                                                        59
# notification                                               59
# least                                                      59
# background                                                 59
# said                                                       59
# little                                                     58
# close                                                      58
# selection                                                  58
# carry                                                      58
# showing                                                    58
# difficult                                                  58
# learning                                                   58
# taking                                                     57
# message                                                    57
# subscription                                               57
# stuck                                                      57
# email                                                      57
# function                                                   57
# otherwise                                                  56
# properly                                                   56
# huge                                                       56
# feel                                                       56
# else                                                       55
# guys                                                       55
# samples                                                    55
# terrible                                                   55
# however                                                    55
# g                                                          55
# freezes                                                    55
# stuff                                                      55
# recently                                                   55
# students                                                   55
# storage                                                    55
# less                                                       55
# send                                                       55
# notes                                                      55
# allows                                                     55
# job                                                        54
# shows                                                      54
# kind                                                       54
# big                                                        54
# pdf                                                        54
# away                                                       54
# internet                                                   54
# okay                                                       53
# impossible                                                 53
# wrong                                                      53
# deleted                                                    53
# everytime                                                  53
# view                                                       53
# making                                                     53
# multiple                                                   53
# hi                                                         53
# recent                                                     52
# totally                                                    52
# automatically                                              52
# thought                                                    52
# gone                                                       52
# black                                                      52
# rating                                                     52
# notifications                                              52
# save                                                       51
# gives                                                      51
# plus                                                       51
# later                                                      51
# story                                                      50
# worth                                                      50
# login                                                      50
# reinstalled                                                50
# loading                                                    50
# sort                                                       49
# tab                                                        49
# hours                                                      49
# couple                                                     49
# possible                                                   49
# order                                                      49
# collections                                                49
# whenever                                                   49
# finally                                                    49
# downloads                                                  48
# given                                                      48
# color                                                      48
# fun                                                        48
# changed                                                    48
# overall                                                    48
# quite                                                      48
# return                                                     48
# missing                                                    48
# simple                                                     48
# location                                                   48
# improve                                                    47
# top                                                        47
# setting                                                    46
# worse                                                      46
# live                                                       46
# brilliant                                                  46
# online                                                     46
# year                                                       46
# understand                                                 46
# uninstalling                                               46
# single                                                     46
# price                                                      45
# needed                                                     45
# choice                                                     45
# previous                                                   45
# highlight                                                  45
# small                                                      45
# battery                                                    45
# ios                                                        45
# end                                                        45
# ago                                                        44
# provide                                                    44
# disappointed                                               44
# school                                                     44
# titles                                                     44
# leave                                                      44
# wifi                                                       43
# seen                                                       43
# p                                                          43
# files                                                      43
# point                                                      43
# prices                                                     43
# five                                                       43
# forever                                                    42
# plz                                                        42
# broken                                                     42
# listen                                                     42
# force                                                      42
# hindi                                                      42
# reviews                                                    42
# except                                                     42
# across                                                     42
# waiting                                                    41
# ask                                                        41
# today                                                      41
# write                                                      41
# type                                                       41
# switch                                                     41
# either                                                     41
# novels                                                     41
# de                                                         41
# landscape                                                  41
# added                                                      41
# white                                                      41
# dark                                                       41
# unless                                                     40
# part                                                       40
# syncing                                                    40
# menu                                                       40
# past                                                       40
# become                                                     40
# current                                                    40
# c                                                          40
# others                                                     40
# lovely                                                     40
# everywhere                                                 40
# offline                                                    39
# check                                                      39
# move                                                       39
# company                                                    39
# select                                                     39
# system                                                     39
# removed                                                    39
# yes                                                        39
# users                                                      39
# half                                                       39
# reset                                                      39
# fast                                                       39
# fact                                                       39
# light                                                      38
# via                                                        38
# bit                                                        38
# comics                                                     38
# week                                                       38
# trial                                                      38
# idea                                                       38
# v                                                          38
# highlights                                                 38
# trouble                                                    38
# rather                                                     38
# w                                                          38
# maybe                                                      38
# wait                                                       37
# took                                                       37
# gave                                                       37
# wishlist                                                   37
# minutes                                                    37
# reinstalling                                               37
# bug                                                        37
# h                                                          37
# continuous                                                 37
# information                                                36
# auto                                                       36
# matter                                                     36
# shopping                                                   36
# purchases                                                  36
# lol                                                        36
# prefer                                                     36
# pocket                                                     36
# syncs                                                      36
# pain                                                       36
# ones                                                       36
# unfortunately                                              36
# mb                                                         36
# turning                                                    36
# author                                                     36
# title                                                      36
# reads                                                      36
# installing                                                 35
# important                                                  35
# eyes                                                       35
# seem                                                       35
# icon                                                       35
# hai                                                        35
# unusable                                                   35
# boring                                                     35
# fabulous                                                   35
# awsome                                                     35
# happened                                                   35
# bookmarks                                                  35
# rate                                                       35
# series                                                     35
# anyone                                                     35
# handy                                                      35
# credit                                                     34
# might                                                      34
# favourite                                                  34
# giving                                                     34
# finish                                                     34
# whatever                                                   34
# definitely                                                 34
# went                                                       34
# touch                                                      34
# large                                                      34
# paper                                                      34
# pc                                                         34
# progress                                                   34
# low                                                        33
# crash                                                      33
# bar                                                        33
# quick                                                      33
# someone                                                    33
# nyc                                                        33
# may                                                        33
# garbage                                                    33
# phones                                                     33
# b                                                          33
# cost                                                       33
# format                                                     33
# paperwhite                                                 33
# carousel                                                   33
# digital                                                    33
# share                                                      33
# guess                                                      33
# fingertips                                                 33
# membership                                                 33
# fonts                                                      33
# na                                                         33
# bright                                                     32
# doesnt                                                     32
# mind                                                       32
# copy                                                       32
# genre                                                      32
# gud                                                        32
# pop                                                        32
# extremely                                                  32
# run                                                        32
# filter                                                     32
# portrait                                                   32
# connection                                                 32
# clear                                                      32
# f                                                          32
# payment                                                    32
# th                                                         32
# alot                                                       32
# lenovo                                                     32
# non                                                        31
# code                                                       31
# complete                                                   31
# cancel                                                     31
# interested                                                 31
# tablets                                                    31
# improved                                                   31
# website                                                    31
# game                                                       31
# none                                                       31
# recommendations                                            31
# rid                                                        31
# rubbish                                                    31
# bring                                                      31
# memory                                                     31
# weeks                                                      31
# navigate                                                   31
# tap                                                        31
# spend                                                      30
# irritating                                                 30
# beautiful                                                  30
# j                                                          30
# zoom                                                       30
# blank                                                      30
# currently                                                  30
# highly                                                     30
# asking                                                     30
# chapter                                                    30
# computer                                                   30
# enable                                                     30
# loving                                                     30
# enjoyed                                                    30
# amount                                                     30
# suggestions                                                29
# sorry                                                      29
# items                                                      29
# disabled                                                   29
# ridiculous                                                 29
# loads                                                      29
# novel                                                      29
# bugs                                                       29
# happens                                                    28
# redownload                                                 28
# restart                                                    28
# seriously                                                  28
# bookmark                                                   28
# que                                                        28
# remember                                                   28
# miss                                                       28
# means                                                      28
# lose                                                       28
# told                                                       28
# forced                                                     28
# request                                                    28
# opened                                                     28
# site                                                       28
# speed                                                      28
# frustrated                                                 28
# numbers                                                    28
# high                                                       27
# charged                                                    27
# limited                                                    27
# wherever                                                   27
# cause                                                      27
# running                                                    27
# ur                                                         27
# pro                                                        27
# per                                                        27
# hell                                                       27
# osm                                                        27
# correct                                                    27
# buggy                                                      27
# actual                                                     27
# name                                                       27
# process                                                    27
# family                                                     27
# refuses                                                    27
# hated                                                      27
# due                                                        27
# middle                                                     27
# paying                                                     27
# japanese                                                   27
# friend                                                     26
# came                                                       26
# spent                                                      26
# ui                                                         26
# hand                                                       26
# freezing                                                   26
# developers                                                 26
# member                                                     26
# telling                                                    26
# intuitive                                                  26
# turned                                                     26
# yeah                                                       26
# main                                                       26
# file                                                       25
# create                                                     25
# total                                                      25
# along                                                      25
# probably                                                   25
# updating                                                   25
# ive                                                        25
# manually                                                   25
# uses                                                       25
# looks                                                      25
# stops                                                      25
# pick                                                       25
# appear                                                     25
# lets                                                       25
# upgrade                                                    25
# although                                                   25
# onto                                                       25
# india                                                      25
# care                                                       25
# basic                                                      25
# class                                                      25
# closes                                                     25
# within                                                     25
# software                                                   25
# carrying                                                   25
# suddenly                                                   25
# line                                                       25
# oh                                                         25
# lately                                                     25
# changing                                                   25
# forward                                                    25
# improvement                                                24
# apparently                                                 24
# daily                                                      24
# comes                                                      24
# faster                                                     24
# bottom                                                     24
# section                                                    24
# lover                                                      24
# luv                                                        24
# disappeared                                                24
# supposed                                                   24
# browser                                                    24
# physical                                                   24
# avid                                                       24
# adds                                                       24
# literally                                                  24
# adding                                                     24
# info                                                       24
# randomly                                                   24
# forget                                                     24
# older                                                      24
# bakwas                                                     23
# deleting                                                   23
# debit                                                      23
# sell                                                       23
# music                                                      23
# program                                                    23
# wants                                                      23
# correctly                                                  23
# limit                                                      23
# previously                                                 23
# hassle                                                     23
# press                                                      23
# hundreds                                                   23
# outstanding                                                23
# flip                                                       23
# offer                                                      23
# accounts                                                   23
# date                                                       23
# refund                                                     23
# nook                                                       23
# nd                                                         22
# seconds                                                    22
# damn                                                       22
# ...
# baaaaaad                                                    1
# grsat                                                       1
# suppwr                                                      1
# ctrl                                                        1
# auideo                                                      1
# alll                                                        1
# freash                                                      1
# intressting                                                 1
# sycning                                                     1
# chatty                                                      1
# configuration                                               1
# configurable                                                1
# atification                                                 1
# patrica                                                     1
# cornwells                                                   1
# chand                                                       1
# fussy                                                       1
# racket                                                      1
# switcher                                                    1
# hotstar                                                     1
# favoritest                                                  1
# dox                                                         1
# talented                                                    1
# golly                                                       1
# bajeezus                                                    1
# boyfriends                                                  1
# spreadsheet                                                 1
# dhjb                                                        1
# tolerate                                                    1
# muh                                                         1
# unwillingly                                                 1
# immoral                                                     1
# dressing                                                    1
# vest                                                        1
# rows                                                        1
# spoilt                                                      1
# warranty                                                    1
# thanksgiving                                                1
# bestfriend                                                  1
# savior                                                      1
# ward                                                        1
# preordered                                                  1
# noe                                                         1
# theclse                                                     1
# roshan                                                      1
# dandsena                                                    1
# nhai                                                        1
# pasand                                                      1
# rh                                                          1
# uska                                                        1
# dikhaaty                                                    1
# mang                                                        1
# rhy                                                         1
# owning                                                      1
# freeprimebook                                               1
# dhoni                                                       1
# crickettips                                                 1
# motivated                                                   1
# watseofmoney                                                1
# nochooseoption                                              1
# foolingsus                                                  1
# nocompetitionbook                                           1
# poorquality                                                 1
# everytimesamehappen                                         1
# thiss                                                       1
# booklibrary                                                 1
# knowle                                                      1
# dge                                                         1
# histry                                                      1
# recieved                                                    1
# wonderous                                                   1
# fantabulious                                                1
# syncronizing                                                1
# uuuyuuuyyyuycu                                              1
# nnnnnn                                                      1
# psychology                                                  1
# belongs                                                     1
# bmm                                                         1
# kannda                                                      1
# serv                                                        1
# finsh                                                       1
# toc                                                         1
# betrayl                                                     1
# seee                                                        1
# prerpbrrpr                                                  1
# rrbr                                                        1
# enbn                                                        1
# paj                                                         1
# subfolders                                                  1
# wh                                                          1
# creed                                                       1
# training                                                    1
# phadu                                                       1
# bai                                                         1
# rings                                                       1
# kanna                                                       1
# bhaija                                                      1
# vjjuk                                                       1
# acted                                                       1
# shortly                                                     1
# washingwet                                                  1
# udikd                                                       1
# thaks                                                       1
# reappears                                                   1
# boht                                                        1
# cooll                                                       1
# sshit                                                       1
# dumbest                                                     1
# rekiability                                                 1
# yuu                                                         1
# wgg                                                         1
# ggu                                                         1
# fwm                                                         1
# oppo                                                        1
# era                                                         1
# malapart                                                    1
# artaud                                                      1
# byron                                                       1
# fanu                                                        1
# beckett                                                     1
# james                                                       1
# joyce                                                       1
# zora                                                        1
# neal                                                        1
# hurston                                                     1
# maya                                                        1
# anjelu                                                      1
# appetite                                                    1
# instal                                                      1
# blu                                                         1
# verygood                                                    1
# spr                                                         1
# deduct                                                      1
# aplgg                                                       1
# shelfing                                                    1
# puzzle                                                      1
# solves                                                      1
# surprize                                                    1
# bmc                                                         1
# boin                                                        1
# ov                                                          1
# wou                                                         1
# nuld                                                        1
# saibd                                                       1
# decreasing                                                  1
# otimos                                                      1
# luij                                                        1
# inn                                                         1
# ummj                                                        1
# iouvi                                                       1
# kllmupimmmm                                                 1
# bl                                                          1
# increases                                                   1
# simly                                                       1
# worat                                                       1
# oooooooooooooooooooooddddddddded                            1
# sandra                                                      1
# tusssss                                                     1
# negation                                                    1
# haunt                                                       1
# rada                                                        1
# shovelware                                                  1
# bhut                                                        1
# creep                                                       1
# identify                                                    1
# optimal                                                     1
# cooperative                                                 1
# horasious                                                   1
# cooollll                                                    1
# optimise                                                    1
# suppport                                                    1
# turner                                                      1
# simulation                                                  1
# llllllllllooollllllllllllllllllll                           1
# llf                                                         1
# jrs                                                         1
# depend                                                      1
# minimalistic                                                1
# aau                                                         1
# estuve                                                      1
# desinstal                                                   1
# datos                                                       1
# cobrado                                                     1
# dos                                                         1
# despu                                                       1
# avisarme                                                    1
# carg                                                        1
# ndolo                                                       1
# cuenta                                                      1
# dekhate                                                     1
# tires                                                       1
# jharna                                                      1
# sarkar                                                      1
# roshnipasi                                                  1
# payements                                                   1
# buts                                                        1
# summaries                                                   1
# favirete                                                    1
# relate                                                      1
# interests                                                   1
# questionable                                                1
# objectionable                                               1
# downright                                                   1
# displeasure                                                 1
# ccouldn                                                     1
# interact                                                    1
# explaining                                                  1
# puper                                                       1
# unpdate                                                     1
# butty                                                       1
# googles                                                     1
# brieeggs                                                    1
# ua                                                          1
# guyg                                                        1
# qfttey                                                      1
# pyler                                                       1
# gaaaa                                                       1
# rudy                                                        1
# rre                                                         1
# yeee                                                        1
# feet                                                        1
# bhhurt                                                      1
# euryeurya                                                   1
# sp                                                          1
# tqq                                                         1
# itu                                                         1
# fe                                                          1
# awee                                                        1
# tuyr                                                        1
# rehhhhhhhls                                                 1
# chr                                                         1
# trtrt                                                       1
# riederrrrt                                                  1
# err                                                         1
# vg                                                          1
# sethu                                                       1
# iski                                                        1
# chodo                                                       1
# jhaatu                                                      1
# chutiyapa                                                   1
# ra                                                          1
# bancho                                                      1
# caverns                                                     1
# recognized                                                  1
# intentionaly                                                1
# offending                                                   1
# abusive                                                     1
# groth                                                       1
# stuvk                                                       1
# copycat                                                     1
# disguise                                                    1
# xico                                                        1
# reminds                                                     1
# cassette                                                    1
# tape                                                        1
# wseetax                                                     1
# ow                                                          1
# whis                                                        1

# %%
#Import manually picked keywords
ios_keywords = sorted(list(pd.read_csv(r"ios_keywords.csv").values.flatten()))
android_keywords = sorted(list(pd.read_csv(r"android_keywords.csv").values.flatten()))
combined_keywords = ios_keywords + android_keywords
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d00dc095bdc2> in <module>
#       1 #Import manually picked keywords
# ----> 2 ios_keywords = sorted(list(pd.read_csv(r"ios_keywords.csv").values.flatten()))
#       3 android_keywords = sorted(list(pd.read_csv(r"android_keywords.csv").values.flatten()))
#       4 combined_keywords = ios_keywords + android_keywords
#
# NameError: name 'pd' is not defined

# %%
ios_keywords
# Out:
# ['able',
#  'accessible',
#  'application',
#  'asleep',
#  'audible',
#  'audiobooks',
#  'author',
#  'authors',
#  'background',
#  'bad',
#  'battery',
#  'best',
#  'bible',
#  'biggest',
#  'bookmark',
#  'bookmarking',
#  'bookmarks',
#  'bookshelf',
#  'bookshelves',
#  'boring',
#  'borrow',
#  'borrowed',
#  'break',
#  'bright',
#  'brightness',
#  'browser',
#  'bug',
#  'bugs',
#  'buy',
#  'buying',
#  'carry',
#  'children',
#  'choice',
#  'choices',
#  'click',
#  'clunky',
#  'clutter',
#  'collection',
#  'collections',
#  'color',
#  'colors',
#  'complaint',
#  'computer',
#  'connection',
#  'continuous',
#  'control',
#  'convenient',
#  'copy',
#  'cost',
#  'cover',
#  'crashes',
#  'crashing',
#  'dark',
#  'delete',
#  'deleting',
#  'design',
#  'developers',
#  'dictionaries',
#  'dictionary',
#  'difficult',
#  'difficulty',
#  'directly',
#  'discover',
#  'display',
#  'download',
#  'downloaded',
#  'downloading',
#  'downloads',
#  'easily',
#  'easy',
#  'ereader',
#  'expensive',
#  'experience',
#  'experiences',
#  'family',
#  'faster',
#  'favorites',
#  'feature',
#  'features',
#  'fiction',
#  'filter',
#  'find',
#  'finding',
#  'fixed',
#  'flip',
#  'folders',
#  'font',
#  'fonts',
#  'format',
#  'formats',
#  'forward',
#  'freezes',
#  'friends',
#  'frustrated',
#  'frustrating',
#  'function',
#  'functionality',
#  'functions',
#  'future',
#  'gave',
#  'genre',
#  'genres',
#  'gift',
#  'glitch',
#  'glitches',
#  'goodreads',
#  'green',
#  'hard',
#  'hassle',
#  'hate',
#  'heavy',
#  'help',
#  'helpful',
#  'helps',
#  'highlight',
#  'highlighting',
#  'highlights',
#  'home',
#  'hooked',
#  'huge',
#  'ibooks',
#  'immediately',
#  'improvement',
#  'improvements',
#  'increase',
#  'ios',
#  'ipad',
#  'iphone',
#  'issue',
#  'kids',
#  'ku',
#  'language',
#  'layout',
#  'libraries',
#  'library',
#  'light',
#  'lighter',
#  'list',
#  'location',
#  'log',
#  'look',
#  'losing',
#  'magazines',
#  'membership',
#  'mind',
#  'money',
#  'multiple',
#  'mystery',
#  'navigate',
#  'negative',
#  'never',
#  'new',
#  'nook',
#  'note',
#  'notifications',
#  'option',
#  'options',
#  'ordering',
#  'organize',
#  'organizing',
#  'overdrive',
#  'pages',
#  'paperwhite',
#  'pay',
#  'pdf',
#  'pdfs',
#  'phone',
#  'physical',
#  'platform',
#  'pocket',
#  'portable',
#  'prices',
#  'prime',
#  'problem',
#  'products',
#  'purchase',
#  'purchased',
#  'purchases',
#  'purchasing',
#  'quickly',
#  'rating',
#  'ready',
#  'recommendations',
#  'recommended',
#  'reference',
#  'release',
#  'remove',
#  'reread',
#  'return',
#  'reviews',
#  'sample',
#  'samples',
#  'saves',
#  'screen',
#  'scroll',
#  'scrolling',
#  'select',
#  'sense',
#  'series',
#  'seriously',
#  'settings',
#  'short',
#  'size',
#  'sizes',
#  'slow',
#  'smell',
#  'social',
#  'sort',
#  'speech',
#  'speed',
#  'star',
#  'stars',
#  'stop',
#  'storage',
#  'stores',
#  'stories',
#  'student',
#  'subscription',
#  'suggestion',
#  'suggestions',
#  'support',
#  'swipe',
#  'switched',
#  'sync',
#  'synced',
#  'syncing',
#  'syncs',
#  'system',
#  'tablet',
#  'technology',
#  'terrible',
#  'text',
#  'textbooks',
#  'title',
#  'tools',
#  'turn',
#  'turning',
#  'unable',
#  'unfortunately',
#  'unlimited',
#  'unread',
#  'update',
#  'updated',
#  'updates',
#  'upgrade',
#  'vision',
#  'voice',
#  'whispersync',
#  'wife',
#  'wifi',
#  'wikipedia',
#  'wish',
#  'writing']

# %%
#Group and normalize similar words (i.e. sync, syncs, syncing)

def manual_kw_normalizer(df):
    
    #sync
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[s][y][n][c][a-z]*", value = r"sync", regex=True)
    #download
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[d][o][w][n][l][o][a][d][a-z]*", value = r"download", regex=True)
    #bookmark
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[b][o][o][k][m][a][r][k][a-z]*", value = r"bookmark", regex=True)
    #bug
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[b][u][g][a-z]*", value = r"bug", regex=True)
    #bookshelf
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[b][o][o][k][s][h][e][l][f][a-z]*", value = r"bookshelf", regex=True)
    #borrow
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[b][o][r][r][o][w][a-z]*", value = r"borrow", regex=True)
    #buy
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[b][u][y][a-z]*", value = r"buy", regex=True)
    #choice
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[c][h][o][i][c][e][a-z]*", value = r"choice", regex=True)
    #collection
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[c][o][l][l][e][c][t][i][o][n][a-z]*", value = r"collection", regex=True)
    #color
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[c][o][l][o][r][a-z]*", value = r"color", regex=True)
    #crash
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[c][r][a][s][h][a-z]*", value = r"crash", regex=True)
    #delete
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[d][e][l][e][t][e][a-z]*", value = r"delete", regex=True)
    #dictionary
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[d][i][c][t][i][o][n][a][r][y][a-z]*", value = r"dictionary", regex=True)
    #difficult
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[d][i][f][f][i][c][u][l][t][a-z]*", value = r"difficult", regex=True)
    #experience
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[e][x][p][e][r][i][e][n][c][e][a-z]*", value = r"experience", regex=True)
    #fast
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[f][a][s][t][a-z]*", value = r"fast", regex=True)
    #feature
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[f][e][a][t][u][r][e][a-z]*", value = r"feature", regex=True)
    #find
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[f][i][n][d][a-z]*", value = r"find", regex=True)
    #search
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[s][e][a][r][c][h][a-z]*", value = r"search", regex=True)
    #format
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[f][o][r][m][a][t][a-z]*", value = r"format", regex=True)
    #freeze
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[f][o][r][m][a][t][a-z]*", value = r"freeze", regex=True)
    #glitch
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[g][l][i][t][c][h][a-z]*", value = r"glitch", regex=True)
    #genre
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[g][e][n][r][e][a-z]*", value = r"genre", regex=True)
    #frustration
    df["Review1"] = df['Review1'].replace(to_replace=r"[a-z0-9]*[f][r][u][s][t][a-z]*", value = r"frustration", regex=True)

# %% [markdown]
# Group similar terms together:
#
# df_as_kindle_05_18_05_19
#
# for example sync, syncs, syncing

# %%
#ios keywords to rating
keywords = []
Reviews = []
month_starts = []
Ratings = []
for _, row in df_as_kindle_05_18_05_19.iterrows():
    Review = row.Review
    month_start = row.month_start
    Rating = row.Rating
    
    for keyword in row.Review1_tok:
        if keyword in ios_keywords:
            Reviews.append(Review)
            keywords.append(keyword)
            month_starts.append(month_start)
            Ratings.append(Rating)
        
as_kw_to_review = pd.DataFrame({
    "month_start": month_starts,
    #"Review": Reviews,
    "keyword": keywords,
    "Rating": Ratings
})

# %%
#ios keywords to rating
keywords = []
Reviews = []
month_starts = []
Ratings = []
for _, row in df_as_kindle_05_18_05_19.iterrows():
    Review = row.Review
    month_start = row.month_start
    Rating = row.Rating
    
    for keyword in row.Review1_tok:
        if keyword in ios_keywords:
            Reviews.append(Review)
            keywords.append(keyword)
            month_starts.append(month_start)
            Ratings.append(Rating)
        
as_kw_to_review = pd.DataFrame({
    "month_start": month_starts,
    "Review": Reviews,
    "keyword": keywords,
    "Rating": Ratings
})

# %%
#Android keywords to rating
keywords = []
Reviews = []
month_starts = []
Ratings = []
for _, row in df_gp_kindle_05_18_05_19.iterrows():
    Review = row.Review
    month_start = row.month_start
    Rating = row.Rating
    
    for keyword in row.Review1_tok:
        if keyword in android_keywords:
            Reviews.append(Review)
            keywords.append(keyword)
            month_starts.append(month_start)
            Ratings.append(Rating)
        
gp_kw_to_review = pd.DataFrame({
    "month_start": month_starts,
    "Review": Reviews,
    "keyword": keywords,
    "Rating": Ratings
})

# %%
gp_kw_to_review.head()
# Out:
#   month_start                                             Review    keyword  \
# 0  2018-05-01  This is very nice app for reading books and fo...    reading
# 1  2018-05-01  This is very nice app for reading books and fo...  recommend
# 2  2018-05-01  Can't sort price low to high/high to low on th...       sort
# 3  2018-05-01  Can't sort price low to high/high to low on th...      price
# 4  2018-05-01  Can't sort price low to high/high to low on th...      store
#
#    Rating
# 0       5
# 1       5
# 2       2
# 3       2
# 4       2

# %%
#Overall rating by keywords
ios_kw_rating = as_kw_to_review.groupby(["keyword","month_start"]).mean().reset_index().sort_values("Rating",ascending=False)

android_kw_rating = gp_kw_to_review.groupby(["keyword","month_start"]).mean().reset_index().sort_values("Rating",ascending=False)

# %%
m1 = ios_kw_rating["month_start"] == "2019-02-01"
m2 = ios_kw_rating["keyword"] == "sort"

ios_kw_rating[m1&m2]
# Out:
#      keyword month_start  Rating
# 2387    sort  2019-02-01     1.0

# %%
#show change

kw = "sort"

as_kw_to_review_sub= ios_kw_rating[ios_kw_rating["keyword"] == kw].sort_values("month_start",ascending=False)
gp_kw_to_review_sub = android_kw_rating[android_kw_rating["keyword"] == kw].sort_values("month_start",ascending=False)

# monthly trend
trace_ios = go.Scatter(
                x=as_kw_to_review_sub.month_start,
                y=as_kw_to_review_sub["Rating"],
                name = "iOS Rating(with review)",
                line = dict(color = '#17BECF', width = 4),
                opacity = 0.8)

trace_android = go.Scatter(
                x=gp_kw_to_review_sub.month_start,
                y=gp_kw_to_review_sub["Rating"],
                name = "Android Rating(with review)",
                line = dict(color = '#7F7F7F', width = 4),
                opacity = 0.8)

data = [trace_ios,trace_android]

layout = dict(
    title = "keyword: " + kw + " " +"iOS and Android monthly avg rating (with review texts)",
    xaxis = dict(
        range = ['2018-06-11','2019-05-31'])
)

fig = dict(data=data, layout=layout)
py.iplot(fig, filename = "Manually Set Range")
# Out:
# <div id="93621479-aa1f-42fe-953f-1242e552a13d" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("93621479-aa1f-42fe-953f-1242e552a13d", [{"line": {"color": "#17BECF", "width": 4}, "name": "iOS Rating(with review)", "opacity": 0.8, "x": ["2019-05-01", "2019-04-01", "2019-02-01", "2019-01-01", "2018-12-01", "2018-11-01", "2018-10-01", "2018-09-01", "2018-08-01", "2018-07-01", "2018-06-01", "2018-05-01"], "y": [3.5, 3.8, 1.0, 3.4, 4.333333333333333, 2.75, 3.727272727272727, 3.2222222222222223, 2.8181818181818183, 3.8360655737704916, 4.022988505747127, 3.0], "type": "scatter", "uid": "09fbd211-d0bf-4e1c-adc7-e8f4aebf0270"}, {"line": {"color": "#7F7F7F", "width": 4}, "name": "Android Rating(with review)", "opacity": 0.8, "x": ["2019-05-01", "2019-04-01", "2019-03-01", "2019-02-01", "2019-01-01", "2018-12-01", "2018-11-01", "2018-10-01", "2018-09-01", "2018-08-01", "2018-07-01", "2018-06-01", "2018-05-01"], "y": [2.5, 2.5, 3.0, 3.0, 2.25, 2.5, 4.0, 2.5, 2.3333333333333335, 2.3333333333333335, 3.0, 2.875, 3.0], "type": "scatter", "uid": "4cf2354a-5301-498a-9b47-a609f91e362e"}], {"title": "keyword: sort iOS and Android monthly avg rating (with review texts)", "xaxis": {"range": ["2018-06-11", "2019-05-31"]}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("93621479-aa1f-42fe-953f-1242e552a13d"));});</script>

# %%
#show change

kw = "library"

as_kw_to_review_sub= ios_kw_rating[ios_kw_rating["keyword"] == kw].sort_values("month_start",ascending=False)
gp_kw_to_review_sub = android_kw_rating[android_kw_rating["keyword"] == kw].sort_values("month_start",ascending=False)

# monthly trend
trace_ios = go.Scatter(
                x=as_kw_to_review_sub.month_start,
                y=as_kw_to_review_sub["Rating"],
                name = "iOS Rating(with review)",
                line = dict(color = '#17BECF', width = 4),
                opacity = 0.8)

trace_android = go.Scatter(
                x=gp_kw_to_review_sub.month_start,
                y=gp_kw_to_review_sub["Rating"],
                name = "Android Rating(with review)",
                line = dict(color = '#7F7F7F', width = 4),
                opacity = 0.8)

data = [trace_ios,trace_android]

layout = dict(
    title = "keyword: " + kw + " " +"iOS and Android monthly avg rating (with review texts)",
    xaxis = dict(
        range = ['2018-06-11','2019-05-31'])
)

fig = dict(data=data, layout=layout)
py.iplot(fig, filename = "Manually Set Range")
# Out:
# <div id="20eee4fb-4cef-4223-a41f-4f1d036c0398" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("20eee4fb-4cef-4223-a41f-4f1d036c0398", [{"line": {"color": "#17BECF", "width": 4}, "name": "iOS Rating(with review)", "opacity": 0.8, "x": ["2019-05-01", "2019-04-01", "2019-03-01", "2019-02-01", "2019-01-01", "2018-12-01", "2018-11-01", "2018-10-01", "2018-09-01", "2018-08-01", "2018-07-01", "2018-06-01", "2018-05-01"], "y": [3.4411764705882355, 3.3448275862068964, 3.823529411764706, 4.111111111111111, 3.4489795918367347, 4.153846153846154, 4.0, 4.3125, 4.2682926829268295, 4.453488372093023, 4.692677070828331, 4.630252100840337, 2.875], "type": "scatter", "uid": "084173a7-696d-455b-b737-150557dee525"}, {"line": {"color": "#7F7F7F", "width": 4}, "name": "Android Rating(with review)", "opacity": 0.8, "x": ["2019-05-01", "2019-04-01", "2019-03-01", "2019-02-01", "2019-01-01", "2018-12-01", "2018-11-01", "2018-10-01", "2018-09-01", "2018-08-01", "2018-07-01", "2018-06-01", "2018-05-01"], "y": [3.1724137931034484, 3.5, 2.8823529411764706, 2.7333333333333334, 3.025, 2.8214285714285716, 3.72, 3.409090909090909, 2.864864864864865, 3.5714285714285716, 2.9722222222222223, 3.3529411764705883, 2.9705882352941178], "type": "scatter", "uid": "03c2e6a5-d9ca-41ca-97d0-7922bc9b5fe9"}], {"title": "keyword library iOS and Android monthly avg rating (with review texts)", "xaxis": {"range": ["2018-06-11", "2019-05-31"]}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("20eee4fb-4cef-4223-a41f-4f1d036c0398"));});</script>

# %%
#show change

kw = "buy"

as_kw_to_review_sub= ios_kw_rating[ios_kw_rating["keyword"] == kw].sort_values("month_start",ascending=False)
gp_kw_to_review_sub = android_kw_rating[android_kw_rating["keyword"] == kw].sort_values("month_start",ascending=False)

# monthly trend
trace_ios = go.Scatter(
                x=as_kw_to_review_sub.month_start,
                y=as_kw_to_review_sub["Rating"],
                name = "iOS Rating(with review)",
                line = dict(color = '#17BECF', width = 4),
                opacity = 0.8)

trace_android = go.Scatter(
                x=gp_kw_to_review_sub.month_start,
                y=gp_kw_to_review_sub["Rating"],
                name = "Android Rating(with review)",
                line = dict(color = '#7F7F7F', width = 4),
                opacity = 0.8)

data = [trace_ios,trace_android]

layout = dict(
    title = "keyword: " + kw + " " +"iOS and Android monthly avg rating (with review texts)",
    xaxis = dict(
        range = ['2018-06-11','2019-05-31'])
)

fig = dict(data=data, layout=layout)
py.iplot(fig, filename = "Manually Set Range")
# Out:
# <div id="420cbcaf-500f-4ec3-b844-9c865ad98f80" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("420cbcaf-500f-4ec3-b844-9c865ad98f80", [{"line": {"color": "#17BECF", "width": 4}, "name": "iOS Rating(with review)", "opacity": 0.8, "x": ["2019-05-01", "2019-04-01", "2019-03-01", "2019-02-01", "2019-01-01", "2018-12-01", "2018-11-01", "2018-10-01", "2018-09-01", "2018-08-01", "2018-07-01", "2018-06-01", "2018-05-01"], "y": [3.0606060606060606, 3.388888888888889, 2.75, 3.3793103448275863, 2.8636363636363638, 3.1315789473684212, 3.604651162790698, 3.7547169811320753, 3.6721311475409837, 3.878787878787879, 4.351351351351352, 4.4021739130434785, 3.4375], "type": "scatter", "uid": "1de696a1-d5e9-4485-8b90-c9fedfea8c50"}, {"line": {"color": "#7F7F7F", "width": 4}, "name": "Android Rating(with review)", "opacity": 0.8, "x": ["2019-05-01", "2019-04-01", "2019-03-01", "2019-02-01", "2019-01-01", "2018-12-01", "2018-11-01", "2018-10-01", "2018-09-01", "2018-08-01", "2018-07-01", "2018-06-01", "2018-05-01"], "y": [2.6129032258064515, 3.130434782608696, 2.25, 2.475, 2.6956521739130435, 1.9444444444444444, 2.6315789473684212, 3.5714285714285716, 2.607142857142857, 2.6470588235294117, 2.739130434782609, 2.8214285714285716, 1.5833333333333333], "type": "scatter", "uid": "0dd67671-77cc-4875-a03b-d03b7ae23427"}], {"title": "keyword: buy iOS and Android monthly avg rating (with review texts)", "xaxis": {"range": ["2018-06-11", "2019-05-31"]}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("420cbcaf-500f-4ec3-b844-9c865ad98f80"));});</script>

# %%
#show change

kw = "crashes"

as_kw_to_review_sub= ios_kw_rating[ios_kw_rating["keyword"] == kw].sort_values("month_start",ascending=False)
gp_kw_to_review_sub = android_kw_rating[android_kw_rating["keyword"] == kw].sort_values("month_start",ascending=False)

# monthly trend
trace_ios = go.Scatter(
                x=as_kw_to_review_sub.month_start,
                y=as_kw_to_review_sub["Rating"],
                name = "iOS Rating(with review)",
                line = dict(color = '#17BECF', width = 4),
                opacity = 0.8)

trace_android = go.Scatter(
                x=gp_kw_to_review_sub.month_start,
                y=gp_kw_to_review_sub["Rating"],
                name = "Android Rating(with review)",
                line = dict(color = '#7F7F7F', width = 4),
                opacity = 0.8)

data = [trace_ios,trace_android]

layout = dict(
    title = "keyword: " + kw + " " +"iOS and Android monthly avg rating (with review texts)",
    xaxis = dict(
        range = ['2018-06-11','2019-05-31'])
)

fig = dict(data=data, layout=layout)
py.iplot(fig, filename = "Manually Set Range")
# Out:
# <div id="de66277f-8bad-49b7-bc31-2fdc3f4c51b1" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("de66277f-8bad-49b7-bc31-2fdc3f4c51b1", [{"line": {"color": "#17BECF", "width": 4}, "name": "iOS Rating(with review)", "opacity": 0.8, "x": ["2019-05-01", "2019-04-01", "2019-03-01", "2019-02-01", "2019-01-01", "2018-12-01", "2018-11-01", "2018-09-01", "2018-08-01", "2018-07-01", "2018-06-01", "2018-05-01"], "y": [1.0, 1.5, 1.0, 1.0, 1.0, 1.0, 3.0, 1.8571428571428572, 3.0, 3.9411764705882355, 3.4285714285714284, 1.4285714285714286], "type": "scatter", "uid": "080f20a1-b172-4c87-b2cb-bd5de0c2e766"}, {"line": {"color": "#7F7F7F", "width": 4}, "name": "Android Rating(with review)", "opacity": 0.8, "x": ["2019-05-01", "2019-04-01", "2019-03-01", "2019-02-01", "2019-01-01", "2018-12-01", "2018-11-01", "2018-10-01", "2018-09-01", "2018-08-01", "2018-07-01", "2018-06-01", "2018-05-01"], "y": [1.6153846153846154, 2.25, 2.1666666666666665, 2.0, 2.1666666666666665, 1.6, 3.4, 1.5454545454545454, 2.0, 2.25, 1.4666666666666666, 2.0, 1.7058823529411764], "type": "scatter", "uid": "e1023b15-eff9-4942-a412-a8013149c02b"}], {"title": "keyword: crashes iOS and Android monthly avg rating (with review texts)", "xaxis": {"range": ["2018-06-11", "2019-05-31"]}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("de66277f-8bad-49b7-bc31-2fdc3f4c51b1"));});</script>

# %%
#show change

kw = "crashes"

as_kw_to_review_sub= ios_kw_rating[ios_kw_rating["keyword"] == kw].sort_values("month_start",ascending=False)
gp_kw_to_review_sub = android_kw_rating[android_kw_rating["keyword"] == kw].sort_values("month_start",ascending=False)

# monthly trend
trace_ios = go.Scatter(
                x=as_kw_to_review_sub.month_start,
                y=as_kw_to_review_sub["Rating"],
                name = "iOS Rating(with review)",
                line = dict(color = '#17BECF', width = 4),
                opacity = 0.8)

trace_android = go.Scatter(
                x=gp_kw_to_review_sub.month_start,
                y=gp_kw_to_review_sub["Rating"],
                name = "Android Rating(with review)",
                line = dict(color = '#7F7F7F', width = 4),
                opacity = 0.8)

data = [trace_ios,trace_android]

layout = dict(
    title = "keyword: " + kw + " " +"iOS and Android monthly avg rating (with review texts)",
    xaxis = dict(
        range = ['2018-06-11','2019-05-31'])
)

fig = dict(data=data, layout=layout)
py.iplot(fig, filename = "Manually Set Range")

# %%
#show change

kw = "recommendations"

as_kw_to_review_sub= ios_kw_rating[ios_kw_rating["keyword"] == kw].sort_values("month_start",ascending=False)
gp_kw_to_review_sub = android_kw_rating[android_kw_rating["keyword"] == kw].sort_values("month_start",ascending=False)

# monthly trend
trace_ios = go.Scatter(
                x=as_kw_to_review_sub.month_start,
                y=as_kw_to_review_sub["Rating"],
                name = "iOS Rating(with review)",
                line = dict(color = '#17BECF', width = 4),
                opacity = 0.8)

trace_android = go.Scatter(
                x=gp_kw_to_review_sub.month_start,
                y=gp_kw_to_review_sub["Rating"],
                name = "Android Rating(with review)",
                line = dict(color = '#7F7F7F', width = 4),
                opacity = 0.8)

data = [trace_ios,trace_android]

layout = dict(
    title = "keyword: " + kw + " " +"iOS and Android monthly avg rating (with review texts)",
    xaxis = dict(
        range = ['2018-06-11','2019-05-31'])
)

fig = dict(data=data, layout=layout)
py.iplot(fig, filename = "Manually Set Range")
# Out:
# <div id="ecec88b5-2c35-44f2-a16e-78e2f4343ddc" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("ecec88b5-2c35-44f2-a16e-78e2f4343ddc", [{"line": {"color": "#17BECF", "width": 4}, "name": "iOS Rating(with review)", "opacity": 0.8, "x": ["2019-05-01", "2019-04-01", "2019-02-01", "2019-01-01", "2018-12-01", "2018-10-01", "2018-07-01", "2018-06-01"], "y": [5.0, 3.5, 2.3333333333333335, 1.5, 5.0, 2.0, 4.64, 4.2], "type": "scatter", "uid": "26dfe1f6-8e0e-4cfd-ab3d-da66bc46b923"}, {"line": {"color": "#7F7F7F", "width": 4}, "name": "Android Rating(with review)", "opacity": 0.8, "x": ["2019-05-01", "2019-04-01", "2019-02-01", "2019-01-01", "2018-12-01", "2018-10-01", "2018-09-01", "2018-08-01", "2018-07-01", "2018-06-01", "2018-05-01"], "y": [2.25, 2.0, 1.0, 2.0, 4.5, 2.0, 1.0, 2.0, 5.0, 4.0, 2.5], "type": "scatter", "uid": "cf4108a5-76dc-482f-b10d-bc88cad28234"}], {"title": "keyword: recommendations iOS and Android monthly avg rating (with review texts)", "xaxis": {"range": ["2018-06-11", "2019-05-31"]}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("ecec88b5-2c35-44f2-a16e-78e2f4343ddc"));});</script>

# %%
#show change

kw = "syncs"

as_kw_to_review_sub= ios_kw_rating[ios_kw_rating["keyword"] == kw].sort_values("month_start",ascending=False)
gp_kw_to_review_sub = android_kw_rating[android_kw_rating["keyword"] == kw].sort_values("month_start",ascending=False)

# monthly trend
trace_ios = go.Scatter(
                x=as_kw_to_review_sub.month_start,
                y=as_kw_to_review_sub["Rating"],
                name = "iOS Rating(with review)",
                line = dict(color = '#17BECF', width = 4),
                opacity = 0.8)

trace_android = go.Scatter(
                x=gp_kw_to_review_sub.month_start,
                y=gp_kw_to_review_sub["Rating"],
                name = "Android Rating(with review)",
                line = dict(color = '#7F7F7F', width = 4),
                opacity = 0.8)

data = [trace_ios,trace_android]

layout = dict(
    title = "keyword: " + kw + " " +"iOS and Android monthly avg rating (with review texts)",
    xaxis = dict(
        range = ['2018-06-11','2019-05-31'])
)

fig = dict(data=data, layout=layout)
py.iplot(fig, filename = "Manually Set Range")
# Out:
# <div id="a570119b-5024-4049-b896-a85d3f2a59e2" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("a570119b-5024-4049-b896-a85d3f2a59e2", [{"line": {"color": "#17BECF", "width": 4}, "name": "iOS Rating(with review)", "opacity": 0.8, "x": ["2019-05-01", "2019-04-01", "2019-03-01", "2019-02-01", "2019-01-01", "2018-12-01", "2018-11-01", "2018-10-01", "2018-09-01", "2018-08-01", "2018-07-01", "2018-06-01", "2018-05-01"], "y": [3.6666666666666665, 4.25, 4.0, 5.0, 2.3333333333333335, 3.0, 4.0, 4.666666666666667, 5.0, 4.571428571428571, 4.78125, 4.716216216216216, 4.0], "type": "scatter", "uid": "90fe8ab0-751c-4c42-8b7a-8ebc58363399"}, {"line": {"color": "#7F7F7F", "width": 4}, "name": "Android Rating(with review)", "opacity": 0.8, "x": ["2019-05-01", "2019-04-01", "2019-03-01", "2019-02-01", "2019-01-01", "2018-12-01", "2018-11-01", "2018-09-01", "2018-08-01", "2018-07-01", "2018-06-01", "2018-05-01"], "y": [2.25, 5.0, 5.0, 3.6, 4.166666666666667, 2.0, 5.0, 2.3333333333333335, 4.75, 5.0, 2.0, 5.0], "type": "scatter", "uid": "2b0e910b-3ae6-4421-aed1-4ca23cf68f35"}], {"title": "keyword: syncs iOS and Android monthly avg rating (with review texts)", "xaxis": {"range": ["2018-06-11", "2019-05-31"]}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("a570119b-5024-4049-b896-a85d3f2a59e2"));});</script>

# %%
#show change

kw = "syncing"

as_kw_to_review_sub= ios_kw_rating[ios_kw_rating["keyword"] == kw].sort_values("month_start",ascending=False)
gp_kw_to_review_sub = android_kw_rating[android_kw_rating["keyword"] == kw].sort_values("month_start",ascending=False)

# monthly trend
trace_ios = go.Scatter(
                x=as_kw_to_review_sub.month_start,
                y=as_kw_to_review_sub["Rating"],
                name = "iOS Rating(with review)",
                line = dict(color = '#17BECF', width = 4),
                opacity = 0.8)

trace_android = go.Scatter(
                x=gp_kw_to_review_sub.month_start,
                y=gp_kw_to_review_sub["Rating"],
                name = "Android Rating(with review)",
                line = dict(color = '#7F7F7F', width = 4),
                opacity = 0.8)

data = [trace_ios,trace_android]

layout = dict(
    title = "keyword: " + kw + " " +"iOS and Android monthly avg rating (with review texts)",
    xaxis = dict(
        range = ['2018-06-11','2019-05-31'])
)

fig = dict(data=data, layout=layout)
py.iplot(fig, filename = "Manually Set Range")
# Out:
# <div id="2b32e0da-5bfd-4e57-b774-db870caecfdf" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("2b32e0da-5bfd-4e57-b774-db870caecfdf", [{"line": {"color": "#17BECF", "width": 4}, "name": "iOS Rating(with review)", "opacity": 0.8, "x": ["2019-05-01", "2019-04-01", "2019-03-01", "2019-02-01", "2019-01-01", "2018-12-01", "2018-11-01", "2018-10-01", "2018-09-01", "2018-08-01", "2018-07-01", "2018-06-01", "2018-05-01"], "y": [3.25, 3.5, 4.0, 2.857142857142857, 3.25, 3.142857142857143, 1.0, 4.2, 3.75, 3.8, 4.37037037037037, 4.513513513513513, 3.2], "type": "scatter", "uid": "9c66827d-e020-4a21-b8a3-d3e6ef48c299"}, {"line": {"color": "#7F7F7F", "width": 4}, "name": "Android Rating(with review)", "opacity": 0.8, "x": ["2019-05-01", "2019-04-01", "2019-03-01", "2019-02-01", "2019-01-01", "2018-12-01", "2018-11-01", "2018-10-01", "2018-09-01", "2018-08-01", "2018-07-01", "2018-06-01", "2018-05-01"], "y": [3.0, 2.3333333333333335, 3.25, 3.0, 3.0, 1.0, 3.2, 2.25, 3.0, 3.0, 2.0, 3.0, 1.0], "type": "scatter", "uid": "8cb0aaa4-51e7-4279-937c-f11ea61adda0"}], {"title": "keyword: syncing iOS and Android monthly avg rating (with review texts)", "xaxis": {"range": ["2018-06-11", "2019-05-31"]}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("2b32e0da-5bfd-4e57-b774-db870caecfdf"));});</script>

# %%
#show change

kw = "notifications"

as_kw_to_review_sub= ios_kw_rating[ios_kw_rating["keyword"] == kw].sort_values("month_start",ascending=False)
gp_kw_to_review_sub = android_kw_rating[android_kw_rating["keyword"] == kw].sort_values("month_start",ascending=False)

# monthly trend
trace_ios = go.Scatter(
                x=as_kw_to_review_sub.month_start,
                y=as_kw_to_review_sub["Rating"],
                name = "iOS Rating(with review)",
                line = dict(color = '#17BECF', width = 4),
                opacity = 0.8)

trace_android = go.Scatter(
                x=gp_kw_to_review_sub.month_start,
                y=gp_kw_to_review_sub["Rating"],
                name = "Android Rating(with review)",
                line = dict(color = '#7F7F7F', width = 4),
                opacity = 0.8)

data = [trace_ios,trace_android]

layout = dict(
    title = "keyword: " + kw + " " +"iOS and Android monthly avg rating (with review texts)",
    xaxis = dict(
        range = ['2018-06-11','2019-05-31'])
)

fig = dict(data=data, layout=layout)
py.iplot(fig, filename = "Manually Set Range")
# Out:
# <div id="09dfaa5e-3911-4aa4-8fc1-8015aa6d25f0" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("09dfaa5e-3911-4aa4-8fc1-8015aa6d25f0", [{"line": {"color": "#17BECF", "width": 4}, "name": "iOS Rating(with review)", "opacity": 0.8, "x": ["2019-05-01", "2019-02-01", "2019-01-01", "2018-12-01", "2018-11-01", "2018-10-01", "2018-09-01", "2018-08-01", "2018-07-01", "2018-06-01"], "y": [3.0, 1.0, 3.0, 3.5, 2.0, 2.0, 2.4, 3.75, 2.2222222222222223, 3.8], "type": "scatter", "uid": "cd7561de-14bf-47be-89fb-c21a056e38fd"}, {"line": {"color": "#7F7F7F", "width": 4}, "name": "Android Rating(with review)", "opacity": 0.8, "x": ["2019-05-01", "2019-04-01", "2019-03-01", "2019-02-01", "2019-01-01", "2018-12-01", "2018-11-01", "2018-10-01", "2018-09-01", "2018-08-01", "2018-07-01", "2018-06-01", "2018-05-01"], "y": [1.4, 2.3333333333333335, 2.5, 1.0, 2.0, 2.857142857142857, 1.0, 2.6666666666666665, 1.5, 2.0, 3.0, 2.75, 2.3333333333333335], "type": "scatter", "uid": "28c4f71b-c859-4a2c-82d7-7c8ff70fb620"}], {"title": "keyword: notifications iOS and Android monthly avg rating (with review texts)", "xaxis": {"range": ["2018-06-11", "2019-05-31"]}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("09dfaa5e-3911-4aa4-8fc1-8015aa6d25f0"));});</script>

# %%
#show change

kw = "continuous"

as_kw_to_review_sub= ios_kw_rating[ios_kw_rating["keyword"] == kw].sort_values("month_start",ascending=False)
gp_kw_to_review_sub = android_kw_rating[android_kw_rating["keyword"] == kw].sort_values("month_start",ascending=False)

# monthly trend
trace_ios = go.Scatter(
                x=as_kw_to_review_sub.month_start,
                y=as_kw_to_review_sub["Rating"],
                name = "iOS Rating(with review)",
                line = dict(color = '#17BECF', width = 4),
                opacity = 0.8)

trace_android = go.Scatter(
                x=gp_kw_to_review_sub.month_start,
                y=gp_kw_to_review_sub["Rating"],
                name = "Android Rating(with review)",
                line = dict(color = '#7F7F7F', width = 4),
                opacity = 0.8)

data = [trace_ios,trace_android]

layout = dict(
    title = "keyword: " + kw + " " +"iOS and Android monthly avg rating (with review texts)",
    xaxis = dict(
        range = ['2018-06-11','2019-05-31'])
)

fig = dict(data=data, layout=layout)
py.iplot(fig, filename = "Manually Set Range")
# Out:
# <div id="d399cfe9-8367-4298-bd7b-eb3d1bdf6a16" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("d399cfe9-8367-4298-bd7b-eb3d1bdf6a16", [{"line": {"color": "#17BECF", "width": 4}, "name": "iOS Rating(with review)", "opacity": 0.8, "x": ["2019-04-01", "2019-01-01", "2018-12-01", "2018-11-01", "2018-10-01", "2018-09-01", "2018-08-01", "2018-07-01", "2018-06-01", "2018-05-01"], "y": [5.0, 1.0, 3.5, 3.8333333333333335, 2.8333333333333335, 3.4, 4.583333333333333, 3.8947368421052633, 4.5, 3.5], "type": "scatter", "uid": "16e8d21a-fe29-4abd-9ebb-5e852486f6aa"}, {"line": {"color": "#7F7F7F", "width": 4}, "name": "Android Rating(with review)", "opacity": 0.8, "x": ["2019-05-01", "2019-04-01", "2019-03-01", "2019-02-01", "2019-01-01", "2018-12-01", "2018-11-01", "2018-10-01", "2018-09-01", "2018-08-01", "2018-06-01", "2018-05-01"], "y": [3.75, 1.0, 3.6, 3.5, 3.5555555555555554, 2.2, 3.0, 4.0, 2.5, 2.3333333333333335, 4.0, 1.0], "type": "scatter", "uid": "4c8d9403-6da8-40b4-8432-e9955c099629"}], {"title": "keyword: continuous iOS and Android monthly avg rating (with review texts)", "xaxis": {"range": ["2018-06-11", "2019-05-31"]}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("d399cfe9-8367-4298-bd7b-eb3d1bdf6a16"));});</script>

# %%
#show change

kw = "font"

as_kw_to_review_sub= ios_kw_rating[ios_kw_rating["keyword"] == kw].sort_values("month_start",ascending=False)
gp_kw_to_review_sub = android_kw_rating[android_kw_rating["keyword"] == kw].sort_values("month_start",ascending=False)

# monthly trend
trace_ios = go.Scatter(
                x=as_kw_to_review_sub.month_start,
                y=as_kw_to_review_sub["Rating"],
                name = "iOS Rating(with review)",
                line = dict(color = '#17BECF', width = 4),
                opacity = 0.8)

trace_android = go.Scatter(
                x=gp_kw_to_review_sub.month_start,
                y=gp_kw_to_review_sub["Rating"],
                name = "Android Rating(with review)",
                line = dict(color = '#7F7F7F', width = 4),
                opacity = 0.8)

data = [trace_ios,trace_android]

layout = dict(
    title = "keyword: " + kw + " " +"iOS and Android monthly avg rating (with review texts)",
    xaxis = dict(
        range = ['2018-06-11','2019-05-31'])
)

fig = dict(data=data, layout=layout)
py.iplot(fig, filename = "Manually Set Range")
# Out:
# <div id="17dc3066-dde2-4c5a-bc42-d90e853deeea" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("17dc3066-dde2-4c5a-bc42-d90e853deeea", [{"line": {"color": "#17BECF", "width": 4}, "name": "iOS Rating(with review)", "opacity": 0.8, "x": ["2019-05-01", "2019-04-01", "2019-03-01", "2019-02-01", "2019-01-01", "2018-12-01", "2018-11-01", "2018-10-01", "2018-09-01", "2018-08-01", "2018-07-01", "2018-06-01", "2018-05-01"], "y": [5.0, 3.375, 3.3333333333333335, 4.3076923076923075, 4.555555555555555, 4.285714285714286, 4.3, 4.111111111111111, 4.380952380952381, 4.2592592592592595, 4.699115044247788, 4.8493150684931505, 2.5], "type": "scatter", "uid": "28c7a62d-f793-43f2-9420-bf7066309694"}, {"line": {"color": "#7F7F7F", "width": 4}, "name": "Android Rating(with review)", "opacity": 0.8, "x": ["2019-05-01", "2019-04-01", "2019-03-01", "2019-02-01", "2019-01-01", "2018-12-01", "2018-11-01", "2018-10-01", "2018-09-01", "2018-08-01", "2018-07-01", "2018-06-01", "2018-05-01"], "y": [3.0, 4.25, 2.9285714285714284, 2.4, 2.888888888888889, 3.25, 4.333333333333333, 1.0, 3.4, 2.3333333333333335, 3.2, 2.3333333333333335, 3.2857142857142856], "type": "scatter", "uid": "6818ec01-7023-4d4d-bf4d-32f04716fe76"}], {"title": "keyword: font iOS and Android monthly avg rating (with review texts)", "xaxis": {"range": ["2018-06-11", "2019-05-31"]}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("17dc3066-dde2-4c5a-bc42-d90e853deeea"));});</script>

# %%
#show change

kw = "fonts"

as_kw_to_review_sub= ios_kw_rating[ios_kw_rating["keyword"] == kw].sort_values("month_start",ascending=False)
gp_kw_to_review_sub = android_kw_rating[android_kw_rating["keyword"] == kw].sort_values("month_start",ascending=False)

# monthly trend
trace_ios = go.Scatter(
                x=as_kw_to_review_sub.month_start,
                y=as_kw_to_review_sub["Rating"],
                name = "iOS Rating(with review)",
                line = dict(color = '#17BECF', width = 4),
                opacity = 0.8)

trace_android = go.Scatter(
                x=gp_kw_to_review_sub.month_start,
                y=gp_kw_to_review_sub["Rating"],
                name = "Android Rating(with review)",
                line = dict(color = '#7F7F7F', width = 4),
                opacity = 0.8)

data = [trace_ios,trace_android]

layout = dict(
    title = "keyword: " + kw + " " +"iOS and Android monthly avg rating (with review texts)",
    xaxis = dict(
        range = ['2018-06-11','2019-05-31'])
)

fig = dict(data=data, layout=layout)
py.iplot(fig, filename = "Manually Set Range")
# Out:
# <div id="61c19d80-a74d-43ee-ac71-1afe34fe5c29" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("61c19d80-a74d-43ee-ac71-1afe34fe5c29", [{"line": {"color": "#17BECF", "width": 4}, "name": "iOS Rating(with review)", "opacity": 0.8, "x": ["2019-05-01", "2019-04-01", "2019-03-01", "2019-01-01", "2018-12-01", "2018-11-01", "2018-10-01", "2018-09-01", "2018-08-01", "2018-07-01", "2018-06-01", "2018-05-01"], "y": [5.0, 4.2, 4.0, 4.666666666666667, 5.0, 4.0, 4.5, 4.3, 3.909090909090909, 4.625, 4.785714285714286, 2.0], "type": "scatter", "uid": "d1819aca-f677-4b64-b84f-ff80de1580fe"}, {"line": {"color": "#7F7F7F", "width": 4}, "name": "Android Rating(with review)", "opacity": 0.8, "x": ["2019-05-01", "2019-04-01", "2019-03-01", "2019-02-01", "2019-01-01", "2018-12-01", "2018-11-01", "2018-09-01", "2018-08-01", "2018-07-01", "2018-06-01"], "y": [5.0, 2.0, 5.0, 4.25, 3.6, 2.3333333333333335, 4.333333333333333, 2.5, 3.0, 4.0, 1.5], "type": "scatter", "uid": "de1f6ebc-964c-43fa-b07b-e19635b68a48"}], {"title": "keyword: fonts iOS and Android monthly avg rating (with review texts)", "xaxis": {"range": ["2018-06-11", "2019-05-31"]}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("61c19d80-a74d-43ee-ac71-1afe34fe5c29"));});</script>

# %%
android_keywords
# Out:
# ['access',
#  'ad',
#  'annoying',
#  'authors',
#  'auto',
#  'background',
#  'battery',
#  'bookmark',
#  'bookmarks',
#  'borrow',
#  'brightness',
#  'broken',
#  'browser',
#  'buggy',
#  'bugs',
#  'buy',
#  'buying',
#  'changed',
#  'cheaper',
#  'children',
#  'click',
#  'collection',
#  'collections',
#  'color',
#  'comics',
#  'continuous',
#  'copy',
#  'crash',
#  'crashes',
#  'crashing',
#  'dark',
#  'delete',
#  'deleted',
#  'developers',
#  'dictionary',
#  'disappearing',
#  'disappointed',
#  'download',
#  'downloaded',
#  'downloading',
#  'downloads',
#  'english',
#  'except',
#  'experience',
#  'faster',
#  'feature',
#  'features',
#  'feedback',
#  'files',
#  'fix',
#  'font',
#  'fonts',
#  'forever',
#  'freezes',
#  'freezing',
#  'frustrating',
#  'functionality',
#  'genre',
#  'goodreads',
#  'highlight',
#  'highlighting',
#  'highlights',
#  'home',
#  'installed',
#  'installing',
#  'interface',
#  'intuitive',
#  'ios',
#  'ipad',
#  'items',
#  'landscape',
#  'language',
#  'large',
#  'layout',
#  'library',
#  'light',
#  'listen',
#  'load',
#  'loading',
#  'membership',
#  'memory',
#  'menu',
#  'message',
#  'mobile',
#  'mode',
#  'money',
#  'navigate',
#  'night',
#  'notes',
#  'notification',
#  'notifications',
#  'novel',
#  'page',
#  'paid',
#  'password',
#  'payment',
#  'pdf',
#  'poor',
#  'price',
#  'prices',
#  'prime',
#  'problems',
#  'progress',
#  'purchase',
#  'purchases',
#  'rating',
#  'reader',
#  'reading',
#  'recommend',
#  'recommendations',
#  'recommended',
#  'redownload',
#  'refund',
#  'reinstall',
#  'reinstalled',
#  'remove',
#  'return',
#  'review',
#  'rubbish',
#  'sample',
#  'samples',
#  'samsung',
#  'school',
#  'scroll',
#  'scrolling',
#  'sd',
#  'search',
#  'searching',
#  'selection',
#  'series',
#  'share',
#  'shopping',
#  'sign',
#  'size',
#  'sort',
#  'spend',
#  'stopped',
#  'store',
#  'stuck',
#  'students',
#  'stupid',
#  'subscription',
#  'suddenly',
#  'suggestions',
#  'superb',
#  'support',
#  'synced',
#  'syncing',
#  'syncs',
#  'text',
#  'trash',
#  'ui',
#  'uninstall',
#  'uninstalled',
#  'uninstalling',
#  'unlimited',
#  'update',
#  'updated',
#  'updates',
#  'updating',
#  'website',
#  'wishlist',
#  'worst',
#  'zoom']

# %%
#combined word freq excluding stop words to csv for inspection
#pd.concat([rslt_ios,rslt_android]).to_csv(os.path.join(path,r'combined_word_freq.csv'))

# %%
# tokenized_sms = pd.array([nltk.word_tokenize(str(sentence)) for sentence in df_as_kindle_05_18_05_19["Title1"]])
# for word in tokenized_sms:
#     if word in sw:
#         tokenized_sms.remove(word)

# tokenized_sms = pd.array([nltk.word_tokenize(str(sentence)) for sentence in df_as_kindle_05_18_05_19["Title1"]])
# for sentence in tokenized_sms:
#     for word in sentence:
#         if word in sw:
#             tokenized_sms[sentence].remove(word)

# %%
a = rslt.reset_index()
print(a[a["Word"]=="crash"])
print(a[a["Word"]=="crashes"])
# Out:
#       Word  Frequency
# 567  crash          6
#         Word  Frequency
# 153  crashes         27

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()

# %%
#sentiment analysis
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.classify import NaiveBayesClassifier
from nltk.corpus import subjectivity
from nltk.sentiment import SentimentAnalyzer
from nltk.sentiment.util import *

# %% [markdown]
# ### In-Book Reading CX related key words ###
#
# text, color, background, dictionary, Aa, bookmark, navigation, brightness, font, margin, paragraph, turn, animation, continous scroll, vertical scroll, notes, highlight, x-ray, flash cards, share,
#
# ### Outside the Book CX related key words ###
#
# Sync, library, download, pdf, search, sd card, filter, mark as read, all, downloaded, store, reading insights, friends, community
#
# ### Else ###
# Notification, prime subscription, ku subscription, best seller, recommendation, multi-user related (husband, wife, son, daughter, grandma, etc.), students (textbook, school), borrow, sample, listen, audible, alexa, magazine, comic

# %% [markdown]
# To do:
# - add review text legth nd by VADER Score
