# %%
import hdbscan
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\YC\\Documents\\Python Scripts\\jupyter'

# %%
np.load()

C:\Users\YC\Documents\Python Scripts\jupyter\datasets

# %%
data = np.load('.\datasets\clusterable_data.npy') #one folder up

# %%
data.shape
# Out:
# (2309, 2)

# %%
data
# Out:
# array([[-0.12153499, -0.22876337],
#        [-0.22093687, -0.25251088],
#        [ 0.1259037 , -0.27314321],
#        ...,
#        [ 0.50243143, -0.3002958 ],
#        [ 0.53822256,  0.19412199],
#        [-0.08688887, -0.2092721 ]])

# %%
plt.scatter(*data.T, s=50, linewidth=0, c='b', alpha=0.25)

# %%
clusterer = hdbscan.HDBSCAN(min_cluster_size=15).fit(data)
color_palette = sns.color_palette('deep', 8)
cluster_colors = [color_palette[x] if x >= 0
                  else (0.5, 0.5, 0.5)
                  for x in clusterer.labels_]
cluster_member_colors = [sns.desaturate(x, p) for x, p in
                         zip(cluster_colors, clusterer.probabilities_)]
plt.scatter(*data.T, s=50, linewidth=0, c=cluster_member_colors, alpha=0.25)

# %%
clusterer.condensed_tree_.plot()

# %%
#to know which branch is selected
clusterer.condensed_tree_.plot(select_clusters=True,
                               selection_palette=sns.color_palette('deep', 8))

# %%
clusterer = hdbscan.HDBSCAN(min_cluster_size=5).fit(data)

# %%
np.array(np.unique(clusterer.labels_, return_counts=True)).T
# Out:
# array([[ -1, 692],
#        [  0,   6],
#        [  1,   6],
#        [  2,  17],
#        [  3,  14],
#        [  4,   8],
#        [  5,   9],
#        [  6, 204],
#        [  7, 374],
#        [  8,   8],
#        [  9,   6],
#        [ 10,   7],
#        [ 11,   5],
#        [ 12,   5],
#        [ 13,   7],
#        [ 14,   5],
#        [ 15, 158],
#        [ 16,   9],
#        [ 17,  97],
#        [ 18, 315],
#        [ 19,   5],
#        [ 20,   6],
#        [ 21,   6],
#        [ 22,  74],
#        [ 23, 124],
#        [ 24,   8],
#        [ 25,   5],
#        [ 26,   7],
#        [ 27,   6],
#        [ 28,  16],
#        [ 29,   6],
#        [ 30,  13],
#        [ 31,   7],
#        [ 32,  19],
#        [ 33,   5],
#        [ 34,  34],
#        [ 35,  16]], dtype=int64)

# %%
color_palette = sns.color_palette('deep', 8)

# %%
color_palette
# Out:
# [(0.2980392156862745, 0.4470588235294118, 0.6901960784313725),
#  (0.8666666666666667, 0.5176470588235295, 0.3215686274509804),
#  (0.3333333333333333, 0.6588235294117647, 0.40784313725490196),
#  (0.7686274509803922, 0.3058823529411765, 0.3215686274509804),
#  (0.5058823529411764, 0.4470588235294118, 0.7019607843137254),
#  (0.5764705882352941, 0.47058823529411764, 0.3764705882352941),
#  (0.8549019607843137, 0.5450980392156862, 0.7647058823529411),
#  (0.5490196078431373, 0.5490196078431373, 0.5490196078431373)]

# %%
clusterer = hdbscan.HDBSCAN(min_cluster_size=5).fit(data)
color_palette = sns.color_palette('deep', 50)
cluster_colors = [color_palette[x] if x >= 0
                  else (0.5, 0.5, 0.5)
                  for x in clusterer.labels_]
cluster_member_colors = [sns.desaturate(x, p) for x, p in
                         zip(cluster_colors, clusterer.probabilities_)]
plt.scatter(*data.T, s=50, linewidth=0, c=cluster_member_colors, alpha=0.25)

# %%
hdbscan.dist_metrics.METRIC_MAPPING
# Out:
# {'euclidean': hdbscan.dist_metrics.EuclideanDistance,
#  'l2': hdbscan.dist_metrics.EuclideanDistance,
#  'minkowski': hdbscan.dist_metrics.MinkowskiDistance,
#  'p': hdbscan.dist_metrics.MinkowskiDistance,
#  'manhattan': hdbscan.dist_metrics.ManhattanDistance,
#  'cityblock': hdbscan.dist_metrics.ManhattanDistance,
#  'l1': hdbscan.dist_metrics.ManhattanDistance,
#  'chebyshev': hdbscan.dist_metrics.ChebyshevDistance,
#  'infinity': hdbscan.dist_metrics.ChebyshevDistance,
#  'seuclidean': hdbscan.dist_metrics.SEuclideanDistance,
#  'mahalanobis': hdbscan.dist_metrics.MahalanobisDistance,
#  'wminkowski': hdbscan.dist_metrics.WMinkowskiDistance,
#  'hamming': hdbscan.dist_metrics.HammingDistance,
#  'canberra': hdbscan.dist_metrics.CanberraDistance,
#  'braycurtis': hdbscan.dist_metrics.BrayCurtisDistance,
#  'matching': hdbscan.dist_metrics.MatchingDistance,
#  'jaccard': hdbscan.dist_metrics.JaccardDistance,
#  'dice': hdbscan.dist_metrics.DiceDistance,
# ...

# %%
clusterer = hdbscan.HDBSCAN(metric='euclidean',min_cluster_size=15).fit(data)
color_palette = sns.color_palette('deep', 8)
cluster_colors = [color_palette[x] if x >= 0
                  else (0.5, 0.5, 0.5)
                  for x in clusterer.labels_]
cluster_member_colors = [sns.desaturate(x, p) for x, p in
                         zip(cluster_colors, clusterer.probabilities_)]
plt.scatter(*data.T, s=50, linewidth=0, c=cluster_member_colors, alpha=0.25)

# %% [markdown]
# Use mahattan distance

# %%
clusterer = hdbscan.HDBSCAN(min_cluster_size=15, metric='manhattan').fit(data)
color_palette = sns.color_palette('deep', 8)
cluster_colors = [color_palette[x] if x >= 0
                  else (0.5, 0.5, 0.5)
                  for x in clusterer.labels_]
cluster_member_colors = [sns.desaturate(x, p) for x, p in
                         zip(cluster_colors, clusterer.probabilities_)]
plt.scatter(*data.T, s=50, linewidth=0, c=cluster_member_colors, alpha=0.25)

# %% [markdown]
# Use wminkowski distance

# %%
clusterer = hdbscan.HDBSCAN(min_cluster_size=15, metric='hamming').fit(data)
color_palette = sns.color_palette('deep', 8)
cluster_colors = [color_palette[x] if x >= 0
                  else (0.5, 0.5, 0.5)
                  for x in clusterer.labels_]
cluster_member_colors = [sns.desaturate(x, p) for x, p in
                         zip(cluster_colors, clusterer.probabilities_)]
plt.scatter(*data.T, s=50, linewidth=0, c=cluster_member_colors, alpha=0.25)

# %%
clusterer = hdbscan.HDBSCAN(min_cluster_size=15, metric='cityblock').fit(data)
color_palette = sns.color_palette('deep', 8)
cluster_colors = [color_palette[x] if x >= 0
                  else (0.5, 0.5, 0.5)
                  for x in clusterer.labels_]
cluster_member_colors = [sns.desaturate(x, p) for x, p in
                         zip(cluster_colors, clusterer.probabilities_)]
plt.scatter(*data.T, s=50, linewidth=0, c=cluster_member_colors, alpha=0.25)

# %%
from sklearn.cluster import DBSCAN

# %%
X = np.array([[1, 2], [2, 2], [2, 3],
               [8, 7], [8, 8], [25, 80]])
clustering = DBSCAN(eps=1, metric = 'cityblock',min_samples=2).fit(X)
clustering.labels_
# Out:
# array([ 0,  0,  0,  1,  1, -1], dtype=int64)

# %%
X = np.array([[1, 2], [2, 2], [2, 3],
               [8, 7], [8, 8], [25, 80]])
clustering = DBSCAN(eps=5, metric = 'manhattan',min_samples=2).fit(X)
clustering.labels_
# Out:
# array([ 0,  0,  0,  1,  1, -1], dtype=int64)
